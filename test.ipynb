# %%
import anndata

# %%
anndata_obj = anndata.read("output.h5ad", backed="r")
# Out:
# /Users/ugur/github/castools/venv/lib/python3.9/site-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
anndata_obj.obs
# Out:
#                                   ROIGroup   ROIGroupCoarse     ROIGroupFine  \
# CellID
# 10X377_4:CCACGTTAGGAAGTCC         Thalamus         Thalamus         Thalamus
# 10X206_4:CATACTTTCTGAGAAA         Thalamus         Thalamus         Thalamus
# 10X359_4:ATCACTTAGTAGTCCT         Thalamus         Thalamus         Thalamus
# 10X215_7:GTAGATCAGTTCATCG  Cerebral cortex  Cerebral cortex  Cerebral cortex
# 10X221_5:ACTTATCGTCAGTCGC  Cerebral cortex  Cerebral cortex  Cerebral cortex
# ...                                    ...              ...              ...
# 10X387_7:ATCACGATCTCGCTCA        Hindbrain   Myelencephalon   Myelencephalon
# 10X219_5:TAACTTCGTGGACTGA  Cerebral nuclei  Cerebral nuclei  Basal forebrain
# 10X387_7:AATAGAGAGCCTTGAT        Hindbrain   Myelencephalon   Myelencephalon
# 10X219_5:GGGTCTGAGGTTATAG  Cerebral nuclei  Cerebral nuclei  Basal forebrain
# 10X191_1:CACAGGCTCTTAGCTT  Cerebral nuclei  Cerebral nuclei  Basal forebrain
#
# ...

# %%
anndata_obj.obs[anndata_obj.obs["cell_label-supercluster_term"] == "Vascular"]
# Out:
#                                   ROIGroup   ROIGroupCoarse     ROIGroupFine  \
# CellID
# 10X377_4:CCACGTTAGGAAGTCC         Thalamus         Thalamus         Thalamus
# 10X206_4:CATACTTTCTGAGAAA         Thalamus         Thalamus         Thalamus
# 10X359_4:ATCACTTAGTAGTCCT         Thalamus         Thalamus         Thalamus
# 10X215_7:GTAGATCAGTTCATCG  Cerebral cortex  Cerebral cortex  Cerebral cortex
# 10X221_5:ACTTATCGTCAGTCGC  Cerebral cortex  Cerebral cortex  Cerebral cortex
# ...                                    ...              ...              ...
# 10X387_7:ATCACGATCTCGCTCA        Hindbrain   Myelencephalon   Myelencephalon
# 10X219_5:TAACTTCGTGGACTGA  Cerebral nuclei  Cerebral nuclei  Basal forebrain
# 10X387_7:AATAGAGAGCCTTGAT        Hindbrain   Myelencephalon   Myelencephalon
# 10X219_5:GGGTCTGAGGTTATAG  Cerebral nuclei  Cerebral nuclei  Basal forebrain
# 10X191_1:CACAGGCTCTTAGCTT  Cerebral nuclei  Cerebral nuclei  Basal forebrain
#
# ...

# %%
anndata_obj.obs[anndata_obj.obs["cell_label-Subtype auto-annotation"] == "VENOUS"]
# Out:
#                                   ROIGroup   ROIGroupCoarse     ROIGroupFine  \
# CellID
# 10X362_6:TCCACGTGTACTTGTG     Hypothalamus     Hypothalamus     Hypothalamus
# 10X194_7:ATCGTGACAGCTCGGT         Midbrain         Midbrain         Midbrain
# 10X362_6:CCACAAAGTCGTCAGC     Hypothalamus     Hypothalamus     Hypothalamus
# 10X176_3:ACATTTCGTTCCTACC        Hindbrain             Pons             Pons
# 10X190_2:GTGGAGACAATCGAAA  Cerebral cortex  Cerebral cortex  Cerebral cortex
# ...                                    ...              ...              ...
# 10X243_4:TGCTCGTGTGTATCCA        Hindbrain       Cerebellum       Cerebellum
# 10X362_5:CTTAGGAGTAGACTGG     Hypothalamus     Hypothalamus     Hypothalamus
# 10X348_3:ACAACCACAGAACTCT         Thalamus         Thalamus         Thalamus
# 10X204_4:CATAAGCAGGGTAATT        Hindbrain   Myelencephalon   Myelencephalon
# 10X175_7:CAGCAATCAGCTACTA         Midbrain         Midbrain         Midbrain
#
# ...

# %%
anndata_obj.uns
# Out:
# {'Subtype auto-annotation-description': 'Subtype auto-annotation xxx',
#  'author_name': 'Kimberly Siletti',
#  'batch_condition': array(['sample_id'], dtype=object),
#  'schema_version': '3.1.0',
#  'supercluster_term-description': 'supercluster_term xxx',
#  'title': 'All non-neuronal cells'}
