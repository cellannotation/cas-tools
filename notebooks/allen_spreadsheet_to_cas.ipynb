# %% [markdown]
# ### Converting an Allen-Style Taxonomy Spreadsheet to CAS Format
#
# This notebook demonstrates how to convert an Allen-style taxonomy spreadsheet into the CAS (Cell Annotation Schema) format. The process includes the following steps:
#
# 1. **Generate CAS**: Convert the spreadsheet data into the CAS format.
# 2. **Validate CAS against h5ad**: Compare CAS and AnnData to check if the annotations and the hierarchy are the same.
# 3. **Populate IDs**: Add corresponding Cell IDs to the CAS from a related Anndata (h5ad) file.
# 4. **Merge Data**: Integrate the updated CAS into the `var` field of the Anndata object.
#
# This workflow uses a subset of the WMBO dataset. Example Allen-style spreadsheet is derived from the `CB Glut (CS20230722_CLAS_29)` subset of the Mouse Cell-type annotations (https://www.nature.com/articles/s41586-023-06812-z#Sec49, Table 7)

# %% [markdown]
# #### Installing Required Packages

# %%
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install anndata
# !{sys.executable} -m pip install --upgrade cas-tools
# Out:
# Requirement already satisfied: pandas in ./venv/lib/python3.9/site-packages (2.2.1)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.9/site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in ./venv/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.9/site-packages (from pandas) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.9/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/hk9/workspaces/workspace3/cas-tools/notebooks/venv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: anndata in ./venv/lib/python3.9/site-packages (0.10.5)
# Requirement already satisfied: h5py>=3 in ./venv/lib/python3.9/site-packages (from anndata) (3.10.0)
# Requirement already satisfied: array-api-compat in ./venv/lib/python3.9/site-packages (from anndata) (1.10.0)
# Requirement already satisfied: scipy>1.4 in ./venv/lib/python3.9/site-packages (from anndata) (1.13.1)
# Requirement already satisfied: exceptiongroup in ./venv/lib/python3.9/site-packages (from anndata) (1.2.2)
# Requirement already satisfied: packaging>=20 in ./venv/lib/python3.9/site-packages (from anndata) (24.2)
# Requirement already satisfied: pandas!=2.1.0rc0,!=2.1.2,>=1.1.1 in ./venv/lib/python3.9/site-packages (from anndata) (2.2.1)
# Requirement already satisfied: natsort in ./venv/lib/python3.9/site-packages (from anndata) (8.4.0)
# Requirement already satisfied: numpy>=1.16.5 in ./venv/lib/python3.9/site-packages (from anndata) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.9/site-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.1.1->anndata) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.9/site-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.1.1->anndata) (2.9.0)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.9/site-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.1.1->anndata) (2024.2)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0rc0,!=2.1.2,>=1.1.1->anndata) (1.17.0)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/hk9/workspaces/workspace3/cas-tools/notebooks/venv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: cas-tools in ./venv/lib/python3.9/site-packages (1.1.2)
# Requirement already satisfied: oaklib==0.6.4 in ./venv/lib/python3.9/site-packages (from cas-tools) (0.6.4)
# Requirement already satisfied: dataclasses-json==0.6.4 in ./venv/lib/python3.9/site-packages (from cas-tools) (0.6.4)
# Requirement already satisfied: cas-linkml<0.0.15,>=0.0.14 in ./venv/lib/python3.9/site-packages (from cas-tools) (0.0.14)
# Requirement already satisfied: schema-automator==0.5.1 in ./venv/lib/python3.9/site-packages (from cas-tools) (0.5.1)
# Requirement already satisfied: deepmerge==1.1.0 in ./venv/lib/python3.9/site-packages (from cas-tools) (1.1.0)
# Requirement already satisfied: cap-anndata<0.4.0,>=0.3.0 in ./venv/lib/python3.9/site-packages (from cas-tools) (0.3.1)
# Requirement already satisfied: pandas==2.2.1 in ./venv/lib/python3.9/site-packages (from cas-tools) (2.2.1)
# Requirement already satisfied: defusedxml==0.7.1 in ./venv/lib/python3.9/site-packages (from cas-tools) (0.7.1)
# Requirement already satisfied: anndata==0.10.5 in ./venv/lib/python3.9/site-packages (from cas-tools) (0.10.5)
# Requirement already satisfied: openpyxl==3.1.2 in ./venv/lib/python3.9/site-packages (from cas-tools) (3.1.2)
# Requirement already satisfied: ordered-set==4.1.0 in ./venv/lib/python3.9/site-packages (from cas-tools) (4.1.0)
# Requirement already satisfied: linkml==1.7.8 in ./venv/lib/python3.9/site-packages (from cas-tools) (1.7.8)
# Requirement already satisfied: cellxgene-census==1.15.0 in ./venv/lib/python3.9/site-packages (from cas-tools) (1.15.0)
# Requirement already satisfied: requests==2.32.3 in ./venv/lib/python3.9/site-packages (from cas-tools) (2.32.3)
# Requirement already satisfied: marshmallow==3.21.1 in ./venv/lib/python3.9/site-packages (from cas-tools) (3.21.1)
# Requirement already satisfied: cell-annotation-schema==1.0.0 in ./venv/lib/python3.9/site-packages (from cas-tools) (1.0.0)
# Requirement already satisfied: psycopg2-binary==2.9.5 in ./venv/lib/python3.9/site-packages (from cas-tools) (2.9.5)
# Requirement already satisfied: python-dateutil==2.9.0 in ./venv/lib/python3.9/site-packages (from cas-tools) (2.9.0)
# Requirement already satisfied: jsonschema==4.4.0 in ./venv/lib/python3.9/site-packages (from cas-tools) (4.4.0)
# Requirement already satisfied: h5py==3.10.0 in ./venv/lib/python3.9/site-packages (from cas-tools) (3.10.0)
# Requirement already satisfied: numpy==1.26.4 in ./venv/lib/python3.9/site-packages (from cas-tools) (1.26.4)
# Requirement already satisfied: ruamel-yaml==0.18.6 in ./venv/lib/python3.9/site-packages (from cas-tools) (0.18.6)
# Requirement already satisfied: rdflib==7.0.0 in ./venv/lib/python3.9/site-packages (from cas-tools) (7.0.0)
# Requirement already satisfied: urllib3<2 in ./venv/lib/python3.9/site-packages (from cas-tools) (1.26.20)
# Requirement already satisfied: natsort in ./venv/lib/python3.9/site-packages (from anndata==0.10.5->cas-tools) (8.4.0)
# Requirement already satisfied: array-api-compat in ./venv/lib/python3.9/site-packages (from anndata==0.10.5->cas-tools) (1.10.0)
# Requirement already satisfied: exceptiongroup in ./venv/lib/python3.9/site-packages (from anndata==0.10.5->cas-tools) (1.2.2)
# Requirement already satisfied: packaging>=20 in ./venv/lib/python3.9/site-packages (from anndata==0.10.5->cas-tools) (24.2)
# Requirement already satisfied: scipy>1.4 in ./venv/lib/python3.9/site-packages (from anndata==0.10.5->cas-tools) (1.13.1)
# Requirement already satisfied: tiledbsoma~=1.11.4 in ./venv/lib/python3.9/site-packages (from cellxgene-census==1.15.0->cas-tools) (1.11.4)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.9/site-packages (from cellxgene-census==1.15.0->cas-tools) (4.12.2)
# Requirement already satisfied: s3fs>=2021.06.1 in ./venv/lib/python3.9/site-packages (from cellxgene-census==1.15.0->cas-tools) (2024.12.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./venv/lib/python3.9/site-packages (from dataclasses-json==0.6.4->cas-tools) (0.9.0)
# Requirement already satisfied: attrs>=17.4.0 in ./venv/lib/python3.9/site-packages (from jsonschema==4.4.0->cas-tools) (24.3.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./venv/lib/python3.9/site-packages (from jsonschema==4.4.0->cas-tools) (0.20.0)
# Requirement already satisfied: pyyaml in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (6.0.2)
# Requirement already satisfied: jsonasobj2<2.0.0,>=1.0.3 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (1.0.4)
# Requirement already satisfied: prefixcommons>=0.1.7 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (0.1.12)
# Requirement already satisfied: linkml-runtime>=1.7.4 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (1.8.3)
# Requirement already satisfied: jinja2>=3.1.0 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (3.1.5)
# Requirement already satisfied: click>=7.0 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (8.1.8)
# Requirement already satisfied: pyjsg>=0.11.6 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (0.11.10)
# Requirement already satisfied: pyshex>=0.7.20 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (0.8.1)
# Requirement already satisfied: hbreader in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (0.9.1)
# Requirement already satisfied: pydantic<3.0.0,>=1.0.0 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (2.10.5)
# Requirement already satisfied: antlr4-python3-runtime<4.10,>=4.9.0 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (4.9.3)
# Requirement already satisfied: pyshexc>=0.8.3 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (0.9.1)
# Requirement already satisfied: linkml-dataops in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (0.1.0)
# Requirement already satisfied: parse in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (1.20.2)
# Requirement already satisfied: watchdog>=0.9.0 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (6.0.0)
# Requirement already satisfied: isodate>=0.6.0 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (0.6.1)
# Requirement already satisfied: sqlalchemy>=1.4.31 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (2.0.37)
# Requirement already satisfied: prefixmaps>=0.2.2 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (0.2.6)
# Requirement already satisfied: graphviz>=0.10.1 in ./venv/lib/python3.9/site-packages (from linkml==1.7.8->cas-tools) (0.20.3)
# Requirement already satisfied: curies>=0.6.6 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.10.2)
# Requirement already satisfied: SPARQLWrapper in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (2.0.0)
# Requirement already satisfied: jsonlines<5.0.0,>=4.0.0 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (4.0.0)
# Requirement already satisfied: ndex2<4.0.0,>=3.5.0 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (3.10.0)
# Requirement already satisfied: kgcl-rdflib==0.5.0 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.5.0)
# Requirement already satisfied: pystow>=0.5.0 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.7.0)
# Requirement already satisfied: sssom<0.5.0,>=0.4.4 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.4.11)
# Requirement already satisfied: eutils>=0.6.0 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.6.0)
# Requirement already satisfied: class-resolver>=0.4.2 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.5.4)
# Requirement already satisfied: pysolr<4.0.0,>=3.9.0 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (3.10.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (8.5.0)
# Requirement already satisfied: funowl>=0.2.0 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.2.3)
# Requirement already satisfied: pronto>=2.5.0 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (2.5.8)
# Requirement already satisfied: kgcl-schema<0.7.0,>=0.6.8 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.6.9)
# Requirement already satisfied: ols-client>=0.1.1 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.1.4)
# Requirement already satisfied: requests-cache<2.0.0,>=1.0.1 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (1.2.1)
# Requirement already satisfied: ontoportal-client>=0.0.3 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.0.4)
# Requirement already satisfied: networkx>=2.7.1 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (3.2.1)
# Requirement already satisfied: appdirs>=1.4.4 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (1.4.4)
# Requirement already satisfied: ratelimit>=2.2.1 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (2.2.1)
# Requirement already satisfied: linkml-renderer>=0.3.0 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.3.1)
# Requirement already satisfied: airium>=0.2.5 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.2.6)
# Requirement already satisfied: semsql>=0.3.1 in ./venv/lib/python3.9/site-packages (from oaklib==0.6.4->cas-tools) (0.3.3)
# Requirement already satisfied: et-xmlfile in ./venv/lib/python3.9/site-packages (from openpyxl==3.1.2->cas-tools) (2.0.0)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.9/site-packages (from pandas==2.2.1->cas-tools) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.9/site-packages (from pandas==2.2.1->cas-tools) (2024.2)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.9/site-packages (from python-dateutil==2.9.0->cas-tools) (1.17.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.9/site-packages (from rdflib==7.0.0->cas-tools) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests==2.32.3->cas-tools) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests==2.32.3->cas-tools) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests==2.32.3->cas-tools) (2024.12.14)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in ./venv/lib/python3.9/site-packages (from ruamel-yaml==0.18.6->cas-tools) (0.2.12)
# Requirement already satisfied: quantulum3>=0.7.9 in ./venv/lib/python3.9/site-packages (from schema-automator==0.5.1->cas-tools) (0.9.2)
# Requirement already satisfied: tomlkit>=0.11.4 in ./venv/lib/python3.9/site-packages (from schema-automator==0.5.1->cas-tools) (0.13.2)
# Requirement already satisfied: jsonpatch>=1.32 in ./venv/lib/python3.9/site-packages (from schema-automator==0.5.1->cas-tools) (1.33)
# Requirement already satisfied: inflect>=6.0.0 in ./venv/lib/python3.9/site-packages (from schema-automator==0.5.1->cas-tools) (7.5.0)
# Requirement already satisfied: xmltodict<0.14.0,>=0.13.0 in ./venv/lib/python3.9/site-packages (from schema-automator==0.5.1->cas-tools) (0.13.0)
# Requirement already satisfied: pandera>=0.12.0 in ./venv/lib/python3.9/site-packages (from schema-automator==0.5.1->cas-tools) (0.22.1)
# Requirement already satisfied: click-default-group<2.0.0,>=1.2.4 in ./venv/lib/python3.9/site-packages (from schema-automator==0.5.1->cas-tools) (1.2.4)
# Requirement already satisfied: duckdb<0.11.0,>=0.10.1 in ./venv/lib/python3.9/site-packages (from schema-automator==0.5.1->cas-tools) (0.10.3)
# Requirement already satisfied: schemasheets>=0.1.24 in ./venv/lib/python3.9/site-packages (from schema-automator==0.5.1->cas-tools) (0.3.1)
# Requirement already satisfied: mkdocs>=1.2.3 in ./venv/lib/python3.9/site-packages (from schema-automator==0.5.1->cas-tools) (1.6.1)
# Requirement already satisfied: click-log>=0.4.0 in ./venv/lib/python3.9/site-packages (from schema-automator==0.5.1->cas-tools) (0.4.0)
# Requirement already satisfied: strsimpy>=0.2.1 in ./venv/lib/python3.9/site-packages (from schema-automator==0.5.1->cas-tools) (0.2.1)
# Requirement already satisfied: dacite<2.0.0,>=1.8.1 in ./venv/lib/python3.9/site-packages (from cas-linkml<0.0.15,>=0.0.14->cas-tools) (1.8.1)
# Requirement already satisfied: importlib-metadata>3.6 in ./venv/lib/python3.9/site-packages (from class-resolver>=0.4.2->oaklib==0.6.4->cas-tools) (8.5.0)
# Requirement already satisfied: eval-type-backport in ./venv/lib/python3.9/site-packages (from curies>=0.6.6->oaklib==0.6.4->cas-tools) (0.2.2)
# Requirement already satisfied: pytrie in ./venv/lib/python3.9/site-packages (from curies>=0.6.6->oaklib==0.6.4->cas-tools) (0.4.0)
# Requirement already satisfied: lxml in ./venv/lib/python3.9/site-packages (from eutils>=0.6.0->oaklib==0.6.4->cas-tools) (5.3.0)
# Requirement already satisfied: jsonasobj in ./venv/lib/python3.9/site-packages (from funowl>=0.2.0->oaklib==0.6.4->cas-tools) (1.3.1)
# Requirement already satisfied: bcp47 in ./venv/lib/python3.9/site-packages (from funowl>=0.2.0->oaklib==0.6.4->cas-tools) (0.1.0)
# Requirement already satisfied: rfc3987 in ./venv/lib/python3.9/site-packages (from funowl>=0.2.0->oaklib==0.6.4->cas-tools) (1.3.8)
# Requirement already satisfied: rdflib-shim in ./venv/lib/python3.9/site-packages (from funowl>=0.2.0->oaklib==0.6.4->cas-tools) (1.0.3)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.9/site-packages (from importlib-metadata>3.6->class-resolver>=0.4.2->oaklib==0.6.4->cas-tools) (3.21.0)
# Requirement already satisfied: more_itertools>=8.5.0 in ./venv/lib/python3.9/site-packages (from inflect>=6.0.0->schema-automator==0.5.1->cas-tools) (10.6.0)
# Requirement already satisfied: typeguard>=4.0.1 in ./venv/lib/python3.9/site-packages (from inflect>=6.0.0->schema-automator==0.5.1->cas-tools) (4.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.9/site-packages (from jinja2>=3.1.0->linkml==1.7.8->cas-tools) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.9/site-packages (from jsonpatch>=1.32->schema-automator==0.5.1->cas-tools) (3.0.0)
# Requirement already satisfied: webcolors>=1.11 in ./venv/lib/python3.9/site-packages (from jsonschema==4.4.0->cas-tools) (24.11.1)
# Requirement already satisfied: rfc3339-validator in ./venv/lib/python3.9/site-packages (from jsonschema==4.4.0->cas-tools) (0.1.4)
# Requirement already satisfied: fqdn in ./venv/lib/python3.9/site-packages (from jsonschema==4.4.0->cas-tools) (1.5.1)
# Requirement already satisfied: isoduration in ./venv/lib/python3.9/site-packages (from jsonschema==4.4.0->cas-tools) (20.11.0)
# Requirement already satisfied: uri-template in ./venv/lib/python3.9/site-packages (from jsonschema==4.4.0->cas-tools) (1.3.0)
# Requirement already satisfied: lark>=1.1.2 in ./venv/lib/python3.9/site-packages (from kgcl-schema<0.7.0,>=0.6.8->oaklib==0.6.4->cas-tools) (1.2.2)
# Requirement already satisfied: deprecated in ./venv/lib/python3.9/site-packages (from linkml-runtime>=1.7.4->linkml==1.7.8->cas-tools) (1.2.15)
# Requirement already satisfied: json-flattener>=0.1.9 in ./venv/lib/python3.9/site-packages (from linkml-runtime>=1.7.4->linkml==1.7.8->cas-tools) (0.1.9)
# Requirement already satisfied: mergedeep>=1.3.4 in ./venv/lib/python3.9/site-packages (from mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools) (1.3.4)
# Requirement already satisfied: mkdocs-get-deps>=0.2.0 in ./venv/lib/python3.9/site-packages (from mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools) (0.2.0)
# Requirement already satisfied: markdown>=3.3.6 in ./venv/lib/python3.9/site-packages (from mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools) (3.7)
# Requirement already satisfied: pathspec>=0.11.1 in ./venv/lib/python3.9/site-packages (from mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools) (0.12.1)
# Requirement already satisfied: ghp-import>=1.0 in ./venv/lib/python3.9/site-packages (from mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools) (2.1.0)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in ./venv/lib/python3.9/site-packages (from mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools) (0.1)
# Requirement already satisfied: platformdirs>=2.2.0 in ./venv/lib/python3.9/site-packages (from mkdocs-get-deps>=0.2.0->mkdocs>=1.2.3->schema-automator==0.5.1->cas-tools) (4.3.6)
# Requirement already satisfied: requests-toolbelt in ./venv/lib/python3.9/site-packages (from ndex2<4.0.0,>=3.5.0->oaklib==0.6.4->cas-tools) (1.0.0)
# Requirement already satisfied: ijson in ./venv/lib/python3.9/site-packages (from ndex2<4.0.0,>=3.5.0->oaklib==0.6.4->cas-tools) (3.3.0)
# Requirement already satisfied: more-click in ./venv/lib/python3.9/site-packages (from ols-client>=0.1.1->oaklib==0.6.4->cas-tools) (0.1.2)
# Requirement already satisfied: pytest-logging<2016.0.0,>=2015.11.4 in ./venv/lib/python3.9/site-packages (from prefixcommons>=0.1.7->linkml==1.7.8->cas-tools) (2015.11.4)
# Requirement already satisfied: fastobo~=0.12.2 in ./venv/lib/python3.9/site-packages (from pronto>=2.5.0->oaklib==0.6.4->cas-tools) (0.12.3)
# Requirement already satisfied: chardet~=5.0 in ./venv/lib/python3.9/site-packages (from pronto>=2.5.0->oaklib==0.6.4->cas-tools) (5.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=1.0.0->linkml==1.7.8->cas-tools) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=1.0.0->linkml==1.7.8->cas-tools) (2.27.2)
# Requirement already satisfied: cfgraph>=0.2.1 in ./venv/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml==1.7.8->cas-tools) (0.2.1)
# Requirement already satisfied: shexjsg>=0.8.2 in ./venv/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml==1.7.8->cas-tools) (0.8.2)
# Requirement already satisfied: sparqlslurper>=0.5.1 in ./venv/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml==1.7.8->cas-tools) (0.5.1)
# Requirement already satisfied: setuptools in ./venv/lib/python3.9/site-packages (from pysolr<4.0.0,>=3.9.0->oaklib==0.6.4->cas-tools) (58.0.4)
# Requirement already satisfied: tqdm in ./venv/lib/python3.9/site-packages (from pystow>=0.5.0->oaklib==0.6.4->cas-tools) (4.67.1)
# Requirement already satisfied: pytest>=2.8.1 in ./venv/lib/python3.9/site-packages (from pytest-logging<2016.0.0,>=2015.11.4->prefixcommons>=0.1.7->linkml==1.7.8->cas-tools) (8.3.4)
# Requirement already satisfied: iniconfig in ./venv/lib/python3.9/site-packages (from pytest>=2.8.1->pytest-logging<2016.0.0,>=2015.11.4->prefixcommons>=0.1.7->linkml==1.7.8->cas-tools) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./venv/lib/python3.9/site-packages (from pytest>=2.8.1->pytest-logging<2016.0.0,>=2015.11.4->prefixcommons>=0.1.7->linkml==1.7.8->cas-tools) (1.5.0)
# Requirement already satisfied: tomli>=1 in ./venv/lib/python3.9/site-packages (from pytest>=2.8.1->pytest-logging<2016.0.0,>=2015.11.4->prefixcommons>=0.1.7->linkml==1.7.8->cas-tools) (2.2.1)
# Requirement already satisfied: num2words in ./venv/lib/python3.9/site-packages (from quantulum3>=0.7.9->schema-automator==0.5.1->cas-tools) (0.5.14)
# Requirement already satisfied: url-normalize>=1.4 in ./venv/lib/python3.9/site-packages (from requests-cache<2.0.0,>=1.0.1->oaklib==0.6.4->cas-tools) (1.4.3)
# Requirement already satisfied: cattrs>=22.2 in ./venv/lib/python3.9/site-packages (from requests-cache<2.0.0,>=1.0.1->oaklib==0.6.4->cas-tools) (24.1.2)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in ./venv/lib/python3.9/site-packages (from s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (2.18.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./venv/lib/python3.9/site-packages (from s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (3.11.11)
# Requirement already satisfied: fsspec==2024.12.0.* in ./venv/lib/python3.9/site-packages (from s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (2024.12.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in ./venv/lib/python3.9/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (0.12.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./venv/lib/python3.9/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in ./venv/lib/python3.9/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (6.1.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in ./venv/lib/python3.9/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (1.17.2)
# Requirement already satisfied: botocore<1.36.2,>=1.36.0 in ./venv/lib/python3.9/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (1.36.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (1.18.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (2.4.4)
# Requirement already satisfied: propcache>=0.2.0 in ./venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (0.2.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (1.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2021.06.1->cellxgene-census==1.15.0->cas-tools) (5.0.1)
# Requirement already satisfied: ontodev-cogs<0.4.0,>=0.3.3 in ./venv/lib/python3.9/site-packages (from schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (0.3.3)
# Requirement already satisfied: bioregistry>0.5.0 in ./venv/lib/python3.9/site-packages (from schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (0.11.34)
# Requirement already satisfied: google in ./venv/lib/python3.9/site-packages (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (3.0.0)
# Requirement already satisfied: google-api-python-client in ./venv/lib/python3.9/site-packages (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (2.159.0)
# Requirement already satisfied: gspread in ./venv/lib/python3.9/site-packages (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (6.1.4)
# Requirement already satisfied: gspread-formatting in ./venv/lib/python3.9/site-packages (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (1.2.0)
# Requirement already satisfied: tabulate in ./venv/lib/python3.9/site-packages (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (0.9.0)
# Requirement already satisfied: daff in ./venv/lib/python3.9/site-packages (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (1.3.46)
# Requirement already satisfied: termcolor in ./venv/lib/python3.9/site-packages (from ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (2.5.0)
# Requirement already satisfied: SQLAlchemy-Utils<0.39.0,>=0.38.2 in ./venv/lib/python3.9/site-packages (from semsql>=0.3.1->oaklib==0.6.4->cas-tools) (0.38.3)
# Requirement already satisfied: importlib-resources<7.0.0,>=6.1.1 in ./venv/lib/python3.9/site-packages (from sssom<0.5.0,>=0.4.4->oaklib==0.6.4->cas-tools) (6.5.2)
# Requirement already satisfied: pansql[pansql]>=0.0.1 in ./venv/lib/python3.9/site-packages (from sssom<0.5.0,>=0.4.4->oaklib==0.6.4->cas-tools) (0.0.1)
# Requirement already satisfied: validators>=0.20.0 in ./venv/lib/python3.9/site-packages (from sssom<0.5.0,>=0.4.4->oaklib==0.6.4->cas-tools) (0.34.0)
# Requirement already satisfied: deprecation<3.0.0,>=2.1.0 in ./venv/lib/python3.9/site-packages (from sssom<0.5.0,>=0.4.4->oaklib==0.6.4->cas-tools) (2.1.0)
# Requirement already satisfied: sssom-schema<0.16.0,>=0.15.2 in ./venv/lib/python3.9/site-packages (from sssom<0.5.0,>=0.4.4->oaklib==0.6.4->cas-tools) (0.15.2)
# WARNING: networkx 3.2.1 does not provide the extra 'networkx'
# WARNING: pansql 0.0.1 does not provide the extra 'pansql'
# Requirement already satisfied: numba>=0.58.0 in ./venv/lib/python3.9/site-packages (from tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (0.60.0)
# Requirement already satisfied: tiledb~=0.29.0 in ./venv/lib/python3.9/site-packages (from tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (0.29.1)
# Requirement already satisfied: somacore==1.0.11 in ./venv/lib/python3.9/site-packages (from tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (1.0.11)
# Requirement already satisfied: pyarrow<13.0.0,>=9.0.0 in ./venv/lib/python3.9/site-packages (from tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (12.0.1)
# Requirement already satisfied: pyarrow-hotfix in ./venv/lib/python3.9/site-packages (from tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (0.6)
# Requirement already satisfied: scanpy>=1.9.2 in ./venv/lib/python3.9/site-packages (from tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (1.10.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in ./venv/lib/python3.9/site-packages (from numba>=0.58.0->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (0.43.0)
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in ./venv/lib/python3.9/site-packages (from scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (0.5.7)
# Requirement already satisfied: seaborn>=0.13 in ./venv/lib/python3.9/site-packages (from scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (0.13.2)
# Requirement already satisfied: session-info in ./venv/lib/python3.9/site-packages (from scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (1.0.0)
# Requirement already satisfied: legacy-api-wrap>=1.4 in ./venv/lib/python3.9/site-packages (from scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (1.4.1)
# Requirement already satisfied: matplotlib>=3.6 in ./venv/lib/python3.9/site-packages (from scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (3.9.4)
# Requirement already satisfied: scikit-learn>=0.24 in ./venv/lib/python3.9/site-packages (from scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (1.6.1)
# Requirement already satisfied: pynndescent>=0.5 in ./venv/lib/python3.9/site-packages (from scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (0.5.13)
# Requirement already satisfied: statsmodels>=0.13 in ./venv/lib/python3.9/site-packages (from scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (0.14.4)
# Requirement already satisfied: patsy in ./venv/lib/python3.9/site-packages (from scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (1.0.1)
# Requirement already satisfied: get-annotations in ./venv/lib/python3.9/site-packages (from scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (0.1.2)
# Requirement already satisfied: joblib in ./venv/lib/python3.9/site-packages (from scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (1.4.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (1.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (4.55.3)
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (11.1.0)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (0.12.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./venv/lib/python3.9/site-packages (from scikit-learn>=0.24->scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (3.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json==0.6.4->cas-tools) (1.0.0)
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.9/site-packages (from google->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.9/site-packages (from beautifulsoup4->google->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (2.6)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in ./venv/lib/python3.9/site-packages (from google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in ./venv/lib/python3.9/site-packages (from google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (4.1.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in ./venv/lib/python3.9/site-packages (from google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (0.22.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in ./venv/lib/python3.9/site-packages (from google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (2.24.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in ./venv/lib/python3.9/site-packages (from google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (2.37.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./venv/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (1.66.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in ./venv/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (1.25.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in ./venv/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (5.29.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./venv/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (5.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in ./venv/lib/python3.9/site-packages (from gspread->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (1.2.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./venv/lib/python3.9/site-packages (from google-auth-oauthlib>=0.4.1->gspread->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread->ontodev-cogs<0.4.0,>=0.3.3->schemasheets>=0.1.24->schema-automator==0.5.1->cas-tools) (3.2.2)
# Requirement already satisfied: arrow>=0.15.0 in ./venv/lib/python3.9/site-packages (from isoduration->jsonschema==4.4.0->cas-tools) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->jsonschema==4.4.0->cas-tools) (2.9.0.20241206)
# Requirement already satisfied: jsonpath-ng in ./venv/lib/python3.9/site-packages (from linkml-dataops->linkml==1.7.8->cas-tools) (1.7.0)
# Requirement already satisfied: ply in ./venv/lib/python3.9/site-packages (from jsonpath-ng->linkml-dataops->linkml==1.7.8->cas-tools) (3.11)
# Requirement already satisfied: docopt>=0.6.2 in ./venv/lib/python3.9/site-packages (from num2words->quantulum3>=0.7.9->schema-automator==0.5.1->cas-tools) (0.6.2)
# Requirement already satisfied: sortedcontainers in ./venv/lib/python3.9/site-packages (from pytrie->curies>=0.6.6->oaklib==0.6.4->cas-tools) (2.4.0)
# Requirement already satisfied: rdflib-jsonld==0.6.1 in ./venv/lib/python3.9/site-packages (from rdflib-shim->funowl>=0.2.0->oaklib==0.6.4->cas-tools) (0.6.1)
# WARNING: scipy 1.13.1 does not provide the extra 'scipy'
# Requirement already satisfied: stdlib-list in ./venv/lib/python3.9/site-packages (from session-info->scanpy>=1.9.2->tiledbsoma~=1.11.4->cellxgene-census==1.15.0->cas-tools) (0.11.0)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/hk9/workspaces/workspace3/cas-tools/notebooks/venv/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# #### Example of an Allen-Style Spreadsheet
#
# To keep things simple, we use the `CB Glut (CS20230722_CLAS_29)` subset from the Mouse Cell-Type Annotations dataset (refer to [Nature article, Supplementary Table 7](https://www.nature.com/articles/s41586-023-06812-z#Sec49)).

# %%
import pandas as pd

pd.read_csv("./data/wmb_class_29_annotation.tsv", delimiter='\t')[:4]
# Out:
#    cluster_id                 cluster               supertype  \
# 0        5197  5197 CB Granule Glut_1  1154 CB Granule Glut_1
# 1        5198  5198 CB Granule Glut_1  1154 CB Granule Glut_1
# 2        5199  5199 CB Granule Glut_1  1154 CB Granule Glut_1
# 3        5200  5200 CB Granule Glut_2  1155 CB Granule Glut_2
#
#               subclass       class neighborhood anatomical_annotation  notes  \
# 0  314 CB Granule Glut  29 CB Glut    NN-IMN-GC               DCO VCO    NaN
# 1  314 CB Granule Glut  29 CB Glut    NN-IMN-GC               DCO VCO    NaN
# 2  314 CB Granule Glut  29 CB Glut    NN-IMN-GC               DCO VCO    NaN
# 3  314 CB Granule Glut  29 CB Glut    NN-IMN-GC               NOD PFL    NaN
#
#             CCF_broad.freq                                   CCF_acronym.freq  \
# 0  MY:0.35,CB:0.33,NA:0.26  DCO:0.19,FL:0.11,arb:0.09,VCO:0.09,DN:0.08,PFL...
# 1  CB:0.56,MY:0.24,NA:0.19  FL:0.25,PFL:0.17,DCO:0.13,VCO:0.09,arb:0.08,NA...
# 2   MY:0.4,CB:0.38,NA:0.18  DCO:0.29,DN:0.12,arb:0.09,FL:0.09,PFL:0.06,VCO...
# 3          CB:0.77,NA:0.22  PFL:0.17,NOD:0.17,FL:0.13,NA:0.11,arb:0.1,UVU:...
#
#    ...  CTX.subclass_id  CTX.subclass_id.1  CTX.neighborhood_id  \
# 0  ...              NaN                NaN                  NaN
# 1  ...              NaN                NaN                  NaN
# 2  ...              NaN                NaN                  NaN
# 3  ...              NaN                NaN                  NaN
#
#    CTX.neighborhood_label  CTX.size   taxonomy_id  cell_set_accession.cluster  \
# 0                     NaN       NaN  CCN202307220        CS20230722_CLUS_5197
# 1                     NaN       NaN  CCN202307220        CS20230722_CLUS_5198
# 2                     NaN       NaN  CCN202307220        CS20230722_CLUS_5199
# 3                     NaN       NaN  CCN202307220        CS20230722_CLUS_5200
#
#    cell_set_accession.supertype cell_set_accession.subclass  \
# 0          CS20230722_SUPT_1154         CS20230722_SUBC_314
# 1          CS20230722_SUPT_1154         CS20230722_SUBC_314
# 2          CS20230722_SUPT_1154         CS20230722_SUBC_314
# 3          CS20230722_SUPT_1155         CS20230722_SUBC_314
#
#   cell_set_accession.class
# 0       CS20230722_CLAS_29
# 1       CS20230722_CLAS_29
# 2       CS20230722_CLAS_29
# 3       CS20230722_CLAS_29
#
# [4 rows x 40 columns]

# %% [markdown]
# #### Import Spreadsheet into CAS
#
# Import an Allen-style spreadsheet into the CAS data-classes using a simple mapping file.

# %%
import json
from cas.ingest.ingest_user_table import ingest_data, ingest_user_data

cas_data = ingest_user_data("./data/wmb_class_29_annotation.tsv", "./data/wmb_ingestion_config.yaml", True)
cas = cas_data.as_dictionary()
print(json.dumps(cas, indent=2)[:2000])
# Out:
# {
#   "author_name": "Hongkui Zeng",
#   "annotations": [
#     {
#       "labelset": "class",
#       "cell_label": "29 CB Glut",
#       "cell_set_accession": "5206"
#     },
#     {
#       "labelset": "subclass",
#       "cell_label": "314 CB Granule Glut",
#       "cell_set_accession": "5207",
#       "parent_cell_set_accession": "5206"
#     },
#     {
#       "labelset": "supertype",
#       "cell_label": "1154 CB Granule Glut_1",
#       "cell_set_accession": "5208",
#       "parent_cell_set_accession": "5207"
#     },
#     {
#       "labelset": "cluster",
#       "cell_label": "5197 CB Granule Glut_1",
#       "cell_set_accession": "5197",
#       "parent_cell_set_accession": "5208",
#       "author_annotation_fields": {
#         "neighborhood": "NN-IMN-GC",
#         "anatomical_annotation": "DCO VCO",
#         "CCF_broad.freq": "MY:0.35,CB:0.33,NA:0.26",
#         "CCF_acronym.freq": "DCO:0.19,FL:0.11,arb:0.09,VCO:0.09,DN:0.08,PFL:0.07,MY:0.07,mcp:0.06,CUL4, 5:0.04",
#         "v3.size": "14544",
#         "v2.size": "0",
#         "multiome.size": "0",
#         "F": "0.5",
#         "M": "0.5",
#         "Dark": "0.04",
#         "Light": "0.96",
#         "nt_type_label": "Glut",
#         "nt.markers": "Slc17a7:8.41",
#         "nt_type_combo_label": "Glut",
#         "cluster.markers.combo": "Gabra6,Lmx1a,Rnf182",
#         "merfish.markers.combo": "Col27a1,Barhl1,St18,Trhde,Spon1,Syt6",
#         "cluster.TF.markers.combo": "Lmx1a,Zic1,St18",
#         "cluster.markers.combo (within subclass)": "Lmx1a,Rnf182",
#         "taxonomy_id": "CCN202307220",
#         "cell_set_accession.cluster": "CS20230722_CLUS_5197",
#         "cell_set_accession.supertype": "CS20230722_SUPT_1154",
#         "cell_set_accession.subclass": "CS20230722_SUBC_314",
#         "cell_set_accession.class": "CS20230722_CLAS_29"
#       }
#     },
#     {
#       "labelset": "cluster",
#       "cell_label": "5198 CB Granule Glut_1",
#       "cell_set_accession": "5198",
#       "parent_cell_set_accession": "5208",
#       "author_annotation_fields": {
#         "neighborhood": "NN-IMN-GC"

# %% [markdown]
# #### Retrieve AnnData File for `CB Glut`
#
# Download the AnnData file corresponding to `CB Glut (CS20230722_CLAS_29)`. The original [WMB-10Xv2](https://allen-brain-cell-atlas.s3.us-west-2.amazonaws.com/index.html#expression_matrices/WMB-10Xv2/20230630/) and [WMB-10Xv3](https://allen-brain-cell-atlas.s3.us-west-2.amazonaws.com/index.html#expression_matrices/WMB-10Xv3/20230630/) AnnData files were generated based on dissection.
#
# These files were merged and then split into 34 top-level classes. The resulting AnnData files for each class can be accessed at the following links:
# - [Class 01](http://cellular-semantics.cog.sanger.ac.uk/public/merged_CS20230722_CLAS_01.h5ad)
# - [Class 02](http://cellular-semantics.cog.sanger.ac.uk/public/merged_CS20230722_CLAS_02.h5ad)
# - ...
# - [Class 34](http://cellular-semantics.cog.sanger.ac.uk/public/merged_CS20230722_CLAS_34.h5ad)
#
# The file specific to `CB Glut` is included in this collection.

# %%
# !wget -N http://cellular-semantics.cog.sanger.ac.uk/public/CS20230722_CLAS_29.h5ad
# Out:
# --2025-02-17 16:12:23--  http://cellular-semantics.cog.sanger.ac.uk/public/CS20230722_CLAS_29.h5ad
# Resolving cellular-semantics.cog.sanger.ac.uk (cellular-semantics.cog.sanger.ac.uk)... 172.27.51.1, 172.27.51.3, 172.27.51.2, ...
# Connecting to cellular-semantics.cog.sanger.ac.uk (cellular-semantics.cog.sanger.ac.uk)|172.27.51.1|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cellular-semantics.cog.sanger.ac.uk/public/CS20230722_CLAS_29.h5ad [following]
# --2025-02-17 16:12:23--  https://cellular-semantics.cog.sanger.ac.uk/public/CS20230722_CLAS_29.h5ad
# Connecting to cellular-semantics.cog.sanger.ac.uk (cellular-semantics.cog.sanger.ac.uk)|172.27.51.1|:443... connected.
# 304 Not Modifiedt, awaiting response...
# File ‘CS20230722_CLAS_29.h5ad’ not modified on server. Omitting download.

# %%
from cas.file_utils import read_anndata_file

anndata = read_anndata_file("./CS20230722_CLAS_29.h5ad")
anndata.obs[:3]
# Out:
#                               cell_barcode       library_label      tissue  \
# cell_label
# AAACCCAAGAACAAGG-472_A05  AAACCCAAGAACAAGG  L8TX_201217_01_G07  Cerebellum
# AAACCCAAGAATCCCT-473_A06  AAACCCAAGAATCCCT  L8TX_201217_01_A08  Cerebellum
# AAACCCAAGACTACCT-225_A01  AAACCCAAGACTACCT  L8TX_200227_01_F10     Medulla
#
#                          tissue_ontology_term_id       class  \
# cell_label
# AAACCCAAGAACAAGG-472_A05          UBERON:0002037  29 CB Glut
# AAACCCAAGAATCCCT-473_A06          UBERON:0002037  29 CB Glut
# AAACCCAAGACTACCT-225_A01          UBERON:0001896  29 CB Glut
#
#                                      subclass               supertype  \
# cell_label
# AAACCCAAGAACAAGG-472_A05  314 CB Granule Glut  1155 CB Granule Glut_2
# AAACCCAAGAATCCCT-473_A06  314 CB Granule Glut  1155 CB Granule Glut_2
# AAACCCAAGACTACCT-225_A01  314 CB Granule Glut  1154 CB Granule Glut_1
#
#                                          cluster      organism disease  \
# cell_label
# AAACCCAAGAACAAGG-472_A05  5201 CB Granule Glut_2  Mus musculus  normal
# AAACCCAAGAATCCCT-473_A06  5201 CB Granule Glut_2  Mus musculus  normal
# AAACCCAAGACTACCT-225_A01  5197 CB Granule Glut_1  Mus musculus  normal
#
#                          organism_ontology_term_id disease_ontology_term_id
# cell_label
# AAACCCAAGAACAAGG-472_A05           NCBITaxon:10090             PATO:0000461
# AAACCCAAGAATCCCT-473_A06           NCBITaxon:10090             PATO:0000461
# AAACCCAAGACTACCT-225_A01           NCBITaxon:10090             PATO:0000461

# %% [markdown]
# #### Analyse CAS and AnnData
#
# Compare CAS and AnnData to verify that the annotations and hierarchy are consistent.

# %%
obs = anndata.obs 

labelsets = [labelset.name for labelset in sorted(cas_data.labelsets, key=lambda x: x.rank)]
print(labelsets)

# assert cluster counts are the same
cas_clusters = { annotation.cell_label for annotation in cas_data.annotations if annotation.labelset == "cluster"}
anndata_clusters = set(obs["cluster"].unique())
assert cas_clusters == anndata_clusters

# assert hierarchies are the same
for annotation in cas_data.annotations:
    if labelsets.index(annotation.labelset) < len(labelsets) -1:
        # list all parent names for the given annotation in the AnnData
        parent_labelset = labelsets[labelsets.index(annotation.labelset) + 1]
        parent_names = obs[obs[annotation.labelset] == annotation.cell_label][parent_labelset].unique()
        # assert has only one parent
        assert len(parent_names) == 1
        # assert AnnData parent is same with CAS parent 
        assert annotation.parent_cell_set_name == parent_names[0]
# Out:
# ['cluster', 'supertype', 'subclass', 'class']

# %% [markdown]
# #### Populate CAS with Cell IDs
#
# Add Cell IDs to the CAS using data from the AnnData file.

# %%
from cas.populate_cell_ids import add_cell_ids

cas = add_cell_ids(cas, anndata.obs)

print(json.dumps(cas["annotations"][5], indent=2)[:1500])
# Out:
# {
#   "labelset": "cluster",
#   "cell_label": "5199 CB Granule Glut_1",
#   "cell_set_accession": "5199",
#   "parent_cell_set_accession": "5208",
#   "author_annotation_fields": {
#     "neighborhood": "NN-IMN-GC",
#     "anatomical_annotation": "DCO VCO",
#     "CCF_broad.freq": "MY:0.4,CB:0.38,NA:0.18",
#     "CCF_acronym.freq": "DCO:0.29,DN:0.12,arb:0.09,FL:0.09,PFL:0.06,VCO:0.05,MY:0.05,CUL4, 5:0.05,P:0.04",
#     "v3.size": "909",
#     "v2.size": "0",
#     "multiome.size": "0",
#     "F": "0.44",
#     "M": "0.56",
#     "Dark": "0.03",
#     "Light": "0.97",
#     "nt_type_label": "Glut",
#     "nt.markers": "Slc17a7:8.33,Slc17a6:3.37",
#     "nt_type_combo_label": "Glut",
#     "cluster.markers.combo": "Cbln3,Tmem132d",
#     "merfish.markers.combo": "Eomes,Col27a1,Calb2",
#     "cluster.TF.markers.combo": "Eomes,Lmx1a,Nr2f2,Lin28b",
#     "cluster.markers.combo (within subclass)": "Rgs6",
#     "taxonomy_id": "CCN202307220",
#     "cell_set_accession.cluster": "CS20230722_CLUS_5199",
#     "cell_set_accession.supertype": "CS20230722_SUPT_1154",
#     "cell_set_accession.subclass": "CS20230722_SUBC_314",
#     "cell_set_accession.class": "CS20230722_CLAS_29"
#   },
#   "cell_ids": [
#     "AAACCCAGTAGCTGTT-225_A01",
#     "AAACCCATCGAACGGA-175_B01",
#     "AAACGAAGTGTTCGTA-175_A01",
#     "AAACGAATCAGGAACG-231.2_B01",
#     "AAACGCTGTCTTGGTA-175_A01",
#     "AAAGAACTCTCGCGTT-231.2_B01",
#     "AAAGGGCCAGTCGGTC-231.2_A01",
#     "AAAGGGCGTCAAGGCA-179_C01",
#     "AAAGGTACATCCCGTT-179_C01",
#     "AAAGTCCAGAGAAGGT-175_B01",
#     "AAAGTGACATTGAGGG

# %% [markdown]
# #### Merge CAS to Anndata
#
# Adds CAS to uns of the AnnData file.

# %%
from cas.anndata_conversion import merge_cas_object
import anndata as ad

anndata.file.close()
merge_cas_object(cas, "./CS20230722_CLAS_29.h5ad", True, "./merged_CS20230722_CLAS_29_v2.h5ad")

# %%
from cas.file_utils import read_cas_from_anndata

cas_read = read_cas_from_anndata("./merged_CS20230722_CLAS_29_v2.h5ad")
cas_read.get_all_annotations().head(5)
# Out:
#     labelset              cell_label cell_set_accession cell_fullname  \
# 0      class              29 CB Glut               5206          None
# 1   subclass     314 CB Granule Glut               5207          None
# 2  supertype  1154 CB Granule Glut_1               5208          None
# 3    cluster  5197 CB Granule Glut_1               5197          None
# 4    cluster  5198 CB Granule Glut_1               5198          None
#
#   cell_ontology_term_id cell_ontology_term rationale rationale_dois  \
# 0                  None               None      None           None
# 1                  None               None      None           None
# 2                  None               None      None           None
# 3                  None               None      None           None
# 4                  None               None      None           None
#
#   marker_gene_evidence synonyms  ...  \
# 0                 None     None  ...
# 1                 None     None  ...
# 2                 None     None  ...
# 3                 None     None  ...
# 4                 None     None  ...
#
#   author_annotation_fields.cluster.markers.combo  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                            Gabra6,Lmx1a,Rnf182
# 4                                   Gabra6,Cntn5
#
#   author_annotation_fields.merfish.markers.combo  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3           Col27a1,Barhl1,St18,Trhde,Spon1,Syt6
# 4                            Svep1,Slc17a7,Chrm2
#
#    author_annotation_fields.cluster.TF.markers.combo  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                    Lmx1a,Zic1,St18
# 4                           Pax6,Neurod2,Etv1,Bcl11b
#
#   author_annotation_fields.cluster.markers.combo (within subclass)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                       Lmx1a,Rnf182
# 4                                              Cntn5
#
#   author_annotation_fields.taxonomy_id  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                         CCN202307220
# 4                         CCN202307220
#
#   author_annotation_fields.cell_set_accession.cluster  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                               CS20230722_CLUS_5197
# 4                               CS20230722_CLUS_5198
#
#   author_annotation_fields.cell_set_accession.supertype  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                               CS20230722_SUPT_1154
# 4                               CS20230722_SUPT_1154
#
#   author_annotation_fields.cell_set_accession.subclass  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                CS20230722_SUBC_314
# 4                                CS20230722_SUBC_314
#
#   author_annotation_fields.cell_set_accession.class  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                CS20230722_CLAS_29
# 4                                CS20230722_CLAS_29
#
#   author_annotation_fields.np.markers
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
# [5 rows x 39 columns]
