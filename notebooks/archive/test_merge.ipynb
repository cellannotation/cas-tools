# %%
import os
import anndata
import pandas as pd

from cas.file_utils import read_json_file, read_cas_from_anndata
from cas.anndata_conversion import merge_cas_object

# %% [markdown]
# Download [Siletti](https://cellxgene.cziscience.com/collections/283d65eb-dd53-496d-adb7-7570c7caa443) `All non-neuronal cells` dataset

# %%
anndata_obj = anndata.read_h5ad("/Users/hk9/tdt_datasets/Siletti_all_non_neuronal_cells.h5ad", backed="r")

# %%
pd.set_option('display.max_columns', None)
anndata_obj.obs
# Out:
#                                   ROIGroup   ROIGroupCoarse     ROIGroupFine  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC     Hypothalamus     Hypothalamus     Hypothalamus
# 10X362_5:TCCGTGTGTGAAAGTT     Hypothalamus     Hypothalamus     Hypothalamus
# 10X362_5:CACGGGTAGAGCAGAA     Hypothalamus     Hypothalamus     Hypothalamus
# 10X362_5:GATTCTTGTATGTCAC     Hypothalamus     Hypothalamus     Hypothalamus
# 10X362_6:AGGACTTGTATCCTTT     Hypothalamus     Hypothalamus     Hypothalamus
# ...                                    ...              ...              ...
# 10X194_8:GAAATGAGTTCGGCTG         Midbrain         Midbrain         Midbrain
# 10X350_4:TTTACCATCGCACGAC        Hindbrain       Cerebellum       Cerebellum
# 10X225_1:AGAAGCGTCCATATGG         Midbrain         Midbrain         Midbrain
# 10X221_5:TTGAACGCAGCCTTCT  Cerebral cortex  Cerebral cortex  Cerebral cortex
# 10X385_3:CTACCCAGTGGCGCTT  Cerebral nuclei  Cerebral nuclei     Basal nuclei
#
#                                   roi organism_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC    Human MN            NCBITaxon:9606
# 10X362_5:TCCGTGTGTGAAAGTT    Human MN            NCBITaxon:9606
# 10X362_5:CACGGGTAGAGCAGAA    Human MN            NCBITaxon:9606
# 10X362_5:GATTCTTGTATGTCAC    Human MN            NCBITaxon:9606
# 10X362_6:AGGACTTGTATCCTTT    Human MN            NCBITaxon:9606
# ...                               ...                       ...
# 10X194_8:GAAATGAGTTCGGCTG    Human SN            NCBITaxon:9606
# 10X350_4:TTTACCATCGCACGAC  Human CbDN            NCBITaxon:9606
# 10X225_1:AGAAGCGTCCATATGG   Human PAG            NCBITaxon:9606
# 10X221_5:TTGAACGCAGCCTTCT   Human STG            NCBITaxon:9606
# 10X385_3:CTACCCAGTGGCGCTT   Human GPi            NCBITaxon:9606
#
#                           disease_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC             PATO:0000461
# 10X362_5:TCCGTGTGTGAAAGTT             PATO:0000461
# 10X362_5:CACGGGTAGAGCAGAA             PATO:0000461
# 10X362_5:GATTCTTGTATGTCAC             PATO:0000461
# 10X362_6:AGGACTTGTATCCTTT             PATO:0000461
# ...                                            ...
# 10X194_8:GAAATGAGTTCGGCTG             PATO:0000461
# 10X350_4:TTTACCATCGCACGAC             PATO:0000461
# 10X225_1:AGAAGCGTCCATATGG             PATO:0000461
# 10X221_5:TTGAACGCAGCCTTCT             PATO:0000461
# 10X385_3:CTACCCAGTGGCGCTT             PATO:0000461
#
#                           self_reported_ethnicity_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC                           HANCESTRO:0005
# 10X362_5:TCCGTGTGTGAAAGTT                           HANCESTRO:0005
# 10X362_5:CACGGGTAGAGCAGAA                           HANCESTRO:0005
# 10X362_5:GATTCTTGTATGTCAC                           HANCESTRO:0005
# 10X362_6:AGGACTTGTATCCTTT                           HANCESTRO:0005
# ...                                                            ...
# 10X194_8:GAAATGAGTTCGGCTG                           HANCESTRO:0005
# 10X350_4:TTTACCATCGCACGAC                           HANCESTRO:0005
# 10X225_1:AGAAGCGTCCATATGG                           HANCESTRO:0005
# 10X221_5:TTGAACGCAGCCTTCT                           HANCESTRO:0005
# 10X385_3:CTACCCAGTGGCGCTT                           HANCESTRO:0005
#
#                           assay_ontology_term_id sex_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC            EFO:0009922         PATO:0000384
# 10X362_5:TCCGTGTGTGAAAGTT            EFO:0009922         PATO:0000384
# 10X362_5:CACGGGTAGAGCAGAA            EFO:0009922         PATO:0000384
# 10X362_5:GATTCTTGTATGTCAC            EFO:0009922         PATO:0000384
# 10X362_6:AGGACTTGTATCCTTT            EFO:0009922         PATO:0000384
# ...                                          ...                  ...
# 10X194_8:GAAATGAGTTCGGCTG            EFO:0009922         PATO:0000384
# 10X350_4:TTTACCATCGCACGAC            EFO:0009922         PATO:0000384
# 10X225_1:AGAAGCGTCCATATGG            EFO:0009922         PATO:0000384
# 10X221_5:TTGAACGCAGCCTTCT            EFO:0009922         PATO:0000384
# 10X385_3:CTACCCAGTGGCGCTT            EFO:0009922         PATO:0000384
#
#                           development_stage_ontology_term_id    donor_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC                     HsapDv:0000123  H19.30.002
# 10X362_5:TCCGTGTGTGAAAGTT                     HsapDv:0000136  H19.30.001
# 10X362_5:CACGGGTAGAGCAGAA                     HsapDv:0000136  H19.30.001
# 10X362_5:GATTCTTGTATGTCAC                     HsapDv:0000136  H19.30.001
# 10X362_6:AGGACTTGTATCCTTT                     HsapDv:0000136  H19.30.001
# ...                                                      ...         ...
# 10X194_8:GAAATGAGTTCGGCTG                     HsapDv:0000144  H18.30.002
# 10X350_4:TTTACCATCGCACGAC                     HsapDv:0000123  H19.30.002
# 10X225_1:AGAAGCGTCCATATGG                     HsapDv:0000144  H18.30.002
# 10X221_5:TTGAACGCAGCCTTCT                     HsapDv:0000144  H18.30.002
# 10X385_3:CTACCCAGTGGCGCTT                     HsapDv:0000123  H19.30.002
#
#                           suspension_type  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC         nucleus
# 10X362_5:TCCGTGTGTGAAAGTT         nucleus
# 10X362_5:CACGGGTAGAGCAGAA         nucleus
# 10X362_5:GATTCTTGTATGTCAC         nucleus
# 10X362_6:AGGACTTGTATCCTTT         nucleus
# ...                                   ...
# 10X194_8:GAAATGAGTTCGGCTG         nucleus
# 10X350_4:TTTACCATCGCACGAC         nucleus
# 10X225_1:AGAAGCGTCCATATGG         nucleus
# 10X221_5:TTGAACGCAGCCTTCT         nucleus
# 10X385_3:CTACCCAGTGGCGCTT         nucleus
#
#                                                                   dissection  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC  Hypothalamus (HTH) - mammillary region of HTH ...
# 10X362_5:TCCGTGTGTGAAAGTT  Hypothalamus (HTH) - mammillary region of HTH ...
# 10X362_5:CACGGGTAGAGCAGAA  Hypothalamus (HTH) - mammillary region of HTH ...
# 10X362_5:GATTCTTGTATGTCAC  Hypothalamus (HTH) - mammillary region of HTH ...
# 10X362_6:AGGACTTGTATCCTTT  Hypothalamus (HTH) - mammillary region of HTH ...
# ...                                                                      ...
# 10X194_8:GAAATGAGTTCGGCTG               Midbrain (M) - Substantia Nigra - SN
# 10X350_4:TTTACCATCGCACGAC    Cerebellum (CB) - Cerebellar deep nuclei - CbDN
# 10X225_1:AGAAGCGTCCATATGG  Midbrain (M) - Periaqueductal gray and nearby ...
# 10X221_5:TTGAACGCAGCCTTCT  Cerebral cortex (Cx) - Superior Temporal Gyrus...
# 10X385_3:CTACCCAGTGGCGCTT  Basal nuclei (BN) - Globus pallidus (GP) - Int...
#
#                            fraction_mitochondrial  fraction_unspliced  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC                0.000445            0.828378
# 10X362_5:TCCGTGTGTGAAAGTT                0.000153            0.848476
# 10X362_5:CACGGGTAGAGCAGAA                0.000000            0.801024
# 10X362_5:GATTCTTGTATGTCAC                0.000000            0.851632
# 10X362_6:AGGACTTGTATCCTTT                0.000000            0.848084
# ...                                           ...                 ...
# 10X194_8:GAAATGAGTTCGGCTG                0.027794            0.670609
# 10X350_4:TTTACCATCGCACGAC                0.003327            0.738418
# 10X225_1:AGAAGCGTCCATATGG                0.002649            0.715096
# 10X221_5:TTGAACGCAGCCTTCT                0.000370            0.699741
# 10X385_3:CTACCCAGTGGCGCTT                0.000693            0.774238
#
#                            cell_cycle_score  total_genes  total_UMIs  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC          0.001513       3100.0     11234.0
# 10X362_5:TCCGTGTGTGAAAGTT          0.002145       2303.0      6527.0
# 10X362_5:CACGGGTAGAGCAGAA          0.001280       2733.0      7031.0
# 10X362_5:GATTCTTGTATGTCAC          0.001995       4771.0     22060.0
# 10X362_6:AGGACTTGTATCCTTT          0.001936       3241.0     12915.0
# ...                                     ...          ...         ...
# 10X194_8:GAAATGAGTTCGGCTG          0.000591       1171.0      1691.0
# 10X350_4:TTTACCATCGCACGAC          0.001536       1940.0      3907.0
# 10X225_1:AGAAGCGTCCATATGG          0.001892       1563.0      2643.0
# 10X221_5:TTGAACGCAGCCTTCT          0.000370       1494.0      2701.0
# 10X385_3:CTACCCAGTGGCGCTT          0.000000        722.0      1444.0
#
#                           sample_id supercluster_term cluster_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC  10X362_3   Oligodendrocyte         50
# 10X362_5:TCCGTGTGTGAAAGTT  10X362_5   Oligodendrocyte         50
# 10X362_5:CACGGGTAGAGCAGAA  10X362_5   Oligodendrocyte         50
# 10X362_5:GATTCTTGTATGTCAC  10X362_5   Oligodendrocyte         50
# 10X362_6:AGGACTTGTATCCTTT  10X362_6   Oligodendrocyte         50
# ...                             ...               ...        ...
# 10X194_8:GAAATGAGTTCGGCTG  10X194_8         Microglia         12
# 10X350_4:TTTACCATCGCACGAC  10X350_4         Microglia         12
# 10X225_1:AGAAGCGTCCATATGG  10X225_1         Microglia         12
# 10X221_5:TTGAACGCAGCCTTCT  10X221_5         Microglia         12
# 10X385_3:CTACCCAGTGGCGCTT  10X385_3         Microglia         12
#
#                           subcluster_id cell_type_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC          2996                 CL:0000128
# 10X362_5:TCCGTGTGTGAAAGTT          2996                 CL:0000128
# 10X362_5:CACGGGTAGAGCAGAA          2996                 CL:0000128
# 10X362_5:GATTCTTGTATGTCAC          2998                 CL:0000128
# 10X362_6:AGGACTTGTATCCTTT          2996                 CL:0000128
# ...                                 ...                        ...
# 10X194_8:GAAATGAGTTCGGCTG          3264                 CL:0000878
# 10X350_4:TTTACCATCGCACGAC          3265                 CL:0000878
# 10X225_1:AGAAGCGTCCATATGG          3264                 CL:0000878
# 10X221_5:TTGAACGCAGCCTTCT          3265                 CL:0000878
# 10X385_3:CTACCCAGTGGCGCTT          3264                 CL:0000878
#
#                           tissue_ontology_term_id  is_primary_data  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC          UBERON:0001898            False
# 10X362_5:TCCGTGTGTGAAAGTT          UBERON:0001898            False
# 10X362_5:CACGGGTAGAGCAGAA          UBERON:0001898            False
# 10X362_5:GATTCTTGTATGTCAC          UBERON:0001898            False
# 10X362_6:AGGACTTGTATCCTTT          UBERON:0001898            False
# ...                                           ...              ...
# 10X194_8:GAAATGAGTTCGGCTG          UBERON:0001891            False
# 10X350_4:TTTACCATCGCACGAC          UBERON:0002037            False
# 10X225_1:AGAAGCGTCCATATGG          UBERON:0001891            False
# 10X221_5:TTGAACGCAGCCTTCT          UBERON:0000956            False
# 10X385_3:CTACCCAGTGGCGCTT          UBERON:8440012            False
#
#                                                    cell_type      assay  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC                    oligodendrocyte  10x 3' v3
# 10X362_5:TCCGTGTGTGAAAGTT                    oligodendrocyte  10x 3' v3
# 10X362_5:CACGGGTAGAGCAGAA                    oligodendrocyte  10x 3' v3
# 10X362_5:GATTCTTGTATGTCAC                    oligodendrocyte  10x 3' v3
# 10X362_6:AGGACTTGTATCCTTT                    oligodendrocyte  10x 3' v3
# ...                                                      ...        ...
# 10X194_8:GAAATGAGTTCGGCTG  central nervous system macrophage  10x 3' v3
# 10X350_4:TTTACCATCGCACGAC  central nervous system macrophage  10x 3' v3
# 10X225_1:AGAAGCGTCCATATGG  central nervous system macrophage  10x 3' v3
# 10X221_5:TTGAACGCAGCCTTCT  central nervous system macrophage  10x 3' v3
# 10X385_3:CTACCCAGTGGCGCTT  central nervous system macrophage  10x 3' v3
#
#                           disease      organism   sex           tissue  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC  normal  Homo sapiens  male     hypothalamus
# 10X362_5:TCCGTGTGTGAAAGTT  normal  Homo sapiens  male     hypothalamus
# 10X362_5:CACGGGTAGAGCAGAA  normal  Homo sapiens  male     hypothalamus
# 10X362_5:GATTCTTGTATGTCAC  normal  Homo sapiens  male     hypothalamus
# 10X362_6:AGGACTTGTATCCTTT  normal  Homo sapiens  male     hypothalamus
# ...                           ...           ...   ...              ...
# 10X194_8:GAAATGAGTTCGGCTG  normal  Homo sapiens  male         midbrain
# 10X350_4:TTTACCATCGCACGAC  normal  Homo sapiens  male       cerebellum
# 10X225_1:AGAAGCGTCCATATGG  normal  Homo sapiens  male         midbrain
# 10X221_5:TTGAACGCAGCCTTCT  normal  Homo sapiens  male  cerebral cortex
# 10X385_3:CTACCCAGTGGCGCTT  normal  Homo sapiens  male  cerebral nuclei
#
#                           self_reported_ethnicity        development_stage
# CellID
# 10X362_3:TCAGTGAGTATTGACC                European  29-year-old human stage
# 10X362_5:TCCGTGTGTGAAAGTT                European  42-year-old human stage
# 10X362_5:CACGGGTAGAGCAGAA                European  42-year-old human stage
# 10X362_5:GATTCTTGTATGTCAC                European  42-year-old human stage
# 10X362_6:AGGACTTGTATCCTTT                European  42-year-old human stage
# ...                                           ...                      ...
# 10X194_8:GAAATGAGTTCGGCTG                European  50-year-old human stage
# 10X350_4:TTTACCATCGCACGAC                European  29-year-old human stage
# 10X225_1:AGAAGCGTCCATATGG                European  50-year-old human stage
# 10X221_5:TTGAACGCAGCCTTCT                European  50-year-old human stage
# 10X385_3:CTACCCAGTGGCGCTT                European  29-year-old human stage
#
# [888263 rows x 33 columns]

# %% [markdown]
# Retrieve and read the related CAS file

# %%
if not os.path.exists(os.path.join(os.getcwd(), "CS202210140.json")):
    # Download
    request.urlretrieve("https://purl.brain-bican.org/taxonomy/CCN202210140/CS202210140_non-neuronal.json", "CS202210140.json")

cas = read_json_file("CS202210140.json")

# %% [markdown]
# Merge CAS to AnnData

# %%
anndata_obj.file.close()
merge_cas_object(cas, "/Users/hk9/tdt_datasets/Siletti_all_non_neuronal_cells.h5ad", True, "./merged.h5ad")

# %%
anndata_merged = anndata.read_h5ad("./merged.h5ad", backed="r")
anndata_merged.obs
# Out:
#                                   ROIGroup   ROIGroupCoarse     ROIGroupFine  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC     Hypothalamus     Hypothalamus     Hypothalamus
# 10X362_5:TCCGTGTGTGAAAGTT     Hypothalamus     Hypothalamus     Hypothalamus
# 10X362_5:CACGGGTAGAGCAGAA     Hypothalamus     Hypothalamus     Hypothalamus
# 10X362_5:GATTCTTGTATGTCAC     Hypothalamus     Hypothalamus     Hypothalamus
# 10X362_6:AGGACTTGTATCCTTT     Hypothalamus     Hypothalamus     Hypothalamus
# ...                                    ...              ...              ...
# 10X194_8:GAAATGAGTTCGGCTG         Midbrain         Midbrain         Midbrain
# 10X350_4:TTTACCATCGCACGAC        Hindbrain       Cerebellum       Cerebellum
# 10X225_1:AGAAGCGTCCATATGG         Midbrain         Midbrain         Midbrain
# 10X221_5:TTGAACGCAGCCTTCT  Cerebral cortex  Cerebral cortex  Cerebral cortex
# 10X385_3:CTACCCAGTGGCGCTT  Cerebral nuclei  Cerebral nuclei     Basal nuclei
#
#                                   roi organism_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC    Human MN            NCBITaxon:9606
# 10X362_5:TCCGTGTGTGAAAGTT    Human MN            NCBITaxon:9606
# 10X362_5:CACGGGTAGAGCAGAA    Human MN            NCBITaxon:9606
# 10X362_5:GATTCTTGTATGTCAC    Human MN            NCBITaxon:9606
# 10X362_6:AGGACTTGTATCCTTT    Human MN            NCBITaxon:9606
# ...                               ...                       ...
# 10X194_8:GAAATGAGTTCGGCTG    Human SN            NCBITaxon:9606
# 10X350_4:TTTACCATCGCACGAC  Human CbDN            NCBITaxon:9606
# 10X225_1:AGAAGCGTCCATATGG   Human PAG            NCBITaxon:9606
# 10X221_5:TTGAACGCAGCCTTCT   Human STG            NCBITaxon:9606
# 10X385_3:CTACCCAGTGGCGCTT   Human GPi            NCBITaxon:9606
#
#                           disease_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC             PATO:0000461
# 10X362_5:TCCGTGTGTGAAAGTT             PATO:0000461
# 10X362_5:CACGGGTAGAGCAGAA             PATO:0000461
# 10X362_5:GATTCTTGTATGTCAC             PATO:0000461
# 10X362_6:AGGACTTGTATCCTTT             PATO:0000461
# ...                                            ...
# 10X194_8:GAAATGAGTTCGGCTG             PATO:0000461
# 10X350_4:TTTACCATCGCACGAC             PATO:0000461
# 10X225_1:AGAAGCGTCCATATGG             PATO:0000461
# 10X221_5:TTGAACGCAGCCTTCT             PATO:0000461
# 10X385_3:CTACCCAGTGGCGCTT             PATO:0000461
#
#                           self_reported_ethnicity_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC                           HANCESTRO:0005
# 10X362_5:TCCGTGTGTGAAAGTT                           HANCESTRO:0005
# 10X362_5:CACGGGTAGAGCAGAA                           HANCESTRO:0005
# 10X362_5:GATTCTTGTATGTCAC                           HANCESTRO:0005
# 10X362_6:AGGACTTGTATCCTTT                           HANCESTRO:0005
# ...                                                            ...
# 10X194_8:GAAATGAGTTCGGCTG                           HANCESTRO:0005
# 10X350_4:TTTACCATCGCACGAC                           HANCESTRO:0005
# 10X225_1:AGAAGCGTCCATATGG                           HANCESTRO:0005
# 10X221_5:TTGAACGCAGCCTTCT                           HANCESTRO:0005
# 10X385_3:CTACCCAGTGGCGCTT                           HANCESTRO:0005
#
#                           assay_ontology_term_id sex_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC            EFO:0009922         PATO:0000384
# 10X362_5:TCCGTGTGTGAAAGTT            EFO:0009922         PATO:0000384
# 10X362_5:CACGGGTAGAGCAGAA            EFO:0009922         PATO:0000384
# 10X362_5:GATTCTTGTATGTCAC            EFO:0009922         PATO:0000384
# 10X362_6:AGGACTTGTATCCTTT            EFO:0009922         PATO:0000384
# ...                                          ...                  ...
# 10X194_8:GAAATGAGTTCGGCTG            EFO:0009922         PATO:0000384
# 10X350_4:TTTACCATCGCACGAC            EFO:0009922         PATO:0000384
# 10X225_1:AGAAGCGTCCATATGG            EFO:0009922         PATO:0000384
# 10X221_5:TTGAACGCAGCCTTCT            EFO:0009922         PATO:0000384
# 10X385_3:CTACCCAGTGGCGCTT            EFO:0009922         PATO:0000384
#
#                           development_stage_ontology_term_id    donor_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC                     HsapDv:0000123  H19.30.002
# 10X362_5:TCCGTGTGTGAAAGTT                     HsapDv:0000136  H19.30.001
# 10X362_5:CACGGGTAGAGCAGAA                     HsapDv:0000136  H19.30.001
# 10X362_5:GATTCTTGTATGTCAC                     HsapDv:0000136  H19.30.001
# 10X362_6:AGGACTTGTATCCTTT                     HsapDv:0000136  H19.30.001
# ...                                                      ...         ...
# 10X194_8:GAAATGAGTTCGGCTG                     HsapDv:0000144  H18.30.002
# 10X350_4:TTTACCATCGCACGAC                     HsapDv:0000123  H19.30.002
# 10X225_1:AGAAGCGTCCATATGG                     HsapDv:0000144  H18.30.002
# 10X221_5:TTGAACGCAGCCTTCT                     HsapDv:0000144  H18.30.002
# 10X385_3:CTACCCAGTGGCGCTT                     HsapDv:0000123  H19.30.002
#
#                           suspension_type  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC         nucleus
# 10X362_5:TCCGTGTGTGAAAGTT         nucleus
# 10X362_5:CACGGGTAGAGCAGAA         nucleus
# 10X362_5:GATTCTTGTATGTCAC         nucleus
# 10X362_6:AGGACTTGTATCCTTT         nucleus
# ...                                   ...
# 10X194_8:GAAATGAGTTCGGCTG         nucleus
# 10X350_4:TTTACCATCGCACGAC         nucleus
# 10X225_1:AGAAGCGTCCATATGG         nucleus
# 10X221_5:TTGAACGCAGCCTTCT         nucleus
# 10X385_3:CTACCCAGTGGCGCTT         nucleus
#
#                                                                   dissection  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC  Hypothalamus (HTH) - mammillary region of HTH ...
# 10X362_5:TCCGTGTGTGAAAGTT  Hypothalamus (HTH) - mammillary region of HTH ...
# 10X362_5:CACGGGTAGAGCAGAA  Hypothalamus (HTH) - mammillary region of HTH ...
# 10X362_5:GATTCTTGTATGTCAC  Hypothalamus (HTH) - mammillary region of HTH ...
# 10X362_6:AGGACTTGTATCCTTT  Hypothalamus (HTH) - mammillary region of HTH ...
# ...                                                                      ...
# 10X194_8:GAAATGAGTTCGGCTG               Midbrain (M) - Substantia Nigra - SN
# 10X350_4:TTTACCATCGCACGAC    Cerebellum (CB) - Cerebellar deep nuclei - CbDN
# 10X225_1:AGAAGCGTCCATATGG  Midbrain (M) - Periaqueductal gray and nearby ...
# 10X221_5:TTGAACGCAGCCTTCT  Cerebral cortex (Cx) - Superior Temporal Gyrus...
# 10X385_3:CTACCCAGTGGCGCTT  Basal nuclei (BN) - Globus pallidus (GP) - Int...
#
#                            fraction_mitochondrial  fraction_unspliced  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC                0.000445            0.828378
# 10X362_5:TCCGTGTGTGAAAGTT                0.000153            0.848476
# 10X362_5:CACGGGTAGAGCAGAA                0.000000            0.801024
# 10X362_5:GATTCTTGTATGTCAC                0.000000            0.851632
# 10X362_6:AGGACTTGTATCCTTT                0.000000            0.848084
# ...                                           ...                 ...
# 10X194_8:GAAATGAGTTCGGCTG                0.027794            0.670609
# 10X350_4:TTTACCATCGCACGAC                0.003327            0.738418
# 10X225_1:AGAAGCGTCCATATGG                0.002649            0.715096
# 10X221_5:TTGAACGCAGCCTTCT                0.000370            0.699741
# 10X385_3:CTACCCAGTGGCGCTT                0.000693            0.774238
#
#                            cell_cycle_score  total_genes  total_UMIs  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC          0.001513       3100.0     11234.0
# 10X362_5:TCCGTGTGTGAAAGTT          0.002145       2303.0      6527.0
# 10X362_5:CACGGGTAGAGCAGAA          0.001280       2733.0      7031.0
# 10X362_5:GATTCTTGTATGTCAC          0.001995       4771.0     22060.0
# 10X362_6:AGGACTTGTATCCTTT          0.001936       3241.0     12915.0
# ...                                     ...          ...         ...
# 10X194_8:GAAATGAGTTCGGCTG          0.000591       1171.0      1691.0
# 10X350_4:TTTACCATCGCACGAC          0.001536       1940.0      3907.0
# 10X225_1:AGAAGCGTCCATATGG          0.001892       1563.0      2643.0
# 10X221_5:TTGAACGCAGCCTTCT          0.000370       1494.0      2701.0
# 10X385_3:CTACCCAGTGGCGCTT          0.000000        722.0      1444.0
#
#                           sample_id supercluster_term cluster_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC  10X362_3   Oligodendrocyte         50
# 10X362_5:TCCGTGTGTGAAAGTT  10X362_5   Oligodendrocyte         50
# 10X362_5:CACGGGTAGAGCAGAA  10X362_5   Oligodendrocyte         50
# 10X362_5:GATTCTTGTATGTCAC  10X362_5   Oligodendrocyte         50
# 10X362_6:AGGACTTGTATCCTTT  10X362_6   Oligodendrocyte         50
# ...                             ...               ...        ...
# 10X194_8:GAAATGAGTTCGGCTG  10X194_8         Microglia         12
# 10X350_4:TTTACCATCGCACGAC  10X350_4         Microglia         12
# 10X225_1:AGAAGCGTCCATATGG  10X225_1         Microglia         12
# 10X221_5:TTGAACGCAGCCTTCT  10X221_5         Microglia         12
# 10X385_3:CTACCCAGTGGCGCTT  10X385_3         Microglia         12
#
#                           subcluster_id cell_type_ontology_term_id  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC          2996                 CL:0000128
# 10X362_5:TCCGTGTGTGAAAGTT          2996                 CL:0000128
# 10X362_5:CACGGGTAGAGCAGAA          2996                 CL:0000128
# 10X362_5:GATTCTTGTATGTCAC          2998                 CL:0000128
# 10X362_6:AGGACTTGTATCCTTT          2996                 CL:0000128
# ...                                 ...                        ...
# 10X194_8:GAAATGAGTTCGGCTG          3264                 CL:0000878
# 10X350_4:TTTACCATCGCACGAC          3265                 CL:0000878
# 10X225_1:AGAAGCGTCCATATGG          3264                 CL:0000878
# 10X221_5:TTGAACGCAGCCTTCT          3265                 CL:0000878
# 10X385_3:CTACCCAGTGGCGCTT          3264                 CL:0000878
#
#                           tissue_ontology_term_id  is_primary_data  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC          UBERON:0001898            False
# 10X362_5:TCCGTGTGTGAAAGTT          UBERON:0001898            False
# 10X362_5:CACGGGTAGAGCAGAA          UBERON:0001898            False
# 10X362_5:GATTCTTGTATGTCAC          UBERON:0001898            False
# 10X362_6:AGGACTTGTATCCTTT          UBERON:0001898            False
# ...                                           ...              ...
# 10X194_8:GAAATGAGTTCGGCTG          UBERON:0001891            False
# 10X350_4:TTTACCATCGCACGAC          UBERON:0002037            False
# 10X225_1:AGAAGCGTCCATATGG          UBERON:0001891            False
# 10X221_5:TTGAACGCAGCCTTCT          UBERON:0000956            False
# 10X385_3:CTACCCAGTGGCGCTT          UBERON:8440012            False
#
#                                                    cell_type      assay  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC                    oligodendrocyte  10x 3' v3
# 10X362_5:TCCGTGTGTGAAAGTT                    oligodendrocyte  10x 3' v3
# 10X362_5:CACGGGTAGAGCAGAA                    oligodendrocyte  10x 3' v3
# 10X362_5:GATTCTTGTATGTCAC                    oligodendrocyte  10x 3' v3
# 10X362_6:AGGACTTGTATCCTTT                    oligodendrocyte  10x 3' v3
# ...                                                      ...        ...
# 10X194_8:GAAATGAGTTCGGCTG  central nervous system macrophage  10x 3' v3
# 10X350_4:TTTACCATCGCACGAC  central nervous system macrophage  10x 3' v3
# 10X225_1:AGAAGCGTCCATATGG  central nervous system macrophage  10x 3' v3
# 10X221_5:TTGAACGCAGCCTTCT  central nervous system macrophage  10x 3' v3
# 10X385_3:CTACCCAGTGGCGCTT  central nervous system macrophage  10x 3' v3
#
#                           disease      organism   sex           tissue  \
# CellID
# 10X362_3:TCAGTGAGTATTGACC  normal  Homo sapiens  male     hypothalamus
# 10X362_5:TCCGTGTGTGAAAGTT  normal  Homo sapiens  male     hypothalamus
# 10X362_5:CACGGGTAGAGCAGAA  normal  Homo sapiens  male     hypothalamus
# 10X362_5:GATTCTTGTATGTCAC  normal  Homo sapiens  male     hypothalamus
# 10X362_6:AGGACTTGTATCCTTT  normal  Homo sapiens  male     hypothalamus
# ...                           ...           ...   ...              ...
# 10X194_8:GAAATGAGTTCGGCTG  normal  Homo sapiens  male         midbrain
# 10X350_4:TTTACCATCGCACGAC  normal  Homo sapiens  male       cerebellum
# 10X225_1:AGAAGCGTCCATATGG  normal  Homo sapiens  male         midbrain
# 10X221_5:TTGAACGCAGCCTTCT  normal  Homo sapiens  male  cerebral cortex
# 10X385_3:CTACCCAGTGGCGCTT  normal  Homo sapiens  male  cerebral nuclei
#
#                           self_reported_ethnicity        development_stage
# CellID
# 10X362_3:TCAGTGAGTATTGACC                European  29-year-old human stage
# 10X362_5:TCCGTGTGTGAAAGTT                European  42-year-old human stage
# 10X362_5:CACGGGTAGAGCAGAA                European  42-year-old human stage
# 10X362_5:GATTCTTGTATGTCAC                European  42-year-old human stage
# 10X362_6:AGGACTTGTATCCTTT                European  42-year-old human stage
# ...                                           ...                      ...
# 10X194_8:GAAATGAGTTCGGCTG                European  50-year-old human stage
# 10X350_4:TTTACCATCGCACGAC                European  29-year-old human stage
# 10X225_1:AGAAGCGTCCATATGG                European  50-year-old human stage
# 10X221_5:TTGAACGCAGCCTTCT                European  50-year-old human stage
# 10X385_3:CTACCCAGTGGCGCTT                European  29-year-old human stage
#
# [888263 rows x 33 columns]

# %%
anndata_merged.uns
# Out:
# {'batch_condition': array(['sample_id'], dtype=object),
#  'cas': '{"author_name": "Kimberly Siletti", "labelset": [{"name": "Cluster", "description": "", "rank": "0"}, {"name": "supercluster_term", "description": "", "rank": "1"}], "annotations": [{"labelset": "Cluster", "cell_label": "Mgl_4", "cell_set_accession": "CS202210140_5", "rationale_dois": [""], "marker_gene_evidence": [""], "synonyms": [""], "parent_cell_set_name": "Microglia", "parent_cell_set_accession": "CS202210140_464", "user_annotations": [{"labelset": "Cluster ID", "cell_label": "4"}]}, {"labelset": "Cluster", "cell_label": "Mgl_5", "cell_set_accession": "CS202210140_6", "rationale_dois": [""], "marker_gene_evidence": [""], "synonyms": [""], "parent_cell_set_name": "Microglia", "parent_cell_set_accession": "CS202210140_464", "user_annotations": [{"labelset": "Cluster ID", "cell_label": "5"}]}, {"labelset": "Cluster", "cell_label": "Mgl_6", "cell_set_accession": "CS202210140_7", "rationale_dois": [""], "marker_gene_evidence": [""], "synonyms": [""], "parent_cell_set_name": "Microglia", "parent_cell_set_accession": "CS202210140_464", "user_annotations": [{"labelset": "Cluster ID", "cell_label": "6"}]}, {"labelset": "Cluster", "cell_label": "Mgl_7", "cell_set_accession": "CS202210140_8", "rationale_dois": [""], "marker_gene_evidence": [""], "synonyms": [""], "parent_cell_set_name": "Microglia", "parent_cell_set_accession": "CS202210140_464", "user_annotations": [{"labelset": "Cluster ID", "cell_label": "7"}]}, {"labelset": "Cluster", "cell_label": "Mgl_8", "cell_set_accession": "CS202210140_9", "rationale_dois": [""], "marker_gene_evidence": [""], "synonyms": [""], "parent_cell_set_name": "Microglia", "parent_cell_set_accession": "CS202210140_464", "user_annotations": [{"labelset": "Cluster ID", "cell_label": "8"}]}, {"labelset": "Cluster", "cell_label": "Mgl_9", "cell_set_accession": "CS202210140_10", "rationale_dois": [""], "marker_gene_evidence": [""], "synonyms": [""], "parent_cell_set_name": "Microglia", "parent_cell_set_accession": "CS202210140_464", "user_annotations": [{"labelset": "Cluster ID", "cell_label": "9"}]}, {"labelset": "Cluster", "cell_label": "Mgl_10", "cell_set_accession": "CS202210140_11", "rationale_dois": [""], "marker_gene_evidence": [""], "synonyms": [""], "parent_cell_set_name": "Microglia", "parent_cell_set_accession": "CS202210140_464", "user_annotations": [{"labelset": "Cluster ID", "cell_label": "10"}]}, {"labelset": "Cluster", "cell_label": "Mgl_11", "cell_set_accession": "CS202210140_12", "rationale_dois": [""], "marker_gene_evidence": [""], "synonyms": [""], "parent_cell_set_name": "Microglia", "parent_cell_set_accession": "CS202210140_464", "user_annotations": [{"labelset": "Cluster ID", "cell_label": "11"}]}, {"labelset": "Cluster", "cell_label": "Mgl_12", "cell_set_accession": "CS202210140_13", "rationale_dois": [""], "marker_gene_evidence": [""], "synonyms": [""], "parent_cell_set_name": "Microglia", "parent_cell_set_accession": "CS202210140_464", "user_annotations": [{"labelset": "Cluster ID", "cell_label": "12"}]}, {"labelset": "Cluster", "cell_label": "VendPLVAP_13", "cell_set_accession": "CS202210140_14", "rationale_dois": [""], "marker_gene_evidence": [""], "synonyms": [""], "parent_cell_set_name": "Vascular", "parent_cell_set_accession": "CS202210140_465", "user_annotations": [{"labelset": "Cluster ID", "cell_label": "13"}]}, {"labelset": "Cluster", "cell_label": "VendAC_14", "cell_set_accession": "CS202210140_15", "rationale_dois": [""], "marker_gene_evidence": [""], "synonyms": [""], "parent_cell_set_name": "Vascular", "parent_cell_set_accession": "CS202210140_465", "user_annotations": [{"labelset": "Cluster ID", "cell_label": "14"}]}, {"labelset": "Cluster", "cell_label": "VendC_15", "cell_set_accession": "CS202210140_16", "cell_ontology_term_id": "CL:0002144", "cell_ontology_term": "capillary endothelial cell", "rationale": "BMX = large artery", "rationale_dois": [""], "marker_gene_evidence": ["FLT1", "CLDN5", "PECAM1", "MFSD2A"], "synonyms": [""], "parent_cell_set_name" ...
#  'schema_version': '3.1.0',
#  'title': 'All non-neuronal cells'}

# %% [markdown]
# Read CAS from AnnData `uns`

# %%
cas_read = read_cas_from_anndata("./merged.h5ad")
df = cas_read.get_all_annotations()
df
# Out:
#              labelset       cell_label cell_set_accession cell_fullname  \
# 0             Cluster            Mgl_4      CS202210140_5          None
# 1             Cluster            Mgl_5      CS202210140_6          None
# 2             Cluster            Mgl_6      CS202210140_7          None
# 3             Cluster            Mgl_7      CS202210140_8          None
# 4             Cluster            Mgl_8      CS202210140_9          None
# ..                ...              ...                ...           ...
# 84  supercluster_term  Oligodendrocyte    CS202210140_469          None
# 85  supercluster_term        Astrocyte    CS202210140_470          None
# 86  supercluster_term        Ependymal    CS202210140_471          None
# 87  supercluster_term   Choroid plexus    CS202210140_472          None
# 88  supercluster_term    Bergmann glia    CS202210140_493          None
#
#    cell_ontology_term_id              cell_ontology_term  \
# 0                   None                            None
# 1                   None                            None
# 2                   None                            None
# 3                   None                            None
# 4                   None                            None
# ..                   ...                             ...
# 84            CL:0000128                 oligodendrocyte
# 85            CL:0000127                       astrocyte
# 86            CL:0000065                  ependymal cell
# 87            CL:0000706  choroid plexus epithelial cell
# 88            CL:0000644             Bergmann glial cell
#
#                                             rationale  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 84  Supported by marker expression and annotation ...
# 85  Supported by marker expression and annotation ...
# 86                                               None
# 87                                               None
# 88  GDF10 marks Bergmann glia in the mouse Other m...
#
#                    rationale_dois               marker_gene_evidence synonyms  \
# 0                              []                                 []       []
# 1                              []                                 []       []
# 2                              []                                 []       []
# 3                              []                                 []       []
# 4                              []                                 []       []
# ..                            ...                                ...      ...
# 84  [DOI:10.1126/science.adf6812]                      [SOX10, PLP1]       []
# 85  [DOI:10.1126/science.adf6812]                             [AQP4]       []
# 86                             []                            [FOXJ1]       []
# 87                             []                       [FOXJ1, TTR]       []
# 88                             []  [AQP4, GDF10, GABRG3, WIF1, LGR6]       []
#
#    parent_cell_set_name parent_cell_set_accession  \
# 0             Microglia           CS202210140_464
# 1             Microglia           CS202210140_464
# 2             Microglia           CS202210140_464
# 3             Microglia           CS202210140_464
# 4             Microglia           CS202210140_464
# ..                  ...                       ...
# 84                 None                      None
# 85                 None                      None
# 86                 None                      None
# 87                 None                      None
# 88                 None                      None
#
#                                      user_annotations transferred_annotations
# 0     [{'labelset': 'Cluster ID', 'cell_label': '4'}]                    None
# 1     [{'labelset': 'Cluster ID', 'cell_label': '5'}]                    None
# 2     [{'labelset': 'Cluster ID', 'cell_label': '6'}]                    None
# 3     [{'labelset': 'Cluster ID', 'cell_label': '7'}]                    None
# 4     [{'labelset': 'Cluster ID', 'cell_label': '8'}]                    None
# ..                                                ...                     ...
# 84  [{'labelset': 'Cluster ID', 'cell_label': 'Non...                    None
# 85  [{'labelset': 'Cluster ID', 'cell_label': 'Non...                    None
# 86  [{'labelset': 'Cluster ID', 'cell_label': 'Non...                    None
# 87  [{'labelset': 'Cluster ID', 'cell_label': 'Non...                    None
# 88  [{'labelset': 'Cluster ID', 'cell_label': 'Non...                    None
#
# [89 rows x 14 columns]
