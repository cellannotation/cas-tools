# %% [markdown]
# # Installing Required Packages

# %%
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install anndata
# !{sys.executable} -m pip install cas-tools

# %%
import pandas as pd
import anndata as ad

# %% [markdown]
# # Checking content of PBMC spreadsheet

# %%
# File and sheet details
file_path = "data/blood.xlsx"
sheet_name = "PBMC3_Yoshida_2022_PBMC"

# Read metadata (rows 1-12)
metadata_df = pd.read_excel(file_path, sheet_name=sheet_name, skiprows=0, nrows=12)

# Read data (rows 13 to end)
data_df = pd.read_excel(file_path, sheet_name=sheet_name, skiprows=13)

# %%
metadata_df
# Out:
#                    #rationale_dois  \
# 0                     #author_name
# 1                           #orcid
# 2                     #author_list
# 3                 #PATH TO DATASET
# 4                        #HCA LINK
# 5                  #matrix_file_id
# 6                        #CAP LINK
# 7            #MANUAL / ALGORITHMIC
# 8               #OTHER INFORMATION
# 9                       #COMMENTS
# 10         #cellannotation_version
# 11  #cellannotation_schema_version
#
#            https://doi.org/10.1038/s41586-021-04345-x
# 0                                    Masahiro Yoshida
# 1               https://orcid.org/0000-0002-3521-5322
# 2      Kaylee B. Worlock|Ni Huang|Rik G. H. Lindeboom
# 3   /home/cap/pbmcBioNetwork/PBMC3_Yoshida/PBMC3_Y...
# 4                                                 NaN
# 5   https://cellxgene.cziscience.com/e/2a498ace-87...
# 6                                                 NaN
# 7   The manual blood cell type annotation was vali...
# 8   Fig 3d - marker genes, Extended Data Fig. 2c -...
# 9                       Need synonyms and categories
# 10                                              3.1.0
# 11                                              0.20b

# %%
data_df
# Out:
#              labelset                                         cell_label  \
# 0           cell_type                                Classical monocyte
# 1           cell_type                         CD4-positive helper T cell
# 2           cell_type  Naive thymus-derived CD8-positive, alpha-beta ...
# 3           cell_type  Naive thymus-derived CD4-positive, alpha-beta ...
# 4           cell_type     Central memory CD8-positive, alpha-beta T cell
# ..                ...                                                ...
# 97   annotation_broad                                             Plasma
# 98   annotation_broad                                             Plasma
# 99   annotation_broad                                                 DC
# 100  annotation_broad                                           Baso/Eos
# 101  annotation_broad                                                RBC
#
#                    marker_gene_evidence  \
# 0       CD4, SELL, FCER1G, CD14, PLSCR1
# 1                 CD3D, CD4, CD27, IL7R
# 2    CD3D, CD8A, CCR7, CD27, SELL, IL7R
# 3     CD3D, CD4, CCR7, CD27, SELL, IL7R
# 4                CD3D, CD8A, CD27, IL7R
# ..                                  ...
# 97                                  NaN
# 98                                  NaN
# 99                                  NaN
# 100                                 NaN
# 101                                 NaN
#
#                         SURFACE PROTEIN MARKERS BCR / TCR  SYNONYMS  \
# 0                                          CD14       NaN       NaN
# 1           CD3D, CD4, CD27, SELL, IL7R, CD45RO       TCR       NaN
# 2    CD3D, CD8A, CCR7, CD27, SELL, IL7R, CD45RA       TCR       NaN
# 3             CD3D, CD4, CCR7, CD27, SELL, IL7R       TCR       NaN
# 4                CD3D, CD8A, CD27, IL7R, CD45RO       TCR       NaN
# ..                                          ...       ...       ...
# 97                                          NaN       NaN       NaN
# 98                                          NaN       NaN       NaN
# 99                                          NaN       NaN       NaN
# 100                                         NaN       NaN       NaN
# 101                                         NaN       NaN       NaN
#
#      CATEGORIES  EVIDENCE
# 0           NaN       NaN
# 1           NaN       NaN
# 2           NaN       NaN
# 3           NaN       NaN
# 4           NaN       NaN
# ..          ...       ...
# 97          NaN       NaN
# 98          NaN       NaN
# 99          NaN       NaN
# 100         NaN       NaN
# 101         NaN       NaN
#
# [102 rows x 8 columns]

# %% [markdown]
# # Spreadsheet to CAS Conversion
#
# In this example, we use the [PBMC dataset](https://cellxgene.cziscience.com/e/2a498ace-872a-4935-984b-1afa70fd9886.cxg/).
#
# ## Command-line Arguments:
#
# - `--spreadsheet`: Path to the spreadsheet file.
# - `--sheet`: Target sheet name in the spreadsheet.
# - `--anndata`: Path to the AnnData file. If not provided, AnnData will be downloaded using CxG LINK in the spreadsheet.
# - `--labelsets`: List to determine the rank of labelsets in the spreadsheet. If not provided, ranks will be determined using the order of CELL LABELSET NAME.
# - `--output`: Output CAS file name (default: output.json).
#
# ## Usage Example:
#
# Navigate to the source directory and run the following command:
#
# ```bash
# python -m cas spreadsheet2cas --spreadsheet path/to/spreadsheet.xlsx --sheet sheet_name --labelsets item1 item2 item3 --output path/to/output_file.json
# ```
#
# ## Current Arguments
#
# - spreadsheet: "data/blood.xlsx"
# - anndata: "2a498ace-872a-4935-984b-1afa70fd9886.h5ad"
# - output: "output/blood_cas.json"

# %%
# Use this command if the file has not already been downloaded into the notebooks directory.
# The CLI will download it automatically, but the process will take longer as it includes the download step.
# !cas spreadsheet2cas --spreadsheet data/blood.xlsx  --labelsets annotation_detailed_fullNames annotation_broad --output output/pbmc_cas.json

# %%
# !cas spreadsheet2cas --spreadsheet data/blood.xlsx --anndata 2a498ace-872a-4935-984b-1afa70fd9886.h5ad  --labelsets annotation_detailed_fullNames annotation_broad --output output/pbmc_cas.json

# %% [markdown]
# # Check the content of cas json file

# %%
import json

with open("output/pbmc_cas.json", "r") as f:
    cas = json.load(f)

# %%
cas["labelsets"]
# Out:
# [{'name': 'annotation_detailed_fullNames', 'description': '', 'rank': '0'},
#  {'name': 'annotation_broad', 'description': '', 'rank': '1'}]

# %%
cas["annotations"][:5]
# Out:
# [{'labelset': 'annotation_detailed_fullNames',
#   'cell_label': 'Classical monocyte',
#   'marker_gene_evidence': ['CD4', ' SELL', ' FCER1G', ' CD14', ' PLSCR1'],
#   'cell_ids': ['CV001_KM10202384-CV001_KM10202394_AAAGCAAAGGGTCTCC-1',
#    'S12_TTGACTTCACCTCGTT-1',
#    'S20_GACGTTATCCCTAACC-1',
#    'S14_TACTCATTCCAAACAC-1',
#    'S13_CTGATAGCAAAGGCGT-1',
#    'S12_GTTCGGGCAGCCAGAA-1',
#    'S12_CGAGAAGCAAGACACG-1',
#    'CV001_KM10202404-CV001_KM10202416_GTTTCTACACCAGGTC-1',
#    'CV001_KM10202384-CV001_KM10202394_CGTTGGGTCAGGCCCA-1',
#    'CV001_KM10202390-CV001_KM10202400_CGAGCACCAAGCCATT-1',
#    'S23_TCGCGTTTCAAGGTAA-1',
#    'S14_TCACAAGGTGCCTGTG-1',
#    'CV001_KM10202406-CV001_KM10202418_TCATTACAGACTAGAT-1',
#    'S24_TTGAACGGTAAAGTCA-1',
#    'CV001_KM10202407-CV001_KM10202419_GATCTAGAGACTTGAA-1',
#    'S19_TGCCAAACAATCGAAA-1',
#    'S23_GAATAAGTCGGTGTCG-1',
#    'S14_GACTACACAAGAGGCT-1',
#    'S24_GTCCTCAGTAGAGTGC-1',
#    'CV001_KM10202389-CV001_KM10202399_GCAGTTATCGGATGTT-1',
#    'S16_GCAGCCATCTTCGGTC-1',
#    'S23_CACCACTGTTAGTGGG-1',
#    'CV001_KM10202407-CV001_KM10202419_GGCGACTGTTATCGGT-1',
#    'S17_TTGACTTGTCCGTTAA-1',
#    'S19_CTGAAACAGCTGCAAG-1',
#    'CV001_KM10202386-CV001_KM10202396_CCTCAGTCAGGGATTG-1',
#    'S14_TCATTACTCAGATAAG-1',
#    'S18_GGAGCAAGTGCAACTT-1',
#    'CV001_KM10202405-CV001_KM10202417_GGGAATGAGAGAGCTC-1',
#    'S10_TGTGTTTGTTCCCGAG-1',
#    'S12_CTCGGAGAGTACGTTC-1',
#    'S11_TTGCCGTAGTACACCT-1',
#    'CV001_KM10202388-CV001_KM10202398_TTCTCAATCTAACTTC-1',
#    'S11_TTTCCTCGTTAGGGTG-1',
#    'S19_TTTGTCAGTAGATTAG-1',
#    'S23_TTAGTTCCAAACCTAC-1',
#    'S28_TATGCCCCACAGAGGT-1',
#    'CV001_KM10202385-CV001_KM10202395_CTCGTACCATAACCTG-1',
#    'S16_TTCTCCTCATCACCCT-1',
#    'S19_CCAGCGAGTAGAGCTG-1',
#    'S24_GGGAGATAGCTGAAAT-1',
#    'S24_CACATAGAGTGACATA-1',
#    'S14_GACACGCAGCTGCCCA-1',
#    'S12_ATTATCCGTCACACGC-1',
#    'CV001_KM10202405-CV001_KM10202417_AGAGCGACATTAACCG-1',
#    'S13_TTGAACGTCGAACTGT-1',
#    'CV001_KM10202387-CV001_KM10202397_GCGGGTTTCACTTATC-1',
#    'S25_CCTCTGATCTTGTCAT-1',
#    'S3_CTAACTTCAGCGTCCA-1',
#    'S3_ACGAGCCCAATGGAGC-1',
#    'S5_GATCGTACATTCCTCG-1',
#    'CV001_KM10202388-CV001_KM10202398_CGTAGCGAGTGAACAT-1',
#    'S4_TTTCCTCCACCATCCT-1',
#    'S14_CCTACACTCAACGCTA-1',
#    'S23_CGATGTAAGGCAAAGA-1',
#    'S11_GGAGCAAGTCACCTAA-1',
#    'CV001_KM10202405-CV001_KM10202417_CATCAAGTCCGCATCT-1',
#    'S3_CTGAAGTTCGCCGTGA-1',
#    'S4_GCGAGAATCTGCGACG-1',
#    'S15_CACACAATCATCACCC-1',
#    'S16_GAAGCAGGTGAACCTT-1',
#    'S17_ATTTCTGGTAACGACG-1',
#    'S28_ACTGTCCCAAGTCATC-1',
#    'S24_CCTTCCCCAAGGGTCA-1',
#    'S27_GCTGCGACACCTCGGA-1',
#    'S14_CAGTAACCAACGCACC-1',
#    'S21_ACGGGTCGTAACGACG-1',
#    'CV001_KM10202387-CV001_KM10202397_ACGTCAATCTTGACGA-1',
#    'S4_GCCAAATGTCTGCCAG-1',
#    'S18_CTCGGAGAGAAACGAG-1',
#    'S27_AGCTTGATCACGAAGG-1',
#    'S7_CAGAGAGAGCGTTGCC-1',
#    'S20_CACTCCAGTGTAAGTA-1',
#    'S10_CTGTTTATCTGGAGCC-1',
#    'CV001_KM10202406-CV001_KM10202418_GCGACCAAGGGAAACA-1',
#    'CV001_KM10202406-CV001_KM10202418_TGCGCAGTCTATGTGG-1',
#    'S11_CTGATAGCATTCCTGC-1',
#    'CV001_KM10202404-CV001_KM10202416_AGTGAGGCACAGAGGT-1',
#    'S13_TAGCCGGCAGTCGTGC-1',
#    'S18_TGGTTAGGTCATCCCT-1',
#    'S24_CCACTACGTAGCAAAT-1',
#    'S23_AGTTGGTGTCAGCTAT-1',
#    'CV001_KM10202388-CV001_KM10202398_CGTCAGGTCCGAACGC-1',
#    'S19_CTGCCTACACAGGAGT-1',
#    'S17_ATCATCTTCGGCATCG-1',
#    'S1_TTGGAACGTAAGTGTA-1',
#    'CV001_KM10202390-CV001_KM10202400_CCTAAAGGTACCGTAT-1',
#    'S15_CTGATAGAGGCACATG-1',
#    'S2_TTGCCGTCAGATCTGT-1',
#    'CV001_KM10202388-CV001_KM10202398_GGAATAAGTCCGCTGA-1',
#    'CV001_KM10202389-CV001_KM10202399_AACCATGAGGCATGGT-1',
#    'S23_GAACCTATCCACTGGG-1',
#    'S12_CAAGATCAGTTAGCGG-1',
#    'S13_CTAAGACGTATCACCA-1',
#    'CV001_KM10202387-CV001_KM10202397_CAACTAGGTAAGCACG-1',
#    'S4_GTAACTGCATGGTAGG-1',
#    'S23_CGATTGATCTTAACCT-1',
#    'S3_GGATTACGTATTCGTG-1',
#    'S8_CCCAATCTCAACACTG-1',
#    'CV001_KM10202405-CV001_KM10202417_AGATTGCGTAAGGATT-1',
#    'S11_GCGACCAGTGTTCGAT-1',
#    'S15_GGAAAGCCAAGTAATG-1',
#    'S17_ATGGGAGAGACAGAGA-1',
#    'S5_CGTGTCTCAATGTAAG-1',
#    'S19_TCGTAGATCTCGTTTA-1',
#    'CV001_KM10202387-CV001_KM10202397_TAAGTGCAGTACGCGA-1',
#    'S17_AGGTCATGTCGGATCC-1',
#    'S17_CTACATTCATTTGCCC-1',
#    'CV001_KM10202385-CV001_KM10202395_CGACTTCGTGTTCTTT-1',
#    'S19_TATCTCAAGTGAAGTT-1',
#    'S19_GGGAATGGTTCCACAA-1',
#    'S17_GTATCTTTCTGGTTCC-1',
#    'S12_TTGGCAAAGACTCGGA-1',
#    'S25_TACAGTGAGAGTGAGA-1',
#    'S4_CTCGGGACATCAGTAC-1',
#    'S19_ACGGAGACATCGTCGG-1',
#    'S4_CCATGTCTCACCTCGT-1',
#    'S20_TGCGTGGTCATAACCG-1',
#    'CV001_KM10202384-CV001_KM10202394_TAAGAGAAGGGCTCTC-1',
#    'S12_GTTCTCGTCGTTTGCC-1',
#    'S24_CTGCCTACATGGATGG-1',
#    'S28_CAACCAAGTCGAGTTT-1',
#    'S7_CTCGAGGGTGTGGTTT-1',
#    'S5_GCAGTTAAGCTACCGC-1',
#    'CV001_KM10202386-CV001_KM10202396_TAAGTGCCAGTTAACC-1',
#    'S5_TGCGCAGGTGTCTGAT-1',
#    'CV001_KM10202386-CV001_KM10202396_CTAGCCTGTACTCTCC-1',
#    'S11_GTGTGCGTCTCCAGGG-1',
#    'S13_TTGGCAAAGTAGCCGA-1',
#    'S3_CTCGGGATCTGAGGGA-1',
#    'S27_GCTGCGATCTCAAGTG-1',
#    'S19_GCTGCGAAGTTACGGG-1',
#    'CV001_KM10202388-CV001_KM10202398_ACAGCCGAGGTGCACA-1',
#    'CV001_KM10202388-CV001_KM10202398_AGGCCGTCATCGGACC-1',
#    'S21_GCATGATGTAAGAGGA-1',
#    'S27_GCGGGTTAGCCATCGC-1',
#    'CV001_KM10202406-CV001_KM10202418_TGTGTTTCAAACCCAT-1',
#    'S4_CGTCACTTCATATCGG-1',
#    'CV001_KM10202405-CV001_KM10202417_ACCTTTAGTTGCTCCT-1',
#    'S1_TAAACCGAGTGCAAGC-1',
#    'S16_GCGCAACTCTGCCAGG-1',
#    'CV001_KM10202384-CV001_KM10202394_GACTGCGCAGATGAGC-1',
#    'S17_TAGTTGGAGAGCTTCT-1',
#    'CV001_KM10202385-CV001_KM10202395_TGCGTGGCAGGACCCT-1',
#    'S2_AACCATGAGACCACGA-1',
#    'CV001_KM10202407-CV001_KM10202419_GGACAAGAGCGCCTTG-1',
#    'S3_AGATCTGCACGTGAGA-1',
#    'S3_GCACATATCTGCTGTC-1',
#    'S15_CGTTCTGAGCAGCCTC-1',
#    'S16_CGATCGGTCGGCTTGG-1',
#    'S20_TTGGCAACACGGTAAG-1',
#    'S27_GTCCTCAGTGTATGGG-1',
#    'CV001_KM10202387-CV001_KM10202397_GCATGCGAGACAATAC-1',
#    'CV001_KM10202405-CV001_KM10202417_CGATGTAGTTCGCGAC-1',
#    'S19_CGATCGGCAAACTGTC-1',
#    'S12_AACCATGTCTCGCTTG-1',
#    'S3_GGACGTCGTCTAAACC-1',
#    'S21_GGTGAAGGTTATCCGA-1',
#    'S3_TGTGTTTGTAGTACCT-1',
#    'S6_CTCGTACGTAACGACG-1',
#    'CV001_KM10202391-CV001_KM10202401_CCGGTAGCAGGATTGG-1',
#    'CV001_KM10202407-CV001_KM10202419_GTACTCCTCGCGTAGC-1',
#    'S27_CTTAACTGTCTCCCTA-1',
#    'S4_CATCAAGGTTCCACGG-1',
#    'S17_CTAAGACTCTTAACCT-1',
#    'CV001_KM10202390-CV001_KM10202400_GGGCATCGTTACCAGT-1',
#    'CV001_KM10202404-CV001_KM10202416_GCGCAGTAGCGCTTAT-1',
#    'CV001_KM10202388-CV001_KM10202398_TCAGGATAGAAGCCCA-1',
#    'S24_CATCCACTCGCTGATA-1',
#    'S24_GTCAAGTTCTTTACAC-1',
#    'S15_GTGCGGTTCCTGCCAT-1',
#    'S23_GACAGAGTCGCGCCAA-1',
#    'S17_TGAGAGGAGTGTACTC-1',
#    'S3_CAGCTAAAGGACATTA-1',
#    'S4_GTGTTAGCATGTAGTC-1',
#    'S23_CCACTACAGATGGGTC-1',
#    'CV001_KM10202391-CV001_KM10202401_CATCGAACAAGTACCT-1',
#    'CV001_KM10202405-CV001_KM10202417_GGCTCGAGTCTAGTCA-1',
#    'S3_TTAGGCAGTGCTTCTC-1',
#    'CV001_KM10202388-CV001_KM10202398_ATTATCCGTTCGGCAC-1',
#    'S2_TAGGCATTCTCGTATT-1',
#    'S5_CGTAGCGAGTGAACGC-1',
#    'S27_AGAGCTTCACCGAATT-1',
#    'S27_AGCAGCCGTTCAGGCC-1',
#    'S14_GCTGGGTCACATCCAA-1',
#    'S27_TGATTTCTCTCCAACC-1',
#    'S11_ACGGGTCTCGAGGTAG-1',
#    'S3_CCTATTACATCTCGCT-1',
#    'CV001_KM10202389-CV001_KM10202399_AGTGTCATCAAGCCTA-1',
#    'S19_ACGGGCTAGCGATTCT-1',
#    'S11_CACATAGGTTTGTTGG-1',
#    'S11_AGTGGGATCTACCTGC-1',
#    'S9_GAGTCCGTCTGACCTC-1',
#    'S11_TGGACGCCACGAAATA-1',
#    'S1_TGAGGGAGTGATGATA-1',
#    'S12_GCGAGAAGTCAACTGT-1',
#    'S14_CCCTCCTTCCTTTACA-1',
#    'CV001_KM10202387-CV001_KM10202397_GCCAAATTCTTTAGGG-1',
#    'S2_TTCGGTCAGCAATCTC-1',
#    'CV001_KM10202388-CV001_KM10202398_CGGACGTAGGCCCTTG-1',
#    'S11_CGATTGAAGGATGGAA-1',
#    'CV001_KM10202404-CV001_KM10202416_AGCGTATCACGCATCG-1',
#    'S24_AAGGCAGGTGTGGTTT-1',
#    'S24_TTGACTTTCCAAATGC-1',
#    'CV001_KM10202389-CV001_KM10202399_GTTCATTCACAAGTAA-1',
#    'S27_TGCGGGTAGGGAACGG-1',
#    'S18_CACAGGCTCATAAAGG-1',
#    'S10_GACGCGTCATCCCATC-1',
#    'S18_AACTGGTCATCTCGCT-1',
#    'S28_CACCACTCAAGTACCT-1',
#    'S14_AGTGTCAAGGCACATG-1',
#    'S11_GCTGCAGTCAGCTGGC-1',
#    'CV001_KM10202406-CV001_KM10202418_CGTGTCTTCGTCACGG-1',
#    'S21_GAACATCAGTCTCAAC-1',
#    'CV001_KM10202385-CV001_KM10202395_AGTGAGGCAGAAGCAC-1',
#    'CV001_KM10202388-CV001_KM10202398_CCGGTAGTCACGCGGT-1',
#    'S22_CCGTACTGTGGTAACG-1',
#    'S25_GCGCAACGTTGTTTGG-1',
#    'S2_TCTCTAACACACTGCG-1',
#    'S24_TTCTTAGTCACTGGGC-1',
#    'S20_CAAGTTGTCACCGGGT-1',
#    'CV001_KM10202387-CV001_KM10202397_CGATCGGTCGGTGTCG-1',
#    'S23_ATTGGACCAGATTGCT-1',
#    'S16_GGGAATGTCCAAAGTC-1',
#    'S3_AGGTCCGTCAATAAGG-1',
#    'S11_CCTCTGATCAGGTAAA-1',
#    'S15_GCTGCGACATCTGGTA-1',
#    'S27_CAACCAAAGGTTCCTA-1',
#    'S19_CGGTTAAGTGTTCTTT-1',
#    'CV001_KM10202406-CV001_KM10202418_CCACCTAGTGAAATCA-1',
#    'S23_CTCGTCATCCAGAGGA-1',
#    'CV001_KM10202388-CV001_KM10202398_TCTATTGTCATGCATG-1',
#    'S11_GTAGGCCCAACACCTA-1',
#    'S2_CGTGTAACACGTCAGC-1',
#    'S18_CGGTTAAAGGAGTTGC-1',
#    'S2_AACACGTTCCCAAGAT-1',
#    'S11_GCGACCATCTTGACGA-1',
#    'CV001_KM10202405-CV001_KM10202417_CAACTAGCAGACAAGC-1',
#    'S27_CCTTCCCGTACGAAAT-1',
#    'CV001_KM10202406-CV001_KM10202418_GAAACTCGTTGTTTGG-1',
#    'S24_AACACGTGTTAAGAAC-1',
#    'S3_CCTTCCCCAGGTGCCT-1',
#    'CV001_KM10202405-CV001_KM10202417_GGGTCTGTCCTAGTGA-1',
#    'S2_AGATCTGAGTTGTAGA-1',
#    'CV001_KM10202404-CV001_KM10202416_CCATGTCTCCATGAGT-1',
#    'CV001_KM10202407-CV001_KM10202419_CACACAAGTAGTACCT-1',
#    'S22_CAAGATCCATTGAGCT-1',
#    'S19_TTATGCTAGGCCATAG-1',
#    'S14_CGATGGCTCCGAGCCA-1',
#    'S4_GGGTCTGAGTGTTAGA-1',
#    'S17_ACGGCCACAGCAGTTT-1',
#    'S22_GGCGACTGTCACCCAG-1',
#    'S12_CAGTAACGTGTGCGTC-1',
#    'S4_ACCTTTAGTAGCGATG-1',
#    'S3_GGAAAGCCACATCCGG-1',
#    'CV001_KM10202389-CV001_KM10202399_TTAGTTCCAGTAAGCG-1',
#    'S4_TTTCCTCAGGCAATTA-1',
#    'S13_TTCGAAGTCGCTTAGA-1',
#    'S14_CGTTGGGTCGAGAACG-1',
#    'S28_TTAGGACCACACAGAG-1',
#    'S20_CTCGTACAGTGGGTTG-1',
#    'CV001_KM10202384-CV001_KM10202394_GATCAGTAGTTGAGAT-1',
#    'CV001_KM10202388-CV001_KM10202398_TGAGCATTCACAGTAC-1',
#    'S2_ATGCGATGTCCGCTGA-1',
#    'CV001_KM10202387-CV001_KM10202397_CTACACCAGTTGTCGT-1',
#    'S24_GAATAAGGTGCAGTAG-1',
#    'S24_GCTCCTATCACCGGGT-1',
#    'S11_TGCCCATAGATATGCA-1',
#    'S11_ACATCAGTCTCTTATG-1',
#    'S18_TCTCTAAGTTACGCGC-1',
#    'S14_ACGCCAGCACGAAACG-1',
#    'CV001_KM10202385-CV001_KM10202395_CAGATCACAGCGAACA-1',
#    'S3_TACCTTAGTTCTCATT-1',
#    'S10_CTACATTAGGATGTAT-1',
#    'S14_GGCGACTGTTATCACG-1',
#    'S24_TCCCGATGTTCATGGT-1',
#    'CV001_KM10202389-CV001_KM10202399_TCAGCTCTCTGCTTGC-1',
#    'CV001_KM10202385-CV001_KM10202395_TCTGAGAGTACCTACA-1',
#    'S17_CGTGTCTTCGGAGCAA-1',
#    'S24_TTAGGCAAGGCTAGGT-1',
#    'CV001_KM10202386-CV001_KM10202396_AACCATGGTCGAAAGC-1',
#    'S1_GAGGTGAGTGGCGAAT-1',
#    'S12_ATCATGGTCAACGGGA-1',
#    'S4_GACTACACACCCAGTG-1',
#    'S23_GAAATGAGTTTGGCGC-1',
#    'S4_TCATTACCATGTCTCC-1',
#    'CV001_KM10202385-CV001_KM10202395_GTGTGCGGTAAGAGAG-1',
#    'S13_CATCCACAGACAGAGA-1',
#    'CV001_KM10202404-CV001_KM10202416_ATGAGGGTCTTATCTG-1',
#    'CV001_KM10202406-CV001_KM10202418_GACGGCTAGACTAGAT-1',
#    'S23_TCAGCAAGTCATATCG-1',
#    'S23_GTGCTTCGTCAGCTAT-1',
#    'S12_TCAGCAATCCTGCCAT-1',
#    'S14_TTCTCAATCGGATGGA-1',
#    'CV001_KM10202388-CV001_KM10202398_AAGGCAGGTGCGCTTG-1',
#    'S27_CGAGCCACACGTCTCT-1',
#    'S21_CACCAGGGTACGCTGC-1',
#    'S19_AGCGTATCAGTAGAGC-1',
#    'S18_GACCAATCATGAAGTA-1',
#    'S4_CTGTGCTGTCGCTTTC-1',
#    'CV001_KM10202385-CV001_KM10202395_CATATGGGTCTCTCTG-1',
#    'CV001_KM10202387-CV001_KM10202397_TGTGTTTGTGGCAAAC-1',
#    'S4_AGCCTAACATATGGTC-1',
#    'S13_GCTGCGAGTTATCACG-1',
#    'CV001_KM10202404-CV001_KM10202416_CTCTAATTCAAGCCTA-1',
#    'S28_GATGAAAAGTGCGTGA-1',
#    'CV001_KM10202404-CV001_KM10202416_CTGCGGATCAATACCG-1',
#    'S3_GTTAAGCCAATGAAAC-1',
#    'S2_GCGCCAAGTCTTGATG-1',
#    'S16_TGACAACAGCGCCTCA-1',
#    'S12_AGCTCTCGTCTAAAGA-1',
#    'S24_ACGGCCAAGCTCCCAG-1',
#    'CV001_KM10202388-CV001_KM10202398_GCTGGGTAGAGATGAG-1',
#    'CV001_KM10202406-CV001_KM10202418_AACCGCGAGGTGATTA-1',
#    'S24_GCGAGAAGTGGCCCTA-1',
#    'CV001_KM10202384-CV001_KM10202394_CCTACACCAAACGTGG-1',
#    'CV001_KM10202389-CV001_KM10202399_AGAATAGAGCAATCTC-1',
#    'S24_AGGCCACAGTGACATA-1',
#    'S28_TGATTTCAGCTAGCCC-1',
#    'S6_GGCCGATGTTCGCTAA-1',
#    'CV001_KM10202388-CV001_KM10202398_CTACATTAGGGTGTTG-1',
#    'S17_TTGAACGAGGATGGAA-1',
#    'S11_GTAGGCCGTGTAATGA-1',
#    'S16_GCTGCTTCAAGTAGTA-1',
#    'S24_GGGTCTGTCTTCTGGC-1',
#    'S14_ATTACTCGTTGGACCC-1',
#    'CV001_KM10202385-CV001_KM10202395_CTGTTTAAGGCATGTG-1',
#    'CV001_KM10202389-CV001_KM10202399_GTAGGCCCATGACATC-1',
#    'S20_CGCTGGAGTGTTCTTT-1',
#    'S27_TCAGGATAGGACTGGT-1',
#    'S4_CAAGTTGCACATCCGG-1',
#    'S19_ACCCACTCATCCGCGA-1',
#    'S24_CCTAAAGTCGAACTGT-1',
#    'S2_TGCTACCCATTACGAC-1',
#    'CV001_KM10202385-CV001_KM10202395_TCACGAAGTGCCTGGT-1',
#    'S1_GCGCAACGTACCGGCT-1',
#    'S28_GTGTTAGAGTAGATGT-1',
#    'CV001_KM10202389-CV001_KM10202399_CGCGTTTAGATGCGAC-1',
#    'CV001_KM10202384-CV001_KM10202394_GTGAAGGTCACCAGGC-1',
#    'CV001_KM10202405-CV001_KM10202417_ATCCACCTCGATGAGG-1',
#    'S3_AGGGTGACATATACCG-1',
#    'S4_CCCAGTTTCTCCAACC-1',
#    'S16_GTACTTTCAGCTGCAC-1',
#    'S17_TTTCCTCAGAGCCCAA-1',
#    'CV001_KM10202388-CV001_KM10202398_GTTACAGGTTGCGCAC-1',
#    'S28_AAGCCGCGTAACGACG-1',
#    'S12_CCACTACTCCACGAAT-1',
#    'S12_GGGAGATGTCGAATCT-1',
#    'S3_GACGTTAAGCTGTTCA-1',
#    'CV001_KM10202405-CV001_KM10202417_TTATGCTCAAGCGCTC-1',
#    'S18_ACCCACTTCTTAACCT-1',
#    'S16_GATGAGGTCGCCATAA-1',
#    'S28_AGCTTGAGTAGCGATG-1',
#    'S15_GGGAATGTCTTTACGT-1',
#    'S28_ACTTGTTGTTCCCGAG-1',
#    'S6_CTGCCTATCTTGAGGT-1',
#    'S15_TAAGAGAAGCAGATCG-1',
#    'S27_TACTCATCATCCGCGA-1',
#    'S7_ACCAGTAAGGCAGGTT-1',
#    'S3_TCAGGTACAATGGAGC-1',
#    'S10_TAAACCGTCGCGGATC-1',
#    'CV001_KM10202388-CV001_KM10202398_GCGAGAACACAAGACG-1',
#    'S13_CCGGGATCAACTTGAC-1',
#    'CV001_KM10202388-CV001_KM10202398_ATTCTACCAGGACGTA-1',
#    'CV001_KM10202407-CV001_KM10202419_CCTTACGGTTCAGCGC-1',
#    'S20_GAGGTGAGTTAAGGGC-1',
#    'S12_CGGTTAATCTGCTGTC-1',
#    'S11_GGTGTTAGTACAGTGG-1',
#    'S14_CCTAAAGGTAGAGTGC-1',
#    'S9_CGATTGACAGGTCCAC-1',
#    'S3_CTGCTGTAGGCATGTG-1',
#    'S3_CTACACCCATCACAAC-1',
#    'S24_ATCGAGTGTCCCTTGT-1',
#    'S27_AGACGTTAGGCCCTTG-1',
#    'S27_CGGAGTCTCAGCTGGC-1',
#    'S17_AAACGGGTCAGGTAAA-1',
#    'S28_CTGATAGAGGGAACGG-1',
#    'CV001_KM10202392-CV001_KM10202402_CTAGCCTAGAGCTGGT-1',
#    'S18_GTGGGTCAGTCCTCCT-1',
#    'S4_AGGTCCGGTCTGGAGA-1',
#    'CV001_KM10202407-CV001_KM10202419_AGCTCCTAGTTGTAGA-1',
#    'S3_CCTTCGAAGCGATATA-1',
#    'S16_CATGCCTCATAGTAAG-1',
#    'S20_GCTCCTATCGAATGCT-1',
#    'CV001_KM10202404-CV001_KM10202416_CCCAGTTAGACAATAC-1',
#    'S28_CGAGAAGAGATAGGAG-1',
#    'CV001_KM10202405-CV001_KM10202417_TAGCCGGGTCGAACAG-1',
#    'S3_CGGACACAGTGTCCCG-1',
#    'S16_GACAGAGCAGCCTTGG-1',
#    'CV001_KM10202404-CV001_KM10202416_CAGCATACATGAAGTA-1',
#    'S24_GATGAAAAGCGTGAAC-1',
#    'S11_CAAGTTGTCAGCTCTC-1',
#    'S4_CAAGGCCTCTCCAACC-1',
#    'S22_ACGGCCAGTCTTCTCG-1',
#    'S18_AGTGTCAGTGCAACTT-1',
#    'S17_CGCTTCACACGTCAGC-1',
#    'CV001_KM10202406-CV001_KM10202418_CACACAAAGATCCCGC-1',
#    'S12_GACACGCGTCTCATCC-1',
#    'S3_TCTCATACACGTCAGC-1',
#    'S18_GCACATATCCTATGTT-1',
#    'S13_ATGTGTGGTAGGCTGA-1',
#    'S16_ATCTACTAGGCTAGGT-1',
#    'S24_CACAGTAAGTTCCACA-1',
#    'S12_CCATGTCGTCTAAACC-1',
#    'CV001_KM10202390-CV001_KM10202400_TCATTTGAGTACGACG-1',
#    'CV001_KM10202387-CV001_KM10202397_CTCAGAACAATAACGA-1',
#    'S18_GATCGTAGTCAGATAA-1',
#    'S27_CCAGCGACATCCCATC-1',
#    'S27_CCAATCCGTGCAGACA-1',
#    'S18_TCAATCTTCTAACCGA-1',
#    'S20_TCAACGAGTCCGACGT-1',
#    'S13_AGGTCATTCTGGTTCC-1',
#    'CV001_KM10202388-CV001_KM10202398_ATTGGTGAGACAAGCC-1',
#    'CV001_KM10202385-CV001_KM10202395_CCATTCGTCATGTGGT-1',
#    'S5_CGCGTTTAGACAAAGG-1',
#    'S16_CGTTCTGGTCTTCTCG-1',
#    'S3_CTGCGGATCCCTAACC-1',
#    'S19_CGTTGGGCAGGTGGAT-1',
#    'S12_TGGTTAGCACGAAGCA-1',
#    'S24_TCTTTCCGTACCAGTT-1',
#    'S6_CTACCCATCTGTCTCG-1',
#    'S15_TGAGCCGTCTAGAGTC-1',
#    'S22_CTAATGGAGTTCGCAT-1',
#    'S24_AGCGTCGGTTCAGACT-1',
#    'S23_CTCGAGGTCAGATAAG-1',
#    'S11_CCTACACAGATGCCTT-1',
#    'S24_CTGGTCTTCTCGTATT-1',
#    'CV001_KM10202384-CV001_KM10202394_GGAGCAAAGCCCAACC-1',
#    'CV001_KM10202388-CV001_KM10202398_AACTGGTTCACGACTA-1',
#    'S27_CAGCGACAGAGGACGG-1',
#    'S28_CGGTTAAGTTGGTTTG-1',
#    'S2_GGTGCGTCAGCTGTGC-1',
#    'S6_CGAACATAGCCGCCTA-1',
#    'CV001_KM10202388-CV001_KM10202398_CATGGCGCACTTCGAA-1',
#    'S27_GCAATCATCCGCGTTT-1',
#    'S5_CATGACATCAGTGCAT-1',
#    'S12_GGGTTGCTCCGCGTTT-1',
#    'CV001_KM10202390-CV001_KM10202400_CGTGTAACATCGGGTC-1',
#    'S14_TACGGATGTGCGGTAA-1',
#    'S16_CTCTACGAGGGAGTAA-1',
#    'CV001_KM10202405-CV001_KM10202417_GTATCTTGTCTAGCGC-1',
#    'CV001_KM10202390-CV001_KM10202400_TTTGTCAAGCGTCAAG-1',
#    'CV001_KM10202384-CV001_KM10202394_AAGGTTCGTCACCCAG-1',
#    'CV001_KM10202389-CV001_KM10202399_TAAGCGTAGACAAAGG-1',
#    'CV001_KM10202391-CV001_KM10202401_CTAATGGTCCTTCAAT-1',
#    'S24_AAGACCTCAAGCCGCT-1',
#    'S19_GTCGGGTTCCATGCTC-1',
#    'S15_GTCCTCACAAGTTCTG-1',
#    'S23_AGGTCCGCAAATCCGT-1',
#    'S28_ACGCAGCCAGGGCATA-1',
#    'S28_AAAGCAAAGCAATCTC-1',
#    'CV001_KM10202385-CV001_KM10202395_ACTGCTCCACAAGTAA-1',
#    'S17_TGGCCAGGTTGGTGGA-1',
#    'S24_GTGCATATCAGTTTGG-1',
#    'CV001_KM10202391-CV001_KM10202401_AACTTTCTCTCGATGA-1',
#    'S27_ATCATGGAGTCACGCC-1',
#    'S23_CGTCACTAGCGATATA-1',
#    'S20_TGCTGCTCACGGATAG-1',
#    'CV001_KM10202388-CV001_KM10202398_GGATTACTCTTCCTTC-1',
#    'S5_ATTCTACCACCGAATT-1',
#    'S18_TATTACCAGTCAATAG-1',
#    'S24_CGATGGCCACGGCCAT-1',
#    'CV001_KM10202386-CV001_KM10202396_GCAGTTACACGAAATA-1',
#    'CV001_KM10202386-CV001_KM10202396_CACAAACCAGGGTTAG-1',
#    'S27_CGAGCCACAGCCAATT-1',
#    'CV001_KM10202404-CV001_KM10202416_GTAGTCACATCACAAC-1',
#    'S3_ACTTACTGTGGAAAGA-1',
#    'S13_GCGACCACAAGAAGAG-1',
#    'CV001_KM10202388-CV001_KM10202398_CACACTCTCTTAGCCC-1',
#    'S26_TCCCGATAGGGTTCCC-1',
#    'S18_CCGGTAGCACGGATAG-1',
#    'S3_AAACGGGGTTAGATGA-1',
#    'S1_CAGGTGCGTGTTAAGA-1',
#    'S3_CAAGGCCCAGATGAGC-1',
#    'CV001_KM10202388-CV001_KM10202398_CAACCAAGTAGCAAAT-1',
#    'S4_CACAAACTCAGCCTAA-1',
#    'S15_GCATGCGTCATAAAGG-1',
#    'CV001_KM10202404-CV001_KM10202416_CACACTCAGACTACAA-1',
#    'S14_GGAAAGCCAAGTTCTG-1',
#    'S18_CCAATCCGTTTCCACC-1',
#    'S13_CGGACACCAATCACAC-1',
#    'S27_ACTATCTTCTCAAGTG-1',
#    'S4_GACTACAAGGGCATGT-1',
#    'S4_CTGATCCTCACTTACT-1',
#    'S17_AGGGTGAAGTGAACAT-1',
#    'S15_TCACGAAGTTAAGACA-1',
#    'S20_TACCTTAAGAATGTGT-1',
#    'CV001_KM10202404-CV001_KM10202416_TTTGCGCCATTAGGCT-1',
#    'S5_AGGTCCGGTCTGCGGT-1',
#    'CV001_KM10202405-CV001_KM10202417_TGCGTGGTCGCAGGCT-1',
#    'S20_AACTCAGTCAAGATCC-1',
#    'S1_CCACTACGTGTTGAGG-1',
#    'S18_AGCGGTCGTTATGTGC-1',
#    'S24_GACTACAAGGCGATAC-1',
#    'S5_TCAGGATAGGCGATAC-1',
#    'S1_AGCTTGAAGGGCTTCC-1',
#    'S11_CTACCCACAATCGGTT-1',
#    'S4_GTGCATACAATGGACG-1',
#    'S2_TGCTACCCACCGCTAG-1',
#    'S23_CCGTTCAAGCCACTAT-1',
#    'S11_CGTCTACAGGTAGCCA-1',
#    'S4_GGCAATTCACCAACCG-1',
#    'CV001_KM10202392-CV001_KM10202402_TTTGGTTGTTCCATGA-1',
#    'S3_AGAATAGTCAGCTTAG-1',
#    'S3_ATGAGGGTCGGTTCGG-1',
#    'S19_GTCACGGTCTCATTCA-1',
#    'S28_CCACTACAGAGGGCTT-1',
#    'S19_CAGAGAGCAATGAATG-1',
#    'S23_TTGTAGGTCACCCTCA-1',
#    'S16_AAACGGGCAAGGTGTG-1',
#    'S11_GTCCTCAAGATCGGGT-1',
#    'CV001_KM10202404-CV001_KM10202416_CGGAGTCTCCCTAATT-1',
#    'S11_TCAGGATGTCCGTCAG-1',
#    'CV001_KM10202389-CV001_KM10202399_GGCCGATAGGCTAGGT-1',
#    'S12_GGTGCGTGTTCCCGAG-1',
#    'S19_AGCCTAACATTGGTAC-1',
#    'S3_ACCTTTATCCTTGCCA-1',
#    'S15_CGGGTCATCAGTACGT-1',
#    'S20_TTGAACGTCATGTGGT-1',
#    'S18_AGTTGGTTCCGAACGC-1',
#    'S3_CGAGCCACACCGATAT-1',
#    'S17_CGTTCTGGTCACTGGC-1',
#    'S23_CGTCAGGGTGTCGCTG-1',
#    'CV001_KM10202384-CV001_KM10202394_CCGGGATAGCACACAG-1',
#    'S13_CATTATCTCATAAAGG-1',
#    'S20_CCTTACGAGACACTAA-1',
#    'S3_GACTACATCCGGCACA-1',
#    'CV001_KM10202407-CV001_KM10202419_GAACCTAAGCTGAAAT-1',
#    'S3_GAACATCCACGAGAGT-1',
#    'S12_ATCTGCCGTAGCAAAT-1',
#    'S2_CGTCAGGTCGAGGTAG-1',
#    'CV001_KM10202387-CV001_KM10202397_AGTGTCATCCACGAAT-1',
#    'S16_GAATGAAAGTTAACGA-1',
#    'S11_CTCGTACAGGGCACTA-1',
#    'CV001_KM10202405-CV001_KM10202417_ACCGTAAAGGGATACC-1',
#    'CV001_KM10202388-CV001_KM10202398_GCGCAGTGTCTCACCT-1',
#    'CV001_KM10202406-CV001_KM10202418_CTAACTTAGCGTTGCC-1',
#    'S1_TGCCCATAGAGTACCG-1',
#    'S3_GGGTCTGTCAACGGGA-1',
#    'S12_GCATGATCAGGATCGA-1',
#    'S28_AAGGCAGGTAGCTCCG-1',
#    'S14_GGGATGAAGAGGTACC-1',
#    'S16_CCAGCGACATTTGCTT-1',
#    'S3_ACAGCTACATCACCCT-1',
#    'S23_CAGATCACAATGGTCT-1',
#    'CV001_KM10202391-CV001_KM10202401_CACACAAAGGGATACC-1',
#    'S24_GGCAATTAGGCATTGG-1',
#    'S11_TCGGTAACAGACGCTC-1',
#    'S28_CGTCACTGTCCGAACC-1',
#    'S23_TGGCCAGAGTGCGTGA-1',
#    'CV001_KM10202389-CV001_KM10202399_ACACCAAGTCTAGTGT-1',
#    'S3_CATCAAGGTAGAAAGG-1',
#    'CV001_KM10202384-CV001_KM10202394_CTCGGGATCTCGTTTA-1',
#    'S13_CACTCCATCGGAGGTA-1',
#    'S14_GATGAGGTCCTAGTGA-1',
#    'S3_TTCTACAGTTTGTTGG-1',
#    'S5_AGTCTTTTCGAGAGCA-1',
#    'S21_GGAATAACACGCTTTC-1',
#    'S14_GACGGCTAGTTAACGA-1',
#    'CV001_KM10202406-CV001_KM10202418_CATCAGATCTTGTACT-1',
#    'S28_CACACCTGTCCAGTGC-1',
#    'CV001_KM10202385-CV001_KM10202395_TTTGGTTTCAAAGTAG-1',
#    'S12_ACAGCTAGTATCGCAT-1',
#    'CV001_KM10202404-CV001_KM10202416_ACTTACTTCTGAGTGT-1',
#    'S15_GCACTCTGTCACAAGG-1',
#    'S28_TAAGCGTAGACCTTTG-1',
#    'S4_TGTTCCGCATGCCCGA-1',
#    'S14_AACACGTCAAGTAGTA-1',
#    'CV001_KM10202405-CV001_KM10202417_TTGTAGGCAATACGCT-1',
#    'S13_TTTCCTCCACGAAATA-1',
#    'S11_GTACTCCTCAGTACGT-1',
#    'S1_TTTGTCAAGCTGTTCA-1',
#    'S18_TCACAAGCAAATTGCC-1',
#    'CV001_KM10202405-CV001_KM10202417_TCGAGGCAGTGAATTG-1',
#    'S19_CATATTCAGACATAAC-1',
#    'S17_TGCCCATTCGAACTGT-1',
#    'S11_CTTCTCTAGAATGTGT-1',
#    'S10_ATAGACCTCAGTTGAC-1',
#    'CV001_KM10202385-CV001_KM10202395_GATTCAGCACATAACC-1',
#    'S4_CCGTTCACAGCTCGCA-1',
#    'S1_CTCACACGTCTAGCCG-1',
#    'S18_GCGCCAATCATTATCC-1',
#    'S10_AGTGAGGTCCTCATTA-1',
#    'S27_TCAGGTAAGTTCCACA-1',
#    'S8_TGACGGCAGTCAAGGC-1',
#    'S22_GCGCCAAGTGAAGGCT-1',
#    'CV001_KM10202390-CV001_KM10202400_ATCGAGTCACAGCGTC-1',
#    'S12_CCTATTATCCGTAGGC-1',
#    'CV001_KM10202385-CV001_KM10202395_CTGAAACCAGCTATTG-1',
#    'S18_AGGCCACCATACTACG-1',
#    'CV001_KM10202385-CV001_KM10202395_ACCAGTAAGAAAGTGG-1',
#    'S23_CGTTGGGTCTTATCTG-1',
#    'S15_TACGGGCTCTTGACGA-1',
#    'S1_ATCCACCCACGTAAGG-1',
#    'S18_CTTAACTCACGCTTTC-1',
#    'CV001_KM10202393-CV001_KM10202403_GACTGCGTCTTAACCT-1',
#    'CV001_KM10202384-CV001_KM10202394_GTTCATTTCTGGCGAC-1',
#    'S19_ATTCTACAGTGTCCAT-1',
#    'CV001_KM10202387-CV001_KM10202397_TCAACGAAGTGGGCTA-1',
#    'S19_CATGCCTCAAGGCTCC-1',
#    'S12_GATCTAGCACAGCCCA-1',
#    'S13_AGCTTGAAGCGTGAGT-1',
#    'S28_CGGAGTCTCTTCATGT-1',
#    'S8_ATCATGGAGTAACCCT-1',
#    'S12_TACTCATTCCGAATGT-1',
#    'S14_TTCTCAAAGTAGCGGT-1',
#    'S24_GTCTTCGTCTAGAGTC-1',
#    'S18_CTAGCCTTCCTGCCAT-1',
#    'S20_ATAAGAGGTAACGCGA-1',
#    'CV001_KM10202387-CV001_KM10202397_GAGTCCGGTAGCTGCC-1',
#    'CV001_KM10202406-CV001_KM10202418_CCTCTGACACATTAGC-1',
#    'S16_TAGCCGGTCAGCATGT-1',
#    'S7_GTAACTGTCCGTTGCT-1',
#    'S27_CGACCTTCAGCTGCAC-1',
#    'S27_CGAGCACAGAGCCCAA-1',
#    'S13_GCAGCCAAGCTACCTA-1',
#    'S19_GCTTCCAAGGTAGCTG-1',
#    'CV001_KM10202384-CV001_KM10202394_TGTGTTTCACACCGAC-1',
#    'CV001_KM10202385-CV001_KM10202395_GCATGTAGTGTCGCTG-1',
#    'S3_TGGTTAGTCTATGTGG-1',
#    'S28_TAAACCGGTGGCAAAC-1',
#    'CV001_KM10202407-CV001_KM10202419_TGCCAAATCCTTAATC-1',
#    'S13_TGATTTCTCGTTACGA-1',
#    'CV001_KM10202404-CV001_KM10202416_GCTGCAGCATCCTTGC-1',
#    'CV001_KM10202385-CV001_KM10202395_GAGGTGAGTTGTGGAG-1',
#    'CV001_KM10202389-CV001_KM10202399_CGTAGGCAGCGTTGCC-1',
#    'S14_TGTTCCGAGATCTGAA-1',
#    'S3_CCACCTAAGACTAGGC-1',
#    'S14_AGTGTCATCCGCGTTT-1',
#    'S4_CGAGCCACAAGAAGAG-1',
#    'S27_GTAACTGCAGCCTGTG-1',
#    'CV001_KM10202388-CV001_KM10202398_AGTTGGTCACTGTGTA-1',
#    'S20_CATTATCGTTCAGACT-1',
#    'S12_CTCATTAAGTGGGATC-1',
#    'CV001_KM10202406-CV001_KM10202418_TCGGGACCATGCAACT-1',
#    'S3_GCATGTAGTGTGGCTC-1',
#    'S24_TCGTAGAGTACAGCAG-1',
#    'S28_GTCAAGTGTTACGCGC-1',
#    'S24_TCGTACCGTCATGCCG-1',
#    'S19_CCGTGGATCTCGCTTG-1',
#    'S7_GCCAAATTCCTAGAAC-1',
#    'S4_TTTATGCAGAGGACGG-1',
#    'S3_TTAGTTCTCTCAACTT-1',
#    'S18_GAACATCCAACGATCT-1',
#    'S19_GCCTCTATCTCATTCA-1',
#    'S11_GATCGATGTTCACGGC-1',
#    'S14_ATCACGATCACTTCAT-1',
#    'S4_CTCTGGTTCTTTACAC-1',
#    'S1_CGGACGTTCGATCCCT-1',
#    'S27_GATTCAGTCTACTTAC-1',
#    'S3_TTTCCTCTCACAAACC-1',
#    'CV001_KM10202390-CV001_KM10202400_TCAGCTCGTAGCGTAG-1',
#    'CV001_KM10202393-CV001_KM10202403_TTGAACGGTTATCACG-1',
#    'S27_TTGCCGTAGGAGTACC-1',
#    'S3_TGGTTCCCAAGTTAAG-1',
#    'CV001_KM10202404-CV001_KM10202416_ACTGCTCCAGGGAGAG-1',
#    'S4_CGGAGCTCACTAAGTC-1',
#    'S17_CGATGTAAGAAGGTGA-1',
#    'S19_AGCAGCCAGCGGATCA-1',
#    'S11_CCCTCCTAGTGTGGCA-1',
#    'S19_GTATCTTGTAGAGTGC-1',
#    'S23_CAGGTGCCAATAGCGG-1',
#    'CV001_KM10202385-CV001_KM10202395_CGTTAGACATCGGTTA-1',
#    'S6_AGCCTAACATTGGCGC-1',
#    'S9_ATTATCCCACGGTGTC-1',
#    'S15_TTAGTTCAGTAACCCT-1',
#    'S17_AGCGTATCATGGTTGT-1',
#    'S17_TACGGATAGCCTTGAT-1',
#    'S15_CTCAGAATCAGTGTTG-1',
#    'S18_CAGCATAAGTTATCGC-1',
#    'CV001_KM10202385-CV001_KM10202395_CGATTGAGTAATCACC-1',
#    'S16_GCTCTGTAGCTAGCCC-1',
#    'CV001_KM10202405-CV001_KM10202417_ATTACTCAGCAGATCG-1',
#    'S19_TGGACGCGTCGCATCG-1',
#    'S16_ATCGAGTCAAAGTCAA-1',
#    'CV001_KM10202406-CV001_KM10202418_CTCGAGGCAGTACACT-1',
#    'S12_ACTGAGTTCCGCAAGC-1',
#    'S23_CACATTTGTTTCCACC-1',
#    'S24_CGAATGTAGGAATTAC-1',
#    'S28_TGACGGCCAATGGACG-1',
#    'S23_CACATAGAGTTGAGTA-1',
#    'S23_CTACGTCCAGACGTAG-1',
#    'S20_TGTCCCAGTAGAGCTG-1',
#    'S12_CGATGTAAGTGAAGAG-1',
#    'S17_CACAAACAGTCAAGCG-1',
#    'CV001_KM10202405-CV001_KM10202417_CGAATGTGTCTCTCTG-1',
#    'S4_CACATAGAGCGTTGCC-1',
#    'S28_ATTACTCGTTCGTTGA-1',
#    'S23_CACAGGCTCGTGGGAA-1',
#    'CV001_KM10202404-CV001_KM10202416_AACTTTCGTACTTCTT-1',
#    'S23_GTCCTCAGTGCACTTA-1',
#    'S11_TCGCGAGAGCGCTTAT-1',
#    'S3_GCTCTGTTCTTGCATT-1',
#    'S3_TCGGGACAGATCCCGC-1',
#    'S15_ATCTGCCTCGTGGGAA-1',
#    'S12_TGCCAAACAACTGCGC-1',
#    'S19_GGGCATCGTCCAACTA-1',
#    'S20_CCATGTCGTCACAAGG-1',
#    'S3_AAATGCCTCCTTGACC-1',
#    'S12_CACACCTAGACTCGGA-1',
#    'S13_CGTTGGGTCCGCATAA-1',
#    'S3_CATGGCGTCCTAGTGA-1',
#    'CV001_KM10202385-CV001_KM10202395_AGCTCTCTCAGAGACG-1',
#    'S26_AGAGCGATCAAAGACA-1',
#    'S3_GACCTGGAGAGAACAG-1',
#    'CV001_KM10202404-CV001_KM10202416_CAGATCAAGCTACCTA-1',
#    'S20_GAGCAGAGTTGTGGCC-1',
#    'S28_CACATAGCACCAGATT-1',
#    'CV001_KM10202388-CV001_KM10202398_GACGGCTAGATCGGGT-1',
#    'S23_GCGGGTTCAGGCTCAC-1',
#    'S5_TCTGGAAAGTGCCATT-1',
#    'S17_CAAGAAACAAGACACG-1',
#    'S11_AAGGTTCCATGCCTTC-1',
#    'CV001_KM10202407-CV001_KM10202419_CGATGGCTCTCACATT-1',
#    'S15_CTGCTGTCAGACTCGC-1',
#    'S28_CCTTTCTGTAAACACA-1',
#    'CV001_KM10202389-CV001_KM10202399_GGACAGAAGATCCCAT-1',
#    'S24_CAGCCGAGTATAGGTA-1',
#    'S23_ACTGAACGTCTAACGT-1',
#    'S23_ATTACTCCATGCTGGC-1',
#    'CV001_KM10202385-CV001_KM10202395_GGGTCTGCAGTAAGAT-1',
#    'CV001_KM10202385-CV001_KM10202395_AGTGGGACATCTGGTA-1',
#    'S23_AAATGCCGTAAGTGTA-1',
#    'S28_AGGGTGACATACTCTT-1',
#    'S1_TGCTACCCAATGGTCT-1',
#    'S3_ACTTACTGTCGGCATC-1',
#    'S9_CTGTTTATCTCGTTTA-1',
#    'S23_TGGTTAGAGACATAAC-1',
#    'S26_GGTATTGGTAGGACAC-1',
#    'CV001_KM10202389-CV001_KM10202399_AGCATACCAATCTGCA-1',
#    'S22_CCACGGATCACATACG-1',
#    'CV001_KM10202404-CV001_KM10202416_AACTCAGTCTCTAAGG-1',
#    'CV001_KM10202405-CV001_KM10202417_AAGCCGCCAGAAGCAC-1',
#    'S3_GTGTGCGGTATAAACG-1',
#    'CV001_KM10202388-CV001_KM10202398_GAATAAGAGCTAGTGG-1',
#    'S15_CATGCCTCAGGGTATG-1',
#    'CV001_KM10202386-CV001_KM10202396_TTTGTCACACCGTTGG-1',
#    'CV001_KM10202406-CV001_KM10202418_CAGATCAGTACTCAAC-1',
#    'S19_GTTCATTAGAACAATC-1',
#    'S2_ACGTCAAAGAAGAAGC-1',
#    'S16_ACTTACTGTTGATTGC-1',
#    'S4_CTTGGCTAGAGATGAG-1',
#    'S11_GCTGCGATCCATGAAC-1',
#    'S19_CGACTTCAGTACGCGA-1',
#    'S5_TCTTCGGTCCACGACG-1',
#    'S13_CCCAATCGTGATGATA-1',
#    'S17_CGTCAGGAGCGTCAAG-1',
#    'CV001_KM10202391-CV001_KM10202401_ACGGAGACATATACGC-1',
#    'S3_ACGGCCACATAGAAAC-1',
#    'S14_GATGAAAAGCTGCGAA-1',
#    'CV001_KM10202388-CV001_KM10202398_CATGACATCCGTCATC-1',
#    'S18_CATCGGGTCGGTCTAA-1',
#    'S10_GCGAGAATCACTGGGC-1',
#    'S27_TCTTTCCAGTCCGGTC-1',
#    'S28_CTGCCTAAGCCAACAG-1',
#    'CV001_KM10202388-CV001_KM10202398_CAACCTCGTACAGTTC-1',
#    'CV001_KM10202384-CV001_KM10202394_CCTTTCTTCCCTAATT-1',
#    'CV001_KM10202388-CV001_KM10202398_CTCGTACCAGATGGGT-1',
#    'S17_CACTCCAAGTATTGGA-1',
#    'CV001_KM10202389-CV001_KM10202399_GACGTGCAGCTGGAAC-1',
#    'S24_GACGCGTCAGTACACT-1',
#    'S3_CTTCTCTCATCGGGTC-1',
#    'S21_ACACCGGGTAATTGGA-1',
#    'S12_TATCTCACATCCTAGA-1',
#    'CV001_KM10202388-CV001_KM10202398_CTACATTTCACTTCAT-1',
#    'S20_AACTCAGCATGGTCTA-1',
#    'S11_GACAGAGAGAAGAAGC-1',
#    'S11_GATCTAGCACAGATTC-1',
#    'S2_CTAGCCTTCTTCATGT-1',
#    'S2_TGGTTAGCATGCCTAA-1',
#    'S27_ACTGAGTCACTGAAGG-1',
#    'S23_AGCTTGACAGCCAATT-1',
#    'S9_AGGCCGTAGGAGCGTT-1',
#    'CV001_KM10202386-CV001_KM10202396_AACCATGAGGAGTTTA-1',
#    'S20_CAGCAGCAGCGTCTAT-1',
#    'S1_CTCTACGAGACCGGAT-1',
#    'S17_CTCCTAGGTTCCCTTG-1',
#    'S4_GCATGTACAGTCAGCC-1',
#    'S19_CACCAGGAGCAGCCTC-1',
#    'S28_GAGGTGAAGGCCGAAT-1',
#    'S17_TTTGGTTTCATGTGGT-1',
#    'S19_TGCACCTGTCATATGC-1',
#    'S3_CCCAGTTAGAAGAAGC-1',
#    'S15_GGACGTCCATAGTAAG-1',
#    'S3_TGACTAGAGTACGTTC-1',
#    'S13_GATCGATTCAAAGTAG-1',
#    'S17_TTGCCGTAGTGGCACA-1',
#    'CV001_KM10202391-CV001_KM10202401_GTGTGCGAGGGTATCG-1',
#    'S9_AGCGTATCAGTTAACC-1',
#    'CV001_KM10202405-CV001_KM10202417_TTCGAAGTCACCAGGC-1',
#    'S12_CCGTGGAAGTCGCCGT-1',
#    'S23_AACTCCCTCGCCCTTA-1',
#    'S19_GAAGCAGCAGACGCTC-1',
#    'S23_GTCTTCGTCAGTACGT-1',
#    'S14_GATCAGTGTTCGCGAC-1',
#    'S24_TATCTCAGTCATCCCT-1',
#    'CV001_KM10202406-CV001_KM10202418_CCTTTCTCAATAACGA-1',
#    'S1_GTGCATAAGATATACG-1',
#    'S28_GTGCAGCAGTTCGCGC-1',
#    'S13_TCCCGATTCAAACAAG-1',
#    'CV001_KM10202386-CV001_KM10202396_GTCGGGTGTGACCAAG-1',
#    'S3_CAAGTTGCAATTCCTT-1',
#    'S27_GTACTTTCAATGGACG-1',
#    'S11_ACGCCAGAGATCTGCT-1',
#    'CV001_KM10202389-CV001_KM10202399_CGTGTCTTCAAGGCTT-1',
#    'S4_GACGGCTTCCATTCTA-1',
#    'S19_CGCTATCGTTTGTTGG-1',
#    'S6_TTGGCAAAGTTAACGA-1',
#    'S12_ACTTGTTTCGAGAACG-1',
#    'S27_TGCACCTGTCTCTCGT-1',
#    'CV001_KM10202393-CV001_KM10202403_GCAAACTCACCGTTGG-1',
#    'S19_CTACGTCCAGATGAGC-1',
#    'CV001_KM10202405-CV001_KM10202417_TGAGAGGCAATAGAGT-1',
#    'S28_CGTCAGGTCTTTACGT-1',
#    'S22_CTCATTAGTGTTCGAT-1',
#    'S3_TACTCATTCAAACAAG-1',
#    'S27_TGTGTTTTCCAGTAGT-1',
#    'S17_TCAACGATCAGTTAGC-1',
#    'S13_GTCACGGCATTGGGCC-1',
#    'S24_AAGTCTGTCTCCGGTT-1',
#    'CV001_KM10202392-CV001_KM10202402_CGATCGGTCTTAGAGC-1',
#    'S6_AGGGAGTGTTTCCACC-1',
#    'S18_CCTACACAGGGTTTCT-1',
#    'S5_CTGCGGAAGTGTTAGA-1',
#    'S6_ACGAGGACAGAAGCAC-1',
#    'CV001_KM10202390-CV001_KM10202400_CTTACCGTCTTTAGTC-1',
#    'S9_TTTGTCAGTACTTGAC-1',
#    'S3_CTACGTCGTCCATCCT-1',
#    'S11_GCGCAACCACTTGGAT-1',
#    'S6_GATCGATGTAACGCGA-1',
#    'CV001_KM10202388-CV001_KM10202398_CTCGAAAGTACGACCC-1',
#    'CV001_KM10202405-CV001_KM10202417_GCGGGTTTCCTTTACA-1',
#    'S20_CGGACACGTTTAAGCC-1',
#    'S19_GTGTGCGTCTTACCGC-1',
#    'S28_CGTTGGGTCTTCGGTC-1',
#    'S15_GGGAATGGTACCGCTG-1',
#    'S24_TCGTAGAGTTAGATGA-1',
#    'S17_ACACCAAGTCGTGGCT-1',
#    'S18_GAATGAAAGCCCTAAT-1',
#    'CV001_KM10202389-CV001_KM10202399_TACCTATAGAAACCAT-1',
#    'CV001_KM10202405-CV001_KM10202417_CAACCTCGTATGAATG-1',
#    'S8_TGTTCCGAGAATTCCC-1',
#    'S17_GGTATTGCAATGTTGC-1',
#    'S13_TGGGCGTGTGAGTGAC-1',
#    'CV001_KM10202391-CV001_KM10202401_CTGCGGAGTGGTCTCG-1',
#    'S3_CGAACATAGTGTGAAT-1',
#    'S3_AACGTTGCACAGGTTT-1',
#    'CV001_KM10202386-CV001_KM10202396_AGTGAGGGTTGGAGGT-1',
#    'S20_CAAGTTGGTTGTGGAG-1',
#    'S3_CCTATTAGTATGCTTG-1',
#    'S23_ACACCCTCACCACCAG-1',
#    'S3_GTCACGGTCTGAAAGA-1',
#    'CV001_KM10202388-CV001_KM10202398_AACTCTTGTCAACATC-1',
#    'S27_ACATGGTGTTGTTTGG-1',
#    'CV001_KM10202404-CV001_KM10202416_TCATTACGTAATTGGA-1',
#    'S19_CGGACACGTGTGAAAT-1',
#    'CV001_KM10202391-CV001_KM10202401_CAGAATCAGAGTAATC-1',
#    'S24_CCTCTGATCGTTGACA-1',
#    'S19_ATTTCTGAGTCTCCTC-1',
#    'S28_CACCTTGCATGGTCTA-1',
#    'S16_GTGCAGCGTCTCTTTA-1',
#    'S24_AGCTTGAGTTCGCGAC-1',
#    'S16_AGTCTTTTCACAAACC-1',
#    'S27_ACGGGCTGTATAGGGC-1',
#    'S27_CACAGTACATAGAAAC-1',
#    'S15_ACTGCTCCAGCTGTGC-1',
#    'S3_ATGCGATTCTATCGCC-1',
#    'S13_GGGTCTGGTAGCGTCC-1',
#    'S28_CGTTGGGAGGAACTGC-1',
#    'S11_GGGACCTAGCCACCTG-1',
#    'CV001_KM10202386-CV001_KM10202396_TACCTTAGTCGAAAGC-1',
#    'S14_TTCTCCTTCCGATATG-1',
#    'CV001_KM10202389-CV001_KM10202399_ACGTCAAGTGCTAGCC-1',
#    'S25_AACGTTGGTCCGAATT-1',
#    'CV001_KM10202390-CV001_KM10202400_TGGCTGGCAACGATGG-1',
#    'S4_AACTCTTGTAGAAAGG-1',
#    'S19_TCAGGATGTGTGGTTT-1',
#    'CV001_KM10202388-CV001_KM10202398_TATCTCATCATATCGG-1',
#    'S9_CAGCAGCGTAATTGGA-1',
#    'CV001_KM10202390-CV001_KM10202400_ACTATCTCACGAAGCA-1',
#    'S23_CGCTTCATCCTAGTGA-1',
#    'S18_TCAACGAGTATGAATG-1',
#    'S11_CTTAGGACATCTACGA-1',
#    'S2_CGAACATCAGCTGCAC-1',
#    'S24_AGATCTGTCAGGCGAA-1',
#    'CV001_KM10202404-CV001_KM10202416_TGCACCTCAGCTGTAT-1',
#    'S23_CGAACATGTAGCGTAG-1',
#    'S10_ACGCCAGTCTCAACTT-1',
#    'S13_TTTATGCAGGATGCGT-1',
#    'S3_ACGTCAATCAACACGT-1',
#    'S3_TTTCCTCTCATAACCG-1',
#    'S4_ACGCCAGTCGAGGTAG-1',
#    'S18_TATCAGGGTACCGTTA-1',
#    'S19_TACTCATTCGATAGAA-1',
#    'S12_ATGTGTGCAGTATGCT-1',
#    'CV001_KM10202392-CV001_KM10202402_TCGGGACGTTGCCTCT-1',
#    'CV001_KM10202404-CV001_KM10202416_TTGACTTAGATGTCGG-1',
#    'S12_TCCACACTCACGCATA-1',
#    'S4_GGTGTTACACATTTCT-1',
#    'S2_CACACAAGTCCGAAGA-1',
#    'S12_GAGCAGATCTGCGACG-1',
#    'S12_CTGATCCTCTACCTGC-1',
#    'S10_CAGCATAAGGACTGGT-1',
#    'S17_AGCGGTCGTGACCAAG-1',
#    'S18_TAGACCACATGACATC-1',
#    'S11_ACTTTCACAAGTAATG-1',
#    'S20_CATCAGAGTTACCAGT-1',
#    'S5_AAAGCAAAGTACCGGA-1',
#    'CV001_KM10202405-CV001_KM10202417_TTTGGTTGTGGTCTCG-1',
#    'S16_CTAATGGGTACTTGAC-1',
#    'S3_TGAGCCGTCTCCCTGA-1',
#    'S12_CCTTTCTAGCAGGTCA-1',
#    'S20_GCTCCTATCCTAGTGA-1',
#    'S15_ATCTACTAGATCTGCT-1',
#    'CV001_KM10202406-CV001_KM10202418_AAGTCTGGTAAATGAC-1',
#    'S12_GTGCATATCAGCGACC-1',
#    'S20_TAGGCATTCTCAAACG-1',
#    'S17_CATCGAAGTAAGAGGA-1',
#    'S4_ATGGGAGCACGACGAA-1',
#    'S17_CTGCGGAAGTTGAGAT-1',
#    'S19_GCGAGAAAGAGATGAG-1',
#    'CV001_KM10202392-CV001_KM10202402_CAACTAGTCAAACGGG-1',
#    'CV001_KM10202406-CV001_KM10202418_GCATACAGTAAAGGAG-1',
#    'S24_TCAGGTACAATAGCAA-1',
#    'CV001_KM10202405-CV001_KM10202417_CTGAAGTCATCGATTG-1',
#    'S10_GTGCGGTTCGAATGCT-1',
#    'S14_CCACCTAAGACGACGT-1',
#    'S4_GTTACAGCACGCCAGT-1',
#    'S23_TCGTAGACAGGGTATG-1',
#    'S25_TAGGCATTCTCGCATC-1',
#    'S13_TACGGATGTGTCGCTG-1',
#    'S15_AGCATACGTTGACGTT-1',
#    'S18_CGCTATCAGAAGGTTT-1',
#    'CV001_KM10202384-CV001_KM10202394_GGTGTTAAGGAATCGC-1',
#    'S19_CTCAGAAGTAAGTGGC-1',
#    'CV001_KM10202385-CV001_KM10202395_TCGAGGCTCACATACG-1',
#    'S1_CTCGAAAGTGAACCTT-1',
#    'S10_GGCCGATTCTTCGAGA-1',
#    'S19_AGATTGCCATACCATG-1',
#    'CV001_KM10202391-CV001_KM10202401_GCTGCAGGTTCCAACA-1',
#    'S3_TGAGAGGGTCCCGACA-1',
#    'S11_CAAGGCCCATCCGCGA-1',
#    'S3_CTCCTAGAGTTATCGC-1',
#    'CV001_KM10202387-CV001_KM10202397_GAACCTATCCCTAATT-1',
#    'S13_GCATGTATCACCAGGC-1',
#    'S27_GGTGCGTTCAATCACG-1',
#    'CV001_KM10202387-CV001_KM10202397_TCAGGTATCGAGAGCA-1',
#    'S1_TAAACCGGTTAAGGGC-1',
#    'S6_CTCAGAACAGGAATGC-1',
#    'CV001_KM10202385-CV001_KM10202395_GCTGCAGCAATGGTCT-1',
#    'CV001_KM10202386-CV001_KM10202396_ACCTTTACACGGACAA-1',
#    'S23_CGCTTCAGTCCGCTGA-1',
#    'S27_CTAACTTTCAGGATCT-1',
#    'S17_ACTTACTCACCTTGTC-1',
#    'S4_CTGATAGGTAGCTAAA-1',
#    'CV001_KM10202388-CV001_KM10202398_CTAATGGTCACTCCTG-1',
#    'CV001_KM10202406-CV001_KM10202418_GTGTTAGAGTGAAGTT-1',
#    'S8_ACAGCCGAGAAGAAGC-1',
#    'S28_CCCTCCTCACACCGAC-1',
#    'S23_GACAGAGGTGGGTCAA-1',
#    'CV001_KM10202386-CV001_KM10202396_TCAGGATTCCTACAGA-1',
#    'S25_ACGAGGAGTTCCAACA-1',
#    'CV001_KM10202384-CV001_KM10202394_GTAGTCACACATCCGG-1',
#    'S19_GCAATCACATTTGCCC-1',
#    'S3_TTCTACATCCGCGGTA-1',
#    'CV001_KM10202389-CV001_KM10202399_AATCGGTGTTAGGGTG-1',
#    'CV001_KM10202389-CV001_KM10202399_GGATGTTAGTCGATAA-1',
#    'CV001_KM10202407-CV001_KM10202419_CCTTCCCTCGGAATCT-1',
#    'S17_TACTTGTCACCCAGTG-1',
#    'S20_GTACTTTCACTCGACG-1',
#    'S17_AACTCTTGTCAGATAA-1',
#    'S18_ATCACGAGTGTGAATA-1',
#    'CV001_KM10202385-CV001_KM10202395_CAGCCGACAATAGCGG-1',
#    'S12_GTACTCCAGACAGACC-1',
#    'CV001_KM10202388-CV001_KM10202398_GTGAAGGTCTAACCGA-1',
#    'S16_CTTAACTCAGCATACT-1',
#    'S9_AGCCTAAGTTCGCGAC-1',
#    'S22_CCGTGGATCACTTCAT-1',
#    'CV001_KM10202391-CV001_KM10202401_GTCATTTAGGTGTTAA-1',
#    'CV001_KM10202406-CV001_KM10202418_ATAGACCCAGCTGTTA-1',
#    'S23_GACTACAAGCTAAGAT-1',
#    'S24_TGCGCAGAGGTGCAAC-1',
#    'S27_CTTCTCTGTTCAACCA-1',
#    'S12_CTGGTCTCAAGGTTTC-1',
#    'S14_GCAATCATCTGCTGCT-1',
#    'S24_TGGGCGTAGTCTCGGC-1',
#    'S4_TTCTCAATCCAAGCCG-1',
#    'S24_GGGATGACAAGGTGTG-1',
#    'CV001_KM10202384-CV001_KM10202394_TATTACCAGCGCTCCA-1',
#    'CV001_KM10202404-CV001_KM10202416_TACAGTGGTGCAGGTA-1',
#    'S19_GGACAAGCATGACATC-1',
#    'CV001_KM10202407-CV001_KM10202419_TTTGTCAGTTGTACAC-1',
#    'S14_CATGCCTAGCCACGTC-1',
#    'S12_CTAGAGTAGCTGAAAT-1',
#    'S23_AACTTTCTCACCTTAT-1',
#    'S11_TACGGATTCTTGCCGT-1',
#    'CV001_KM10202387-CV001_KM10202397_CTACCCACAGATTGCT-1',
#    'S28_TTCTCCTTCTCAAGTG-1',
#    'CV001_KM10202391-CV001_KM10202401_GAACATCTCCACGTTC-1',
#    'S27_ACGTCAACAGGACGTA-1',
#    ...],
#   'cell_set_accession': 'annotation_detailed_fullNames:18b0749342',
#   'cell_ontology_term_id': 'CL:0000860',
#   'cell_ontology_term': 'classical monocyte',
#   'author_annotation_fields': {'SURFACE PROTEIN MARKERS': 'CD14'},
#   'parent_cell_set_name': 'Monocyte',
#   'parent_cell_set_accession': 'annotation_broad:5faf33d7f7'},
#  {'labelset': 'annotation_detailed_fullNames',
#   'cell_label': 'T CD4 helper',
#   'marker_gene_evidence': ['CD3D', ' CD4', ' CD27', ' IL7R'],
#   'cell_ids': ['S16_CTTACCGGTGCAGTAG-1',
#    'S12_GAACGGAAGGCAATTA-1',
#    'S12_CATCGAATCATGGTCA-1',
#    'S23_GCTGCTTCAGCGTAAG-1',
#    'S2_GGCAATTAGCGCCTCA-1',
#    'S22_GGCTCGAAGCCAGGAT-1',
#    'CV001_KM10202385-CV001_KM10202395_CATATTCTCGAACGGA-1',
#    'S22_TTTCCTCCAGGACGTA-1',
#    'CV001_KM10202393-CV001_KM10202403_TGCTGCTAGTTTAGGA-1',
#    'S5_CTCGGGAAGAAACCGC-1',
#    'CV001_KM10202392-CV001_KM10202402_TAGTTGGGTCTTTCAT-1',
#    'CV001_KM10202389-CV001_KM10202399_CTCATTACAATCCGAT-1',
#    'S11_TCGAGGCGTCCGAAGA-1',
#    'S13_CTCGGAGTCCATTCTA-1',
#    'CV001_KM10202393-CV001_KM10202403_GCGCAGTCATAGAAAC-1',
#    'S25_GGACGTCAGACAGACC-1',
#    'S24_CTAATGGCATTGAGCT-1',
#    'S20_GTAACTGAGAGCTGGT-1',
#    'S23_CCATGTCCAAGGTTCT-1',
#    'CV001_KM10202389-CV001_KM10202399_GAACCTAAGATGAGAG-1',
#    'S3_TTCGGTCCAGCTCGAC-1',
#    'CV001_KM10202384-CV001_KM10202394_CTCACACGTAAAGTCA-1',
#    'S3_CTACGTCTCGTAGGAG-1',
#    'CV001_KM10202390-CV001_KM10202400_AAGGCAGAGAAGATTC-1',
#    'CV001_KM10202387-CV001_KM10202397_CTTAGGATCAGGCCCA-1',
#    'S11_GGGAATGTCTAACTGG-1',
#    'S13_CAGTCCTCATGTCGAT-1',
#    'S9_TAGGCATTCTGATTCT-1',
#    'CV001_KM10202390-CV001_KM10202400_TGTGTTTGTTGGAGGT-1',
#    'S21_ACGGGCTCACAGCCCA-1',
#    'S27_TGATTTCCAGATGGGT-1',
#    'S18_TGTGTTTAGTCTCAAC-1',
#    'S24_ACTTTCAAGAGCTGCA-1',
#    'CV001_KM10202389-CV001_KM10202399_CATATGGCAAGTAATG-1',
#    'S8_GCGAGAACAACGATGG-1',
#    'S15_CAGCATATCGTTTAGG-1',
#    'S22_TGCCCTAAGCTACCGC-1',
#    'CV001_KM10202388-CV001_KM10202398_CGTTAGATCGGCTTGG-1',
#    'S8_TAGACCACAGTCCTTC-1',
#    'S15_CGGACACGTGACAAAT-1',
#    'S25_CTAGAGTGTAGCTCCG-1',
#    'CV001_KM10202405-CV001_KM10202417_ACCCACTGTCTGATTG-1',
#    'S4_TGCTACCCAGCTCGAC-1',
#    'S21_TGCCAAACAGTAAGCG-1',
#    'CV001_KM10202385-CV001_KM10202395_CCGTGGATCAAGATCC-1',
#    'S26_AACTGGTCACTGAAGG-1',
#    'CV001_KM10202391-CV001_KM10202401_TGTATTCGTAACGTTC-1',
#    'S21_CATCAAGTCTGCCCTA-1',
#    'CV001_KM10202391-CV001_KM10202401_ACCGTAACATGTTGAC-1',
#    'CV001_KM10202392-CV001_KM10202402_CTGAAGTTCCTGCAGG-1',
#    'S21_TCACAAGCAAGAGGCT-1',
#    'S28_CGTCAGGTCATTGCGA-1',
#    'S10_ACTGAGTCAAAGTCAA-1',
#    'CV001_KM10202392-CV001_KM10202402_GCCAAATGTCCGTCAG-1',
#    'CV001_KM10202388-CV001_KM10202398_GCTGCGACAGTAGAGC-1',
#    'S22_ATTCTACGTCATCCCT-1',
#    'S24_ATCGAGTGTAAGTTCC-1',
#    'S8_TCATTACAGTATCTCG-1',
#    'CV001_KM10202389-CV001_KM10202399_CTACCCAGTACCCAAT-1',
#    'S24_GGGATGATCACCATAG-1',
#    'CV001_KM10202388-CV001_KM10202398_TGCCAAAGTCCTGCTT-1',
#    'S9_ACACCAATCTCACATT-1',
#    'S19_GGAACTTGTGTGCCTG-1',
#    'CV001_KM10202385-CV001_KM10202395_CACAGGCGTTCCCTTG-1',
#    'CV001_KM10202384-CV001_KM10202394_CCACGGATCATTATCC-1',
#    'S1_TTCTCCTCAACAACCT-1',
#    'CV001_KM10202384-CV001_KM10202394_ACGCCAGCATACGCCG-1',
#    'CV001_KM10202389-CV001_KM10202399_CGAGCCATCAACCATG-1',
#    'S4_TGAGGGAAGGTAGCCA-1',
#    'CV001_KM10202404-CV001_KM10202416_GTGCGGTAGTGTTTGC-1',
#    'CV001_KM10202390-CV001_KM10202400_GATCAGTAGTCGCCGT-1',
#    'S22_CCGTGGACAAAGCAAT-1',
#    'S14_AACTCCCGTGAAGGCT-1',
#    'S19_TATCAGGTCGGAGCAA-1',
#    'S22_TGGACGCCATCGGACC-1',
#    'S8_GAACGGAAGCGATATA-1',
#    'S22_CTCGTCAGTGAACCTT-1',
#    'S11_TACGGATTCAAACCAC-1',
#    'CV001_KM10202388-CV001_KM10202398_AAATGCCTCTGTCAAG-1',
#    'S7_CGAACATTCCCTAATT-1',
#    'S11_CTGATAGGTAAGAGGA-1',
#    'S16_CGCGGTAGTTCGAATC-1',
#    'CV001_KM10202389-CV001_KM10202399_TTCTCCTCATTGAGCT-1',
#    'CV001_KM10202389-CV001_KM10202399_GCGCAACGTCCGCTGA-1',
#    'S21_CTCTAATAGTTAACGA-1',
#    'S15_GTCTCGTCACTTGGAT-1',
#    'CV001_KM10202390-CV001_KM10202400_ATTGGACCACACCGAC-1',
#    'CV001_KM10202384-CV001_KM10202394_CATCCACAGAGACTAT-1',
#    'S10_CACACCTCAAGTCATC-1',
#    'CV001_KM10202387-CV001_KM10202397_CACACTCAGAGTCGGT-1',
#    'S10_TACTCGCCACGAAATA-1',
#    'S22_GTACTTTAGCGCTTAT-1',
#    'CV001_KM10202388-CV001_KM10202398_GGCCGATTCCGTCAAA-1',
#    'S2_GTAACGTAGTTGTCGT-1',
#    'S22_CGGACGTTCGAGGTAG-1',
#    'CV001_KM10202388-CV001_KM10202398_CCTAAAGGTAGTACCT-1',
#    'CV001_KM10202388-CV001_KM10202398_CGAGAAGGTAGAAGGA-1',
#    'CV001_KM10202389-CV001_KM10202399_ACGTCAAGTCGGGTCT-1',
#    'S12_TCTGGAACAAGGACTG-1',
#    'S14_CCTTCCCAGGTCGGAT-1',
#    'CV001_KM10202390-CV001_KM10202400_TACAGTGCAACCGCCA-1',
#    'CV001_KM10202388-CV001_KM10202398_TCCACACCATCCGTGG-1',
#    'CV001_KM10202405-CV001_KM10202417_CCACGGAGTGAGCGAT-1',
#    'CV001_KM10202404-CV001_KM10202416_CCGGGATAGTGGTAAT-1',
#    'S11_GCTCTGTCATCCTAGA-1',
#    'S25_ATGGGAGGTATTCTCT-1',
#    'S27_GCAAACTGTTCAGACT-1',
#    'S14_TCGAGGCGTAGAGCTG-1',
#    'S20_AGCAGCCGTAGGGTAC-1',
#    'S16_GATCAGTCATCTGGTA-1',
#    'S27_GGGAGATCATGCCACG-1',
#    'S20_CCGGTAGCAAGCTGAG-1',
#    'S4_CACACAAAGTAGGTGC-1',
#    'S24_TGGGCGTTCAGCAACT-1',
#    'CV001_KM10202405-CV001_KM10202417_GCCTCTATCACGATGT-1',
#    'S23_CGGACGTCACATCTTT-1',
#    'CV001_KM10202390-CV001_KM10202400_GCTTCCACAATGGAGC-1',
#    'S21_GTTACAGCACGGCTAC-1',
#    'S9_TGTTCCGGTTGGTAAA-1',
#    'CV001_KM10202392-CV001_KM10202402_TTGACTTCATTGGCGC-1',
#    'CV001_KM10202392-CV001_KM10202402_TTGCCGTAGGTGGGTT-1',
#    'S26_CAAGGCCTCAAGGCTT-1',
#    'S12_TTGACTTTCCGCGCAA-1',
#    'S21_GGCAATTCACGTGAGA-1',
#    'S24_CAACTAGGTTACCGAT-1',
#    'S14_GCAGTTACATGTAAGA-1',
#    'S24_CAAGATCCAGCGAACA-1',
#    'CV001_KM10202390-CV001_KM10202400_TAGCCGGAGTTTCCTT-1',
#    'CV001_KM10202389-CV001_KM10202399_GGCTCGATCCTCTAGC-1',
#    'CV001_KM10202387-CV001_KM10202397_CTCGGAGTCAGGATCT-1',
#    'CV001_KM10202389-CV001_KM10202399_AAAGTAGCATCGACGC-1',
#    'CV001_KM10202391-CV001_KM10202401_CAACCAACACAGCGTC-1',
#    'CV001_KM10202389-CV001_KM10202399_GTCGTAAGTGAACCTT-1',
#    'S14_CACTCCAGTGTCGCTG-1',
#    'S21_ATAAGAGGTACATCCA-1',
#    'CV001_KM10202393-CV001_KM10202403_GGCAATTCAAGCCTAT-1',
#    'S7_CGGACACTCCCAACGG-1',
#    'S2_TGCGTGGGTTGAGTTC-1',
#    'CV001_KM10202388-CV001_KM10202398_AATCCAGAGGCCGAAT-1',
#    'CV001_KM10202389-CV001_KM10202399_TGACTAGTCATCTGTT-1',
#    'S3_TCTGGAAGTAACGCGA-1',
#    'CV001_KM10202392-CV001_KM10202402_CATCAGAGTAATTGGA-1',
#    'CV001_KM10202404-CV001_KM10202416_TCCACACCAACAACCT-1',
#    'S10_TGTGGTAGTCACTGGC-1',
#    'S22_CTGCGGACAGGATCGA-1',
#    'S12_AACTGGTCATGAAGTA-1',
#    'S23_CCTACACAGTGGGCTA-1',
#    'S14_GCAGTTAGTACAGTGG-1',
#    'S4_CGATGGCTCGCTGATA-1',
#    'CV001_KM10202391-CV001_KM10202401_GATGAGGTCACATAGC-1',
#    'CV001_KM10202389-CV001_KM10202399_CGAACATTCGTACCGG-1',
#    'CV001_KM10202404-CV001_KM10202416_GGAAAGCCACCGAAAG-1',
#    'CV001_KM10202407-CV001_KM10202419_CGTTAGAAGAGCTTCT-1',
#    'S22_GGTGCGTAGGATATAC-1',
#    'S27_CAGGTGCTCAACGGGA-1',
#    'S18_CCTTCGAAGTGAACAT-1',
#    'S26_TCGCGAGCATGCCACG-1',
#    'S24_AGAATAGCATATGCTG-1',
#    'CV001_KM10202389-CV001_KM10202399_CGCCAAGTCCCTAATT-1',
#    'CV001_KM10202390-CV001_KM10202400_GCTGCGAGTCAGCTAT-1',
#    'S20_TACACGAGTCAGAATA-1',
#    'S25_AACCATGAGGTCGGAT-1',
#    'S26_ATCATGGCATCCTAGA-1',
#    'S13_GGGACCTCAGGGCATA-1',
#    'S1_GTCTTCGAGAAACGCC-1',
#    'S21_AGTGAGGAGGGAACGG-1',
#    'CV001_KM10202386-CV001_KM10202396_CGACCTTTCGTAGGAG-1',
#    'S4_ATAAGAGGTGCGGTAA-1',
#    'S22_GGAAAGCAGTGACTCT-1',
#    'S16_TCGCGTTAGGAATCGC-1',
#    'CV001_KM10202390-CV001_KM10202400_GTCACAACAATTCCTT-1',
#    'S21_CCACTACAGCTGCGAA-1',
#    'S26_TTGCCGTGTTTGACTG-1',
#    'S27_TATTACCCAATCCAAC-1',
#    'S22_ACGGGTCAGTGGGTTG-1',
#    'S1_GCATGATTCACTTCAT-1',
#    'S3_CAGCTGGCACACGCTG-1',
#    'S9_CCTCTGATCGTTTAGG-1',
#    'CV001_KM10202391-CV001_KM10202401_GCTTGAATCGGAGGTA-1',
#    'S24_GTATTCTCATCACAAC-1',
#    'S16_GCTCCTATCAGGTAAA-1',
#    'S2_AAGTCTGAGGACCACA-1',
#    'S17_CACAGTATCTCCGGTT-1',
#    'S11_GACTACAGTATGAATG-1',
#    'CV001_KM10202392-CV001_KM10202402_ACGATACAGTACGTAA-1',
#    'S20_ATCATCTTCTTAGCCC-1',
#    'S21_GTAGGCCTCGTCGTTC-1',
#    'S23_GGGAGATGTTGACGTT-1',
#    'S28_TCGAGGCAGGCTCTTA-1',
#    'CV001_KM10202392-CV001_KM10202402_GAACCTATCAGGCCCA-1',
#    'S22_GCTGCTTGTGGTACAG-1',
#    'S13_TGCCCTACAATGTAAG-1',
#    'S21_CTCTAATTCACGCATA-1',
#    'S3_CGCGGTAGTACCGCTG-1',
#    'S21_GACGTGCTCGAATCCA-1',
#    'CV001_KM10202391-CV001_KM10202401_GGATGTTAGATGCCAG-1',
#    'CV001_KM10202391-CV001_KM10202401_TGTCCCATCCGGCACA-1',
#    'S12_GGTGCGTGTATCTGCA-1',
#    'S17_GGCTGGTGTGAGGGTT-1',
#    'S19_TTGAACGTCTCTAGGA-1',
#    'CV001_KM10202387-CV001_KM10202397_CGAATGTTCGACGGAA-1',
#    'CV001_KM10202404-CV001_KM10202416_GTGCGGTAGCGATATA-1',
#    'S20_AGGTCATTCTAACTGG-1',
#    'S13_GACGCGTAGCTAACAA-1',
#    'S2_ATGGGAGGTTAAGACA-1',
#    'S25_TGAAAGACAGCTCGAC-1',
#    'S26_TTCTACACATCAGTAC-1',
#    'CV001_KM10202387-CV001_KM10202397_TCTCTAAGTCACAAGG-1',
#    'CV001_KM10202388-CV001_KM10202398_ACAGCCGAGTTTGCGT-1',
#    'CV001_KM10202389-CV001_KM10202399_CCAATCCTCGCCATAA-1',
#    'S17_AGAGCTTTCCTAGAAC-1',
#    'S3_AGGCCGTCAAAGCGGT-1',
#    'S15_TGAGAGGGTGTGGTTT-1',
#    'S12_CGAGCACTCGGAAACG-1',
#    'S21_CTCAGAACACCCTATC-1',
#    'S15_GATCGTAGTCAGAATA-1',
#    'S20_TGACTAGGTCACCTAA-1',
#    'S11_TCGCGAGGTAGCACGA-1',
#    'S22_AATCGGTGTTATTCTC-1',
#    'S12_CTTTGCGAGAACAACT-1',
#    'S9_TATGCCCGTAAACCTC-1',
#    'CV001_KM10202388-CV001_KM10202398_ACTGCTCAGTAGGTGC-1',
#    'CV001_KM10202389-CV001_KM10202399_CCTTTCTCATCACCCT-1',
#    'S5_ACCTTTAAGCTGAAAT-1',
#    'CV001_KM10202407-CV001_KM10202419_GAACCTACAATTCCTT-1',
#    'S25_AGTGGGACAGTTTACG-1',
#    'CV001_KM10202405-CV001_KM10202417_TCGTACCCAATTCCTT-1',
#    'S4_TCAGATGAGCGACGTA-1',
#    'S9_ACATGGTCATAGACTC-1',
#    'CV001_KM10202389-CV001_KM10202399_ACTGCTCTCGGACAAG-1',
#    'S13_GTTAAGCAGTTGAGAT-1',
#    'S9_TACGGATGTAGGAGTC-1',
#    'S27_AGAATAGAGAGGTAGA-1',
#    'CV001_KM10202389-CV001_KM10202399_ACTTGTTAGTGCCAGA-1',
#    'S20_CGGACACAGGAGTAGA-1',
#    'S25_CGTCCATTCAGTACGT-1',
#    'S11_GACTAACAGAGACTAT-1',
#    'S13_TGCGGGTGTGTGACGA-1',
#    'S10_AGATTGCTCATGTGGT-1',
#    'S21_CGATGGCAGACTTGAA-1',
#    'S28_TGCACCTTCCAGAAGG-1',
#    'S22_ACTGCTCGTTCTCATT-1',
#    'S13_CGGTTAAAGAGTACCG-1',
#    'S21_GAGTCCGAGGCGATAC-1',
#    'S14_CGGTTAAAGGCCGAAT-1',
#    'S20_CCGTTCAGTTGTCGCG-1',
#    'S14_TGGGAAGAGGGTTTCT-1',
#    'CV001_KM10202388-CV001_KM10202398_GTGCATAAGTGCGATG-1',
#    'CV001_KM10202391-CV001_KM10202401_AACTTTCTCGCGCCAA-1',
#    'CV001_KM10202385-CV001_KM10202395_TCAATCTGTACTCAAC-1',
#    'S25_CTCACACAGCCAGGAT-1',
#    'CV001_KM10202392-CV001_KM10202402_CTTCTCTTCCAAGCCG-1',
#    'S14_CGTCTACAGGCGATAC-1',
#    'S25_TTCTCAAAGCTCCTCT-1',
#    'S21_CTAGTGAAGGCAATTA-1',
#    'CV001_KM10202407-CV001_KM10202419_CATCAGAAGTCACGCC-1',
#    'CV001_KM10202389-CV001_KM10202399_TGCGCAGCATCCGCGA-1',
#    'CV001_KM10202390-CV001_KM10202400_CAGCATAGTTGTCGCG-1',
#    'S10_ACACCGGCACAAGCCC-1',
#    'CV001_KM10202390-CV001_KM10202400_ATTACTCTCACGCATA-1',
#    'CV001_KM10202392-CV001_KM10202402_CTGATCCAGATGAGAG-1',
#    'CV001_KM10202406-CV001_KM10202418_CGCTGGATCCTGCAGG-1',
#    'S22_CTACCCAAGGTCGGAT-1',
#    'S7_CACTCCAAGTGTTGAA-1',
#    'CV001_KM10202388-CV001_KM10202398_CCAATCCCACAGGTTT-1',
#    'S21_CGGACTGCAGGGCATA-1',
#    'S21_CTGATCCAGTGCAAGC-1',
#    'CV001_KM10202389-CV001_KM10202399_TCTCTAAAGGCAAAGA-1',
#    'S13_AATCCAGAGAGTTGGC-1',
#    'S21_GACAGAGCAATACGCT-1',
#    'CV001_KM10202389-CV001_KM10202399_TTCGAAGTCTCCTATA-1',
#    'CV001_KM10202388-CV001_KM10202398_CCTTACGAGCTGCCCA-1',
#    'S25_GCGGGTTAGTTTGCGT-1',
#    'S27_TACTCGCTCACGATGT-1',
#    'S25_TGCGGGTAGCACACAG-1',
#    'S16_GACGTTAGTCCGAACC-1',
#    'CV001_KM10202391-CV001_KM10202401_CCGTTCAAGTTTGCGT-1',
#    'S13_AGAGCTTAGCCATCGC-1',
#    'S23_AAAGCAAAGTCGAGTG-1',
#    'CV001_KM10202391-CV001_KM10202401_AGCGTCGGTCTTTCAT-1',
#    'CV001_KM10202391-CV001_KM10202401_CAGAGAGTCAGGTTCA-1',
#    'CV001_KM10202391-CV001_KM10202401_TAGAGCTTCAAGGCTT-1',
#    'S24_AACCATGCACGGCTAC-1',
#    'S7_CCCATACAGATGTGTA-1',
#    'S21_CATATTCCAAACGCGA-1',
#    'S11_CACCTTGCACATCCGG-1',
# ...
#    'CV001_KM10202391-CV001_KM10202401_ACCTTTAGTCTCTTAT-1',
#    'CV001_KM10202393-CV001_KM10202403_TCAATCTAGGATATAC-1',
#    'CV001_KM10202393-CV001_KM10202403_CCGTTCATCTGAGGGA-1',
#    'S12_TGAGCATTCGGCTACG-1',
#    'S23_GTGTTAGTCGTGGGAA-1',
#    'S23_TTTGCGCAGAAAGTGG-1',
#    'S6_CGAATGTAGTGGGTTG-1',
#    'S11_ATAAGAGTCAGCACAT-1',
#    'CV001_KM10202405-CV001_KM10202417_CAACCAAGTCGCTTTC-1',
#    'S18_ACTTACTGTCCGTCAG-1',
#    'CV001_KM10202390-CV001_KM10202400_AGTGGGATCGAGCCCA-1',
#    'S21_GGGAGATTCTCCGGTT-1',
#    'S16_CATCGGGGTACAAGTA-1',
#    'S22_GCGCAACGTGTTGGGA-1',
#    'S26_AAGGCAGTCTTACCTA-1',
#    'S10_CGCCAAGTCTGCAGTA-1',
#    'CV001_KM10202391-CV001_KM10202401_TTAGGCAGTCAGAGGT-1',
#    'S15_CAAGTTGGTACGAAAT-1',
#    'S27_CTAAGACAGATGTCGG-1',
#    'S26_ATCATCTTCTAACTTC-1',
#    'S12_ACGGGCTGTGGTCTCG-1',
#    'S24_AGCTCTCCAGCGAACA-1',
#    'S1_CCCAATCTCCGCGTTT-1',
#    'S12_AAAGATGCATGTTGAC-1',
#    'CV001_KM10202384-CV001_KM10202394_TAAACCGTCTAAGCCA-1',
#    'CV001_KM10202405-CV001_KM10202417_TAAGTGCCAATAGAGT-1',
#    'CV001_KM10202389-CV001_KM10202399_CACAGGCTCCAGATCA-1',
#    'S17_CTAGCCTGTGAGCGAT-1',
#    'S16_ACTTGTTGTAGCAAAT-1',
#    'S15_CTACACCGTTACGGAG-1',
#    'CV001_KM10202389-CV001_KM10202399_ACGGGTCAGGCAAAGA-1',
#    'CV001_KM10202392-CV001_KM10202402_AAGACCTAGTTCGATC-1',
#    'S9_TTCCCAGTCAACACAC-1',
#    'CV001_KM10202388-CV001_KM10202398_GTCACAACACCTTGTC-1',
#    'CV001_KM10202387-CV001_KM10202397_ATAAGAGAGGGCACTA-1',
#    'CV001_KM10202390-CV001_KM10202400_GTCCTCAGTAGATTAG-1',
#    'S24_TTAGGACGTAAATGTG-1',
#    'CV001_KM10202390-CV001_KM10202400_CTGTGCTGTTATCACG-1',
#    'S22_TAGGCATGTAAGAGAG-1',
#    'CV001_KM10202388-CV001_KM10202398_GTGTTAGCAAGCGAGT-1',
#    'CV001_KM10202389-CV001_KM10202399_CAGCCGAAGTGGAGTC-1',
#    'S23_TTCTCAACATGTAAGA-1',
#    'S24_ACTGTCCCAATAAGCA-1',
#    'S14_GCTCTGTAGGGCTTCC-1',
#    'S13_TGCTGCTAGTTTAGGA-1',
#    'S1_ACTGAGTCACATCTTT-1',
#    'S22_CTGTTTATCAGGCCCA-1',
#    'S24_GTTTCTATCAGATAAG-1',
#    'CV001_KM10202405-CV001_KM10202417_TATGCCCGTAGCCTCG-1',
#    'CV001_KM10202389-CV001_KM10202399_AACCATGCATTAACCG-1',
#    'S23_AGGTCCGTCTTCCTTC-1',
#    'S15_CATCAAGGTCCTCTTG-1',
#    'S23_CTCATTAAGAAGCCCA-1',
#    'S27_AGCTTGACAAAGCGGT-1',
#    'CV001_KM10202393-CV001_KM10202403_GGGCATCCACCTTGTC-1',
#    'S8_GATCTAGCATGGAATA-1',
#    'S23_GCTGCAGAGGTGTGGT-1',
#    'CV001_KM10202386-CV001_KM10202396_CTCACACTCACTCCTG-1',
#    'CV001_KM10202388-CV001_KM10202398_GCTCTGTGTGAAGGCT-1',
#    'S9_TGTGGTAGTATTACCG-1',
#    'S7_GTCCTCACAAGGTGTG-1',
#    'S14_CGTCACTAGATCCCAT-1',
#    'S4_TGACTTTTCTAACTCT-1',
#    'S21_AAGTCTGCACATCTTT-1',
#    'S21_TGATTTCAGGCAATTA-1',
#    'S8_CTAGTGAGTATGAATG-1',
#    'S12_GGGCATCCAACGATCT-1',
#    'S12_CGCTTCAGTCTTGATG-1',
#    'S19_AAGCCGCGTCATGCAT-1',
#    'S21_TAAGCGTCACCATCCT-1',
#    'CV001_KM10202392-CV001_KM10202402_GACGTGCCAAGCCCAC-1',
#    'S12_GGAACTTCACTGTCGG-1',
#    'S18_ACATCAGGTCGATTGT-1',
#    'S23_GTGTTAGTCAGCTCGG-1',
#    'S13_CATATTCTCCTTGCCA-1',
#    'CV001_KM10202393-CV001_KM10202403_GGAATAACAATGGTCT-1',
#    'CV001_KM10202404-CV001_KM10202416_GCATACAGTACGACCC-1',
#    'S6_CATATGGTCCGGGTGT-1',
#    'S5_TCACAAGTCGATGAGG-1',
#    'S23_TGAGAGGCAGTAAGCG-1',
#    'S25_CGAGCCATCGTCTGAA-1',
#    'S13_CACAAACCACTAAGTC-1',
#    'S10_GGCGTGTCACACATGT-1',
#    'S19_AGTCTTTAGACGCTTT-1',
#    'S19_TCGTAGAGTTATCGGT-1',
#    'S28_CCATGTCAGGGCTTGA-1',
#    'S4_CTAATGGCAACGATGG-1',
#    'S11_CCACGGAAGCGTAATA-1',
#    'S5_CTGCGGACATTGGTAC-1',
#    'S2_CGTCCATGTACCCAAT-1',
#    'S15_TTAGGACAGGGATCTG-1',
#    'S4_AGGGATGCAGACGCCT-1',
#    'S21_AACGTTGTCACGAAGG-1',
#    'CV001_KM10202392-CV001_KM10202402_TACGGATAGGATCGCA-1',
#    'S15_AACCATGTCTGTTTGT-1',
#    'S20_CATCCACAGTCGATAA-1',
#    'CV001_KM10202389-CV001_KM10202399_CAAGGCCAGTTTGCGT-1',
#    'S4_AACTCAGAGAGGTACC-1',
#    'S1_CGACCTTAGAGGGCTT-1',
#    'S19_ATGCGATGTCGCTTTC-1',
#    'S3_TTTGGTTGTAAGCACG-1',
#    'S27_TTGGAACGTCATGCAT-1',
#    'S28_ACTTTCAGTAGGACAC-1',
#    'CV001_KM10202404-CV001_KM10202416_AAGGAGCTCGCCAAAT-1',
#    'S26_CTCTAATTCCTTTACA-1',
#    'S3_GCATGATTCACCCTCA-1',
#    'S12_CGATGTATCGAACTGT-1',
#    'S13_GGCAATTTCATCGCTC-1',
#    'CV001_KM10202406-CV001_KM10202418_CCACGGAGTTCCATGA-1',
#    'S11_ATTATCCTCTACTCAT-1',
#    'CV001_KM10202392-CV001_KM10202402_TGGACGCAGAGCTGGT-1',
#    'S17_CCGGGATTCTATCCCG-1',
#    'CV001_KM10202390-CV001_KM10202400_GTCATTTGTGTAAGTA-1',
#    'S2_TACTTACAGAGGTACC-1',
#    'S15_TAGCCGGTCATTTGGG-1',
#    'S4_TTTATGCGTACAGCAG-1',
#    'CV001_KM10202391-CV001_KM10202401_TCCACACAGCGTCAAG-1',
#    'S27_GCAAACTCACCGTTGG-1',
#    'S1_GATCAGTCATTATCTC-1',
#    'S24_TGGCCAGAGGACCACA-1',
#    'S8_CAACCTCTCAAGAAGT-1',
#    'S11_ATCATGGTCATGCATG-1',
#    'CV001_KM10202388-CV001_KM10202398_CGCGTTTTCCGTTGTC-1',
#    'CV001_KM10202392-CV001_KM10202402_GCTCCTACATCCTTGC-1',
#    'S3_CGTAGCGGTGTAACGG-1',
#    'S10_TGCCCTATCGATCCCT-1',
#    'S1_TGCCCTATCAGAGGTG-1',
#    'CV001_KM10202391-CV001_KM10202401_CAGCCGAAGTGTACTC-1',
#    'CV001_KM10202406-CV001_KM10202418_CACCACTGTGAGCGAT-1',
#    'S22_CTACGTCTCTCCAACC-1',
#    'S16_CAAGAAAAGCTTATCG-1',
#    'CV001_KM10202391-CV001_KM10202401_ATAAGAGTCGTCTGCT-1',
#    'S10_GCTTCCAAGTTGAGTA-1',
#    'CV001_KM10202389-CV001_KM10202399_CGTAGGCCATGGTTGT-1',
#    'S16_GCTTGAAGTGCTTCTC-1',
#    'S22_TGAGAGGTCAAACCAC-1',
#    'CV001_KM10202406-CV001_KM10202418_ACATACGGTAAGAGAG-1',
#    'S12_TGCGCAGCAAGACGTG-1',
#    'S19_CCGGTAGCAGGGAGAG-1',
#    'S7_GTGTGCGTCACGATGT-1',
#    'CV001_KM10202406-CV001_KM10202418_CCTAGCTCACAGACAG-1',
#    'CV001_KM10202405-CV001_KM10202417_GCATACAAGCGGCTTC-1',
#    'S20_GTGCGGTGTCGCTTCT-1',
#    'CV001_KM10202393-CV001_KM10202403_GTACTCCTCACGATGT-1',
#    'S10_GCTCTGTGTGTGCGTC-1',
#    'CV001_KM10202392-CV001_KM10202402_GAGCAGACACAACGTT-1',
#    'CV001_KM10202392-CV001_KM10202402_GGGAATGTCTTCATGT-1',
#    'S10_TCGTACCGTCCGTCAG-1',
#    'S19_TAGTGGTCAGGTCCAC-1',
#    'S12_ACTGAGTGTTCACCTC-1',
#    'CV001_KM10202392-CV001_KM10202402_CTGATAGAGCCAGGAT-1',
#    'CV001_KM10202406-CV001_KM10202418_GCTTCCAGTGTGACCC-1',
#    'CV001_KM10202388-CV001_KM10202398_ACGGCCAAGGCCCTTG-1',
#    'S19_ACGGGTCTCATGCTCC-1',
#    'S19_AGGCCACGTTGACGTT-1',
#    'S21_GTCCTCATCTCAAGTG-1',
#    'S21_TCTCATAGTGGCGAAT-1',
#    'S2_GAGGTGAAGTATCTCG-1',
#    'S24_AGGCCACGTAAGCACG-1',
#    'S18_CTCTAATGTGCTCTTC-1',
#    'CV001_KM10202390-CV001_KM10202400_AAAGCAATCACTTATC-1',
#    'S7_AACGTTGCAAGCGAGT-1',
#    'S4_AAACGGGGTGGCCCTA-1',
#    'S20_AATCGGTCATGGAATA-1',
#    'CV001_KM10202393-CV001_KM10202403_GGTGCGTGTTCCAACA-1',
#    'S11_TAAGTGCTCGTACGGC-1',
#    'S6_CCCAATCTCAGGATCT-1',
#    'CV001_KM10202393-CV001_KM10202403_CACACTCAGTGGAGTC-1',
#    'S11_GGACAGAAGTCGAGTG-1',
#    'CV001_KM10202385-CV001_KM10202395_AGGTCCGTCGCATGGC-1',
#    'CV001_KM10202391-CV001_KM10202401_CTAGTGACATTGTGCA-1',
#    'CV001_KM10202404-CV001_KM10202416_TTTGCGCCATATACGC-1',
#    'S6_TGAGAGGAGCGATATA-1',
#    'CV001_KM10202393-CV001_KM10202403_TAAGTGCGTTATGTGC-1',
#    'S19_ACGCAGCTCTCCAACC-1',
#    'CV001_KM10202386-CV001_KM10202396_ACTTACTGTGACTACT-1',
#    'S15_ACTGAACAGAACAACT-1',
#    'CV001_KM10202386-CV001_KM10202396_ACAGCCGCAGGATTGG-1',
#    'CV001_KM10202404-CV001_KM10202416_CAGATCATCCCAAGAT-1',
#    'S15_CTGGTCTCATCTGGTA-1',
#    'S24_CCTCAGTCAGTGAGTG-1',
#    'S11_ACGTCAACACAACTGT-1',
#    'S4_GGTGCGTTCAGCACAT-1',
#    'S13_GATGAAAAGACTGTAA-1',
#    'S20_TGAGGGAAGCTAGTCT-1',
#    'CV001_KM10202389-CV001_KM10202399_CTCACACTCCACGTTC-1',
#    'S5_TATCAGGCAGATCTGT-1',
#    'S10_GATCTAGAGCACCGTC-1',
#    'S6_CGTTAGACAAGCCGCT-1',
#    'S11_GTGCGGTAGTGCGATG-1',
#    'CV001_KM10202385-CV001_KM10202395_AGCGTATCACGAAGCA-1',
#    'CV001_KM10202391-CV001_KM10202401_CCACCTAGTTGTGGAG-1',
#    'S9_CGACCTTCATTGGCGC-1',
#    'CV001_KM10202407-CV001_KM10202419_ACGCAGCTCCTAGAAC-1',
#    'S23_GTCATTTTCCGCGGTA-1',
#    'S28_GTAACTGTCGGAAATA-1',
#    'S8_TGACAACGTTGTGGAG-1',
#    'S23_TATGCCCAGAGTCTGG-1',
#    'CV001_KM10202389-CV001_KM10202399_TTAACTCGTCAAGCGA-1',
#    'S18_CATGACAAGTCCTCCT-1',
#    'S24_TGACAACAGCGGCTTC-1',
#    'S13_ATTGGACCACAACGTT-1',
#    'CV001_KM10202405-CV001_KM10202417_GTTTCTACACGGCGTT-1',
#    'S7_TGCGGGTTCTACCAGA-1',
#    'S23_AACTCAGCAGGTTTCA-1',
#    'CV001_KM10202406-CV001_KM10202418_GCATGATCAATCGGTT-1',
#    'CV001_KM10202391-CV001_KM10202401_CCTTCGACAATCGGTT-1',
#    'S24_AATCCAGAGTCCCACG-1',
#    'S27_GCGACCAAGAGGTAGA-1',
#    'CV001_KM10202387-CV001_KM10202397_CTGCGGACAAGCGCTC-1',
#    'S7_TAGAGCTCATTCTTAC-1',
#    'S13_GAATGAAAGTAGGTGC-1',
#    'S24_TATTACCGTAGTGAAT-1',
#    'S20_GCCAAATCAAGTTGTC-1',
#    'S12_GGCAATTCATGCAACT-1',
#    'CV001_KM10202393-CV001_KM10202403_ATTGGACCAGGCTGAA-1',
#    'S13_TGACAACCACCGAAAG-1',
#    'CV001_KM10202388-CV001_KM10202398_CCCATACTCAATACCG-1',
#    'S22_AGGGATGTCAGGCAAG-1',
#    'S6_ATGCGATTCCACGCAG-1',
#    'S8_CTCGTACAGTGTACCT-1',
#    'S12_GAATGAAGTAAGTAGT-1',
#    'S19_GAAGCAGCAAACAACA-1',
#    'S27_CGCTGGAAGGTGCTAG-1',
#    'S11_GCTTGAAGTTTGTGTG-1',
#    'S24_TGACGGCCAACACCTA-1',
#    'CV001_KM10202392-CV001_KM10202402_GAAACTCTCGAGGTAG-1',
#    'S23_GGACATTGTAGTGAAT-1',
#    'S18_AGTGTCATCTTGTTTG-1',
#    'S14_AACTCTTGTCTTCTCG-1',
#    'S5_CATGGCGAGTGTACGG-1',
#    'S25_AACTTTCTCCACTGGG-1',
#    'S16_CTGCCTACATAAGACA-1',
#    'CV001_KM10202384-CV001_KM10202394_GCATGCGGTGCACTTA-1',
#    'CV001_KM10202387-CV001_KM10202397_TCTTCGGTCGGAGGTA-1',
#    'CV001_KM10202390-CV001_KM10202400_TCGCGAGCATTTGCTT-1',
#    'S15_CATCAAGCAGATCTGT-1',
#    'S11_GAACGGATCGCCATAA-1',
#    'S27_ACATCAGTCTGTGCAA-1',
#    'CV001_KM10202393-CV001_KM10202403_GAACCTAGTAATTGGA-1',
#    'S2_AGGGAGTGTGATGTCT-1',
#    'CV001_KM10202392-CV001_KM10202402_GCTGCGATCTTATCTG-1',
#    'CV001_KM10202405-CV001_KM10202417_CGGACACTCTGTCTCG-1',
#    'S11_CTACATTAGAATGTGT-1',
#    'S2_CTGATCCAGCCATCGC-1',
#    'S20_CAGCAGCTCTCCGGTT-1',
#    'S24_CCTACACCAATCTACG-1',
#    'S7_CGATCGGAGGCCCTCA-1',
#    'S24_TAGAGCTTCACAACGT-1',
#    'CV001_KM10202392-CV001_KM10202402_TAGTTGGAGGCATGTG-1',
#    'S13_TACCTATAGGCTCATT-1',
#    'S27_CCGGTAGCAAGTCATC-1',
#    'S13_GATCAGTCAATAGCGG-1',
#    'S27_TCTCTAATCGTAGATC-1',
#    'S19_GGTGAAGCACGTCTCT-1',
#    'S22_AACTCCCGTAGGGACT-1',
#    'S25_ACTGAGTTCATCGCTC-1',
#    'S6_CGACCTTAGATATACG-1',
#    'S6_CGTTAGAGTGTCGCTG-1',
#    'S7_CATGACAAGCTAGCCC-1',
#    'CV001_KM10202406-CV001_KM10202418_GCATGCGAGATAGGAG-1',
#    'S18_AACCGCGGTCTCTCTG-1',
#    'S17_GACTACATCAACGGGA-1',
#    'S25_GCAGCCAAGTGGTCCC-1',
#    'S6_TGCTACCGTATTCGTG-1',
#    'S9_CTGCCTAGTTGGTTTG-1',
#    'CV001_KM10202385-CV001_KM10202395_TCTCATACAGCCTTGG-1',
#    'S27_CACCACTTCCTGCAGG-1',
#    'S4_TCCACACGTGGGTCAA-1',
#    'S20_CGTGTCTAGCGGCTTC-1',
#    'S27_CATGACAAGTGTACGG-1',
#    'S12_ATGGGAGAGATGTGGC-1',
#    'S12_TACTTACGTGTTAAGA-1',
#    'S5_CGTGAGCAGGCACATG-1',
#    'S16_CTTACCGAGATGCCAG-1',
#    'S23_CGATGTACATCACAAC-1',
#    'S11_GACGGCTCAGTAAGAT-1',
#    'CV001_KM10202404-CV001_KM10202416_GGAACTTCACTCAGGC-1',
#    'CV001_KM10202389-CV001_KM10202399_CTACCCAAGACACGAC-1',
#    'S11_GGACATTCAATGGATA-1',
#    'CV001_KM10202393-CV001_KM10202403_GTGCGGTAGTAGTGCG-1',
#    'S2_GGCTGGTAGCTGCGAA-1',
#    'CV001_KM10202390-CV001_KM10202400_AAATGCCAGTCGATAA-1',
#    'S14_GATGAAAAGGAGTAGA-1',
#    'S25_CAAGAAAGTATCGCAT-1',
#    'CV001_KM10202405-CV001_KM10202417_TCCACACCAAGTAGTA-1',
#    'S2_ACATGGTGTATAGGGC-1',
#    'CV001_KM10202392-CV001_KM10202402_CACATAGTCATTTGGG-1',
#    'S19_CAACCAAAGCCACGCT-1',
#    'S21_GCGGGTTTCCTAAGTG-1',
#    'CV001_KM10202406-CV001_KM10202418_GGAACTTAGGAGCGTT-1',
#    'S2_GTCTTCGAGGTTCCTA-1',
#    'S19_GGAAAGCGTACGAAAT-1',
#    'S24_GTCAAGTCATGTCCTC-1',
#    'S27_TCTTTCCAGCCGGTAA-1',
#    'S11_AACTCCCAGTCGATAA-1',
#    'S17_GGTGTTACAGACAAGC-1',
#    'CV001_KM10202392-CV001_KM10202402_CCCAATCGTCAGAAGC-1',
#    'S23_GGAGCAAAGATTACCC-1',
#    'CV001_KM10202392-CV001_KM10202402_GCATACATCAGAGGTG-1',
#    'CV001_KM10202392-CV001_KM10202402_TCTCATAGTAGCGTGA-1',
#    'S3_GATGCTATCCCATTAT-1',
#    'CV001_KM10202393-CV001_KM10202403_CGGACTGGTACAGTTC-1',
#    'S5_TGGTTAGTCAATCACG-1',
#    'S4_TTAGTTCAGTCATGCT-1',
#    'S11_GTGCTTCAGGAGTACC-1',
#    'CV001_KM10202391-CV001_KM10202401_TCGTAGAAGTAGCGGT-1',
#    'CV001_KM10202393-CV001_KM10202403_GGGAATGCAATCACAC-1',
#    'S14_CTCGAAACACCCATTC-1',
#    'S7_CCTACCATCTGATACG-1',
#    'S10_TGCGTGGCAATGTAAG-1',
#    'S10_GGCGACTCATGGAATA-1',
#    'S16_GCGCAGTGTCTGGAGA-1',
#    'S11_GACACGCAGGGTTCCC-1',
#    'CV001_KM10202392-CV001_KM10202402_CATCAAGTCGGTTCGG-1',
#    'CV001_KM10202391-CV001_KM10202401_ACCCACTCATACGCTA-1',
#    'S8_TTTGTCACATTACGAC-1',
#    'S7_CCAGCGAAGCTGAAAT-1',
#    'S4_CATCCACGTCGAAAGC-1',
#    'CV001_KM10202386-CV001_KM10202396_ACGGGCTCATTGAGCT-1',
#    'S1_ACATCAGGTGTGACGA-1',
#    'CV001_KM10202392-CV001_KM10202402_TTAGTTCGTAACGACG-1',
#    'CV001_KM10202388-CV001_KM10202398_GCGCGATTCCACTGGG-1',
#    'CV001_KM10202388-CV001_KM10202398_ACGGGCTGTCGGGTCT-1',
#    'CV001_KM10202389-CV001_KM10202399_TGGCCAGCAGGGATTG-1',
#    'S8_GTTCGGGAGTGTACGG-1',
#    'S10_CGTCTACAGGTGCTAG-1',
#    'S6_TCTATTGGTACCGTAT-1',
#    'S24_ACGATGTAGATTACCC-1',
#    'S8_CAGAGAGGTTATCGGT-1',
#    'S24_GCAGTTATCAACCAAC-1',
#    'CV001_KM10202389-CV001_KM10202399_GAAACTCAGTTCGATC-1',
#    'CV001_KM10202390-CV001_KM10202400_GGACAAGGTCACTGGC-1',
#    'S20_TGGGAAGCAGGCTGAA-1',
#    'S9_AGCATACGTGCAGACA-1',
#    'S1_TAGTGGTTCGCCGTGA-1',
#    'CV001_KM10202388-CV001_KM10202398_CTTGGCTGTCAGCTAT-1',
#    'CV001_KM10202392-CV001_KM10202402_TGCTACCTCGGGAGTA-1',
#    'CV001_KM10202389-CV001_KM10202399_GTCGGGTAGTGAACGC-1',
#    'S6_GACTAACCACTGTCGG-1',
#    'CV001_KM10202386-CV001_KM10202396_GAACGGACATGAACCT-1',
#    'S1_GCATACAAGCGTTGCC-1',
#    'S17_GGCTGGTAGATATACG-1',
#    'S21_CTCGTACTCCCTCAGT-1',
#    'CV001_KM10202388-CV001_KM10202398_ACGGGTCTCGTTTAGG-1',
#    'CV001_KM10202392-CV001_KM10202402_ACTGAGTAGATGTTAG-1',
#    'S1_TTAGTTCGTAGAGGAA-1',
#    'CV001_KM10202388-CV001_KM10202398_TCCACACGTCAGAAGC-1',
#    'CV001_KM10202391-CV001_KM10202401_AGACGTTCACGAGGTA-1',
#    'S1_TACTTACGTCATGCAT-1',
#    'S10_CACATTTGTACCGCTG-1',
#    'S19_TACTCATTCAAGGCTT-1',
#    'S4_AGCTTGATCATCGATG-1',
#    'CV001_KM10202389-CV001_KM10202399_CTTAACTCACCAACCG-1',
#    'CV001_KM10202404-CV001_KM10202416_CCTTCGAAGTCCATAC-1',
#    'S23_GATCGATTCTACCAGA-1',
#    'S11_CGGTTAATCTGAAAGA-1',
#    'S11_ACATCAGGTTCGCGAC-1',
#    'CV001_KM10202407-CV001_KM10202419_ACTATCTTCTCTGAGA-1',
#    'CV001_KM10202385-CV001_KM10202395_CTAGAGTCACCGATAT-1',
#    'CV001_KM10202392-CV001_KM10202402_TGACTAGTCGTCCGTT-1',
#    'S22_AGTGGGATCCTTTCTC-1',
#    'CV001_KM10202388-CV001_KM10202398_AGTTGGTTCTGGTATG-1',
#    'S1_CTCGTACGTGTCTGAT-1',
#    'CV001_KM10202387-CV001_KM10202397_AGTCTTTTCTGAGTGT-1',
#    'S9_GAACATCGTGCACTTA-1',
#    'CV001_KM10202404-CV001_KM10202416_GTAGTCAAGCCCAATT-1',
#    'CV001_KM10202393-CV001_KM10202403_CATTATCCAGTGGAGT-1',
#    'S3_TGGCCAGTCAGGCGAA-1',
#    'S15_GAGGTGAGTCCGAACC-1',
#    'S18_TCCACACCAGCCACCA-1',
#    'S24_ATCACGAGTCCGAAGA-1',
#    'S1_TAAACCGTCCTTGCCA-1',
#    'CV001_KM10202406-CV001_KM10202418_CATCCACCATTGGGCC-1',
#    'S12_TTGTAGGTCGTGGTCG-1',
#    'CV001_KM10202387-CV001_KM10202397_CTAACTTTCCTGTACC-1',
#    'CV001_KM10202393-CV001_KM10202403_CCACTACAGCCGGTAA-1',
#    'S4_ATGAGGGAGATCCCGC-1',
#    'S14_GTGTTAGTCATGTCCC-1',
#    'S20_GGAATAAGTTAAGACA-1',
#    'S1_GATTCAGGTTTAGGAA-1',
#    'CV001_KM10202406-CV001_KM10202418_TTCGGTCCAGCTCGCA-1',
#    'S22_CTGCGGATCAGCTCGG-1',
#    'CV001_KM10202385-CV001_KM10202395_GACACGCCAAACTGCT-1',
#    'S18_CATCCACTCCGTAGTA-1',
#    'S15_ACGATGTGTCCGAACC-1',
#    'CV001_KM10202406-CV001_KM10202418_TACGGATAGCTCAACT-1',
#    'S23_TTCCCAGTCGTGGGAA-1',
#    'CV001_KM10202405-CV001_KM10202417_CTGTTTATCTCATTCA-1',
#    'S1_TACGGTAAGGCTCATT-1',
#    'S28_ATAGACCTCGATAGAA-1',
#    'CV001_KM10202390-CV001_KM10202400_GGTGTTATCCCAAGTA-1',
#    'CV001_KM10202407-CV001_KM10202419_CAAGAAAAGGCCGAAT-1',
#    'CV001_KM10202385-CV001_KM10202395_ATGTGTGCACGTCTCT-1',
#    'S20_CGTGTCTCAGACTCGC-1',
#    'CV001_KM10202405-CV001_KM10202417_CATGCCTTCAGCTTAG-1',
#    'S19_GTAACTGTCTTCCTTC-1',
#    'CV001_KM10202404-CV001_KM10202416_GAACGGACATCTCGCT-1',
#    'CV001_KM10202404-CV001_KM10202416_CTCTAATCAATTCCTT-1',
#    'S15_CACCTTGGTCCATGAT-1',
#    'S24_GATGAGGGTTAAGATG-1',
#    'S5_TACTTACAGCGGCTTC-1',
#    'CV001_KM10202405-CV001_KM10202417_GTACTCCCATCCAACA-1',
#    ...],
#   'cell_set_accession': 'annotation_detailed_fullNames:098e3ca532',
#   'cell_ontology_term_id': 'CL:0000907',
#   'cell_ontology_term': 'central memory CD8-positive, alpha-beta T cell',
#   'author_annotation_fields': {'SURFACE PROTEIN MARKERS': 'CD3D, CD8A, CD27, IL7R, CD45RO',
#    'BCR / TCR': 'TCR'},
#   'parent_cell_set_name': 'T CD8+',
#   'parent_cell_set_accession': 'annotation_broad:75baed17b1'}]
