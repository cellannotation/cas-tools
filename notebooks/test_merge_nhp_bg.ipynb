# %%
import os
import anndata
import pandas as pd

from cas.file_utils import read_json_file, read_cas_from_anndata
from cas.anndata_conversion import merge_cas_object

# %% [markdown]
# Read `NHP Basal Ganglia` dataset

# %%
anndata_obj = anndata.read_h5ad("/Volumes/osumi-sutherland/BICAN/tdt_datasets/nhp50930-982a-11ee-b9d1-0242ac120002.h5ad", backed="r")

# %%
pd.set_option('display.max_columns', None)
anndata_obj.obs
# Out:
#                                                Class Neighborhood  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408    IN         TAC3
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408    IN         TAC3
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408    IN         TAC3
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408    IN          SST
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408    IN         TAC3
# ...                                              ...          ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938    NN       Oligos
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938    NN       Oligos
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938    NN    Microglia
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938    NN       Oligos
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938    NN       Oligos
#
#                                                        Subclass  Supertype  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408  LHX6-TAC3-PLPP4        NaN
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408  LHX6-TAC3-PLPP4        NaN
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408  LHX6-TAC3-PLPP4        NaN
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408        SST_Chodl        NaN
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408  LHX6-TAC3-PLPP4        NaN
# ...                                                         ...        ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938           Oligos        NaN
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938           Oligos        NaN
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938        Microglia        NaN
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938           Oligos        NaN
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938           Oligos        NaN
#
#                                                 Celltype Cluster        Donor  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408       NaN    1_IN   Q21.26.010
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408       NaN    1_IN   Q21.26.010
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408       NaN    1_IN   Q21.26.010
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408       NaN    5_IN   Q21.26.010
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408       NaN    1_IN   Q21.26.010
# ...                                                  ...     ...          ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938       NaN   21_NN  QM21.26.003
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938       NaN   20_NN  QM21.26.003
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938       NaN    6_NN  QM21.26.003
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938       NaN    8_NN  QM21.26.003
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938       NaN   20_NN  QM21.26.003
#
#                                                    Load Sex  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408  810_B02   M
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408  810_B02   M
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408  810_B02   M
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408  810_B02   M
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408  810_B02   M
# ...                                                 ...  ..
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938  954_A06
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938  954_A06
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938  954_A06
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938  954_A06
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938  954_A06
#
#                                                           Species  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408  Macaca nemestrina
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408  Macaca nemestrina
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408  Macaca nemestrina
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408  Macaca nemestrina
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408  Macaca nemestrina
# ...                                                           ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938     Macaca mulatta
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938     Macaca mulatta
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938     Macaca mulatta
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938     Macaca mulatta
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938     Macaca mulatta
#
#                                                      Region  nCount_RNA  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408  Macaque PuR      8152.0
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408  Macaque PuR      7061.0
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408  Macaque PuR      6875.0
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408  Macaque PuR     15306.0
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408  Macaque PuR      4862.0
# ...                                                     ...         ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938  Macaque GPe      6557.0
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938  Macaque GPe      3169.0
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938  Macaque GPe      6681.0
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938  Macaque GPe     11648.0
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938  Macaque GPe      6163.0
#
#                                                 nFeature_RNA  Core_cell_score  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408          3305              0.0
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408          2945              0.0
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408          3011              0.0
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408          4425              0.0
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408          2472              0.0
# ...                                                      ...              ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938          2458              0.0
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938          1558              0.0
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938          2440              0.0
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938          3516              0.0
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938          2481              0.0
#
#                                                 Taxonomy  Taxonomy_entropy
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408     False             False
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408      True              True
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408     False             False
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408      True              True
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408      True              True
# ...                                                  ...               ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938      True              True
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938      True              True
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938     False             False
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938     False             False
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938     False             False
#
# [344471 rows x 16 columns]

# %% [markdown]
# **!!Manual Step!!:** Download the related CAS file from the private repo (https://github.com/brain-bican/nhp_basal_ganglia_taxonomy/blob/main/CCN20230601.json) and place into the `notebooks` folder

# %%
cas = read_json_file("CCN20230601.json")

# %% [markdown]
# Merge CAS to AnnData

# %%
merge_cas_object(cas, anndata_obj, True, "./nhp_bg_merged.h5ad")
# Out:
# Dopaminergic cell ids from CAS match with the cell ids in Dopimanergic from anndata. But they have different cell label.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /Users/hk9/workspaces/workspace2/cas-tools/notebooks/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# Rename `Dopimanergic` to `Dopaminergic` in the AnnData.

# %%
# anndata_obj.obs.loc[anndata_obj.obs['Neighborhood'].isin(['Dopimanergic'])] = 'Dopaminergic'
anndata_obj.obs['Neighborhood'] = anndata_obj.obs['Neighborhood'].cat.rename_categories({'Dopimanergic': 'Dopaminergic'})

# %%
merge_cas_object(cas, anndata_obj, False, "./nhp_bg_merged.h5ad")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 merge_cas_object(cas, anndata_obj, True, "./nhp_bg_merged.h5ad")
#
# File ~/workspaces/workspace2/cas-tools/notebooks/venv/lib/python3.9/site-packages/cas/anndata_conversion.py:81, in merge_cas_object(input_json, input_anndata, validate, output_file_name)
#      70 def merge_cas_object(input_json: dict, input_anndata: Optional[anndata.AnnData], validate: bool, output_file_name: str):
#      71     """
#      72     Tests if CAS json and AnnData are compatible and merges CAS into AnnData if possible.
#      73
#    (...)
#      79
#      80     """
# ---> 81     test_compatibility(input_anndata, input_json, validate)
#      83     save_cas_to_uns(input_anndata, input_json)
#      84     write_anndata(input_anndata, output_file_name)
#
# File ~/workspaces/workspace2/cas-tools/notebooks/venv/lib/python3.9/site-packages/cas/anndata_conversion.py:100, in test_compatibility(input_anndata, input_json, validate)
#      97 validate_cell_ids(input_anndata, annotations, validate)
#      99 matching_obs_keys = get_matching_obs_keys(input_anndata, input_json)
# --> 100 check_labelsets(input_json, input_anndata, matching_obs_keys, validate)
#
# File ~/workspaces/workspace2/cas-tools/notebooks/venv/lib/python3.9/site-packages/cas/anndata_conversion.py:120, in check_labelsets(cas_json, input_anndata, matching_obs_keys, validate)
#     118     handle_matching_labelset(ann, cell_label, input_anndata, validate)
#     119 elif cell_label == ann[CELL_LABEL]:
# --> 120     handle_non_matching_labelset(ann, validate, derived_cell_ids)
#
# TypeError: handle_non_matching_labelset() missing 1 required positional argument: 'derived_cell_ids'

# %%
# anndata_merged = anndata.read_h5ad("./nhp_bg_merged.h5ad", backed="r")
anndata_merged = anndata.read_h5ad("/Users/hk9/tdt_datasets/nhp_bg_merged.h5ad", backed="r")
anndata_merged.obs
# Out:
#                                                Class Neighborhood  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408    IN         TAC3
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408    IN         TAC3
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408    IN         TAC3
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408    IN          SST
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408    IN         TAC3
# ...                                              ...          ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938    NN       Oligos
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938    NN       Oligos
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938    NN    Microglia
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938    NN       Oligos
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938    NN       Oligos
#
#                                                        Subclass  Supertype  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408  LHX6-TAC3-PLPP4        NaN
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408  LHX6-TAC3-PLPP4        NaN
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408  LHX6-TAC3-PLPP4        NaN
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408        SST_Chodl        NaN
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408  LHX6-TAC3-PLPP4        NaN
# ...                                                         ...        ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938           Oligos        NaN
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938           Oligos        NaN
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938        Microglia        NaN
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938           Oligos        NaN
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938           Oligos        NaN
#
#                                                 Celltype Cluster        Donor  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408       NaN    1_IN   Q21.26.010
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408       NaN    1_IN   Q21.26.010
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408       NaN    1_IN   Q21.26.010
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408       NaN    5_IN   Q21.26.010
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408       NaN    1_IN   Q21.26.010
# ...                                                  ...     ...          ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938       NaN   21_NN  QM21.26.003
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938       NaN   20_NN  QM21.26.003
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938       NaN    6_NN  QM21.26.003
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938       NaN    8_NN  QM21.26.003
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938       NaN   20_NN  QM21.26.003
#
#                                                    Load Sex  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408  810_B02   M
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408  810_B02   M
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408  810_B02   M
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408  810_B02   M
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408  810_B02   M
# ...                                                 ...  ..
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938  954_A06
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938  954_A06
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938  954_A06
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938  954_A06
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938  954_A06
#
#                                                           Species  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408  Macaca nemestrina
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408  Macaca nemestrina
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408  Macaca nemestrina
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408  Macaca nemestrina
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408  Macaca nemestrina
# ...                                                           ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938     Macaca mulatta
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938     Macaca mulatta
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938     Macaca mulatta
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938     Macaca mulatta
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938     Macaca mulatta
#
#                                                      Region  nCount_RNA  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408  Macaque PuR      8152.0
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408  Macaque PuR      7061.0
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408  Macaque PuR      6875.0
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408  Macaque PuR     15306.0
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408  Macaque PuR      4862.0
# ...                                                     ...         ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938  Macaque GPe      6557.0
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938  Macaque GPe      3169.0
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938  Macaque GPe      6681.0
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938  Macaque GPe     11648.0
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938  Macaque GPe      6163.0
#
#                                                 nFeature_RNA  Core_cell_score  \
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408          3305              0.0
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408          2945              0.0
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408          3011              0.0
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408          4425              0.0
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408          2472              0.0
# ...                                                      ...              ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938          2458              0.0
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938          1558              0.0
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938          2440              0.0
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938          3516              0.0
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938          2481              0.0
#
#                                                 Taxonomy  Taxonomy_entropy
# exp_component_name
# AAACCAACATGCAACC-L8XR_210909_02_E08-1135448408     False             False
# AAACGCGCACCAGGTT-L8XR_210909_02_E08-1135448408      True              True
# AAATCCGGTTGTTGGA-L8XR_210909_02_E08-1135448408     False             False
# AAATGGCCAGCTTAAT-L8XR_210909_02_E08-1135448408      True              True
# AACAGGATCGGTTTCC-L8XR_210909_02_E08-1135448408      True              True
# ...                                                  ...               ...
# TTTCCGGGTGACCTGG-L8XR_211124_02_B11-1145519938      True              True
# TTTCCTGAGAGGAGGA-L8XR_211124_02_B11-1145519938      True              True
# TTTGAGTCAAGTGTCC-L8XR_211124_02_B11-1145519938     False             False
# TTTGCATTCATAAGCC-L8XR_211124_02_B11-1145519938     False             False
# TTTGTGTTCCAAACAC-L8XR_211124_02_B11-1145519938     False             False
#
# [344471 rows x 16 columns]

# %%
anndata_merged.uns
# Out:
# {'cas': '{"author_name": "Nelson Johansen", "labelset": [{"name": "Cluster", "description": "", "rank": "0"}, {"name": "Subclass", "description": "", "rank": "1"}, {"name": "Neighborhood", "description": "", "rank": "2"}, {"name": "Class", "description": "", "rank": "3"}], "annotations": [{"labelset": "Cluster", "cell_label": "1_MSN", "cell_set_accession": "AIT115_1", "parent_cell_set_name": "D1-Matrix", "parent_cell_set_accession": "AIT115_300", "user_annotations": [{"labelset": "Supertype", "cell_label": "1_MSN"}, {"labelset": "region.info _Frequency_", "cell_label": "PuR(0.52) | CaH(0.39)"}, {"labelset": "Cluster size", "cell_label": "16393"}, {"labelset": "Gene counts", "cell_label": "3798"}, {"labelset": "UMI counts", "cell_label": "13134"}, {"labelset": "AIT21_ABC_atlas__subclass_homology", "cell_label": "STR D1 Gaba"}, {"labelset": "Binary genes", "cell_label": "EPYC, EBF1, TAC1, RELN, SEMA3A, GULP1, GPC5, CNTNAP4, KCNIP4, DSCAM"}, {"labelset": "NSForest markers _Combo_", "cell_label": "EPYC, RELN, GULP1"}, {"labelset": "NSForest F1 score", "cell_label": "0.577393009"}, {"labelset": "Curated markers", "cell_label": "None"}, {"labelset": "Notes", "cell_label": "None"}, {"labelset": "history", "cell_label": "None"}]}, {"labelset": "Cluster", "cell_label": "2_MSN", "cell_set_accession": "AIT115_2", "parent_cell_set_name": "D1-Matrix", "parent_cell_set_accession": "AIT115_300", "user_annotations": [{"labelset": "Supertype", "cell_label": "None"}, {"labelset": "region.info _Frequency_", "cell_label": "CaH(0.95)"}, {"labelset": "Cluster size", "cell_label": "1642"}, {"labelset": "Gene counts", "cell_label": "3720"}, {"labelset": "UMI counts", "cell_label": "11928"}, {"labelset": "AIT21_ABC_atlas__subclass_homology", "cell_label": "STR D1 Gaba"}, {"labelset": "Binary genes", "cell_label": "ZNF484, SEMA3E, TOX3, RELN, SEMA3A, RAP1GAP, CNTNAP4, FHOD3, PSD3, ZBTB20"}, {"labelset": "NSForest markers _Combo_", "cell_label": "SEMA3E, TOX3, RELN, RAP1GAP"}, {"labelset": "NSForest F1 score", "cell_label": "0.297633569"}, {"labelset": "Curated markers", "cell_label": "None"}, {"labelset": "Notes", "cell_label": "None"}, {"labelset": "history", "cell_label": "None"}]}, {"labelset": "Cluster", "cell_label": "3_MSN", "cell_set_accession": "AIT115_3", "parent_cell_set_name": "D1-Matrix", "parent_cell_set_accession": "AIT115_300", "user_annotations": [{"labelset": "Supertype", "cell_label": "None"}, {"labelset": "region.info _Frequency_", "cell_label": "CaH(0.59) | PuR(0.38)"}, {"labelset": "Cluster size", "cell_label": "226"}, {"labelset": "Gene counts", "cell_label": "4152"}, {"labelset": "UMI counts", "cell_label": "15628"}, {"labelset": "AIT21_ABC_atlas__subclass_homology", "cell_label": "STR D1 Gaba"}, {"labelset": "Binary genes", "cell_label": "RELN, FGGY, CDH10, LRMDA, VRK1, ASAP2, CALN1, RALYL"}, {"labelset": "NSForest markers _Combo_", "cell_label": "RELN, FGGY, CDH10, LRMDA, VRK1, ASAP2"}, {"labelset": "NSForest F1 score", "cell_label": "0.105531295"}, {"labelset": "Curated markers", "cell_label": "None"}, {"labelset": "Notes", "cell_label": "None"}, {"labelset": "history", "cell_label": "None"}]}, {"labelset": "Cluster", "cell_label": "4_MSN", "cell_set_accession": "AIT115_4", "parent_cell_set_name": "D1-Matrix", "parent_cell_set_accession": "AIT115_300", "user_annotations": [{"labelset": "Supertype", "cell_label": "None"}, {"labelset": "region.info _Frequency_", "cell_label": "PuR(0.91) | CaH(0.08)"}, {"labelset": "Cluster size", "cell_label": "974"}, {"labelset": "Gene counts", "cell_label": "4827"}, {"labelset": "UMI counts", "cell_label": "23573"}, {"labelset": "AIT21_ABC_atlas__subclass_homology", "cell_label": "STR D1 Gaba"}, {"labelset": "Binary genes", "cell_label": "EVC, RXFP2, SP100, ETV5, SEMA3E, HTR2C, RELN, RGS6, MAML2, CLSTN2"}, {"labelset": "NSForest markers _Combo_", "cell_label": "EVC, RXFP2, ETV5, SEMA3E"}, {"labelset": "NSForest F1 score", "cell_label": "0.386255924"}, {"labelset": "Curated markers", "cell_labe ...
#  'hvg': {'flavor': 'seurat_v3'},
#  'neighbors': {'connectivities_key': 'connectivities',
#   'distances_key': 'distances',
#   'params': {'method': 'umap',
#    'metric': 'euclidean',
#    'n_neighbors': 15,
#    'random_state': 0,
#    'use_rep': 'X_scVI'}}}

# %% [markdown]
# Read CAS from AnnData `uns`

# %%
# cas_read = read_cas_from_anndata("./merged.h5ad")
cas_read = read_cas_from_anndata("/Users/hk9/tdt_datasets/nhp_bg_merged.h5ad")
df = cas_read.get_all_annotations()
df
# Out:
#          labelset cell_label cell_set_accession cell_fullname  \
# 0         Cluster      1_MSN           AIT115_1          None
# 1         Cluster      2_MSN           AIT115_2          None
# 2         Cluster      3_MSN           AIT115_3          None
# 3         Cluster      4_MSN           AIT115_4          None
# 4         Cluster      5_MSN           AIT115_5          None
# ..            ...        ...                ...           ...
# 350  Neighborhood   Ependyma         AIT115_365          None
# 351         Class        MSN         AIT115_366          None
# 352         Class   Granular         AIT115_367          None
# 353         Class         IN         AIT115_368          None
# 354         Class         NN         AIT115_369          None
#
#     cell_ontology_term_id cell_ontology_term rationale rationale_dois  \
# 0                    None               None      None           None
# 1                    None               None      None           None
# 2                    None               None      None           None
# 3                    None               None      None           None
# 4                    None               None      None           None
# ..                    ...                ...       ...            ...
# 350                  None               None      None           None
# 351                  None               None      None           None
# 352                  None               None      None           None
# 353                  None               None      None           None
# 354                  None               None      None           None
#
#     marker_gene_evidence synonyms parent_cell_set_name  \
# 0                   None     None            D1-Matrix
# 1                   None     None            D1-Matrix
# 2                   None     None            D1-Matrix
# 3                   None     None            D1-Matrix
# 4                   None     None            D2-Matrix
# ..                   ...      ...                  ...
# 350                 None     None                   NN
# 351                 None     None                 None
# 352                 None     None                 None
# 353                 None     None                 None
# 354                 None     None                 None
#
#     parent_cell_set_accession  \
# 0                  AIT115_300
# 1                  AIT115_300
# 2                  AIT115_300
# 3                  AIT115_300
# 4                  AIT115_301
# ..                        ...
# 350                AIT115_369
# 351                      None
# 352                      None
# 353                      None
# 354                      None
#
#                                       user_annotations transferred_annotations
# 0    [{'labelset': 'Supertype', 'cell_label': '1_MS...                    None
# 1    [{'labelset': 'Supertype', 'cell_label': 'None...                    None
# 2    [{'labelset': 'Supertype', 'cell_label': 'None...                    None
# 3    [{'labelset': 'Supertype', 'cell_label': 'None...                    None
# 4    [{'labelset': 'Supertype', 'cell_label': '5_MS...                    None
# ..                                                 ...                     ...
# 350  [{'labelset': 'Supertype', 'cell_label': 'None...                    None
# 351  [{'labelset': 'Supertype', 'cell_label': 'None...                    None
# 352  [{'labelset': 'Supertype', 'cell_label': 'None...                    None
# 353  [{'labelset': 'Supertype', 'cell_label': 'None...                    None
# 354  [{'labelset': 'Supertype', 'cell_label': 'None...                    None
#
# [355 rows x 14 columns]

# %%
df = cas_read.get_all_annotations(labels=[("Neighborhood", "Ependyma"),
                                             ("Cluster", "2_MSN"),
                                             ("Cluster", "5_MSN"),
                                             ("Dummy", "Dummy")])
df
# Out:
#          labelset cell_label cell_set_accession cell_fullname  \
# 1         Cluster      2_MSN           AIT115_2          None
# 4         Cluster      5_MSN           AIT115_5          None
# 350  Neighborhood   Ependyma         AIT115_365          None
#
#     cell_ontology_term_id cell_ontology_term rationale rationale_dois  \
# 1                    None               None      None           None
# 4                    None               None      None           None
# 350                  None               None      None           None
#
#     marker_gene_evidence synonyms parent_cell_set_name  \
# 1                   None     None            D1-Matrix
# 4                   None     None            D2-Matrix
# 350                 None     None                   NN
#
#     parent_cell_set_accession  \
# 1                  AIT115_300
# 4                  AIT115_301
# 350                AIT115_369
#
#                                       user_annotations transferred_annotations
# 1    [{'labelset': 'Supertype', 'cell_label': 'None...                    None
# 4    [{'labelset': 'Supertype', 'cell_label': '5_MS...                    None
# 350  [{'labelset': 'Supertype', 'cell_label': 'None...                    None
