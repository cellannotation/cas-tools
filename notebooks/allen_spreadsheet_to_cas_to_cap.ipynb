# %% [markdown]
# ### Converting an Allen-Style Taxonomy Spreadsheet to CAS Format
#
# This notebook demonstrates how to convert an Allen-style taxonomy spreadsheet into the CAS (Cell Annotation Schema) format, how to merge it to an h5a file and how to export to CAP anndata formt. The process includes the following steps:
#
# 1. **Generate CAS**: Convert the spreadsheet data into the CAS format.
# 2. **Validate CAS against h5ad**: Compare CAS and AnnData to check if the annotations and the hierarchy are the same.
# 3. **Populate IDs**: Add corresponding Cell IDs to the CAS from a related Anndata (h5ad) file.
# 4. **Merge Data**: Integrate the updated CAS into the `var` field of the Anndata object.
# 5. **Export to CAP**: Merge CAS in
#
# This workflow uses a subset of the WMBO dataset. Example Allen-style spreadsheet is derived from the `CB Glut (CS20230722_CLAS_29)` subset of the Mouse Cell-type annotations (https://www.nature.com/articles/s41586-023-06812-z#Sec49, Table 7)
#
# This notebook demonstrates how to carry out these steps in Python, but most can also be done via the [cas-tools command-line interface](https://cellannotation.github.io/cas-tools/cli.html).

# %% [markdown]
# ### How to Run the Notebooks
#
# For detailed instructions on setting up and running the notebooks, please refer to the [README.md](https://github.com/cellannotation/cas-tools/blob/main/notebooks/README.md) in the notebooks directory.

# %% [markdown]
# #### Example of an Allen-Style Spreadsheet
#
# To keep things simple, we use the `CB Glut (CS20230722_CLAS_29)` subset from the Mouse Cell-Type Annotations dataset (refer to [Nature article, Supplementary Table 7](https://www.nature.com/articles/s41586-023-06812-z#Sec49)).

# %%
import pandas as pd

pd.read_csv("./data/wmb_class_29_annotation.tsv", delimiter='\t')[:4]
# Out:
#    cluster_id                 cluster               supertype  \
# 0        5197  5197 CB Granule Glut_1  1154 CB Granule Glut_1
# 1        5198  5198 CB Granule Glut_1  1154 CB Granule Glut_1
# 2        5199  5199 CB Granule Glut_1  1154 CB Granule Glut_1
# 3        5200  5200 CB Granule Glut_2  1155 CB Granule Glut_2
#
#               subclass       class neighborhood anatomical_annotation  notes  \
# 0  314 CB Granule Glut  29 CB Glut    NN-IMN-GC               DCO VCO    NaN
# 1  314 CB Granule Glut  29 CB Glut    NN-IMN-GC               DCO VCO    NaN
# 2  314 CB Granule Glut  29 CB Glut    NN-IMN-GC               DCO VCO    NaN
# 3  314 CB Granule Glut  29 CB Glut    NN-IMN-GC               NOD PFL    NaN
#
#             CCF_broad.freq                                   CCF_acronym.freq  \
# 0  MY:0.35,CB:0.33,NA:0.26  DCO:0.19,FL:0.11,arb:0.09,VCO:0.09,DN:0.08,PFL...
# 1  CB:0.56,MY:0.24,NA:0.19  FL:0.25,PFL:0.17,DCO:0.13,VCO:0.09,arb:0.08,NA...
# 2   MY:0.4,CB:0.38,NA:0.18  DCO:0.29,DN:0.12,arb:0.09,FL:0.09,PFL:0.06,VCO...
# 3          CB:0.77,NA:0.22  PFL:0.17,NOD:0.17,FL:0.13,NA:0.11,arb:0.1,UVU:...
#
#    ...  CTX.subclass_id  CTX.subclass_id.1  CTX.neighborhood_id  \
# 0  ...              NaN                NaN                  NaN
# 1  ...              NaN                NaN                  NaN
# 2  ...              NaN                NaN                  NaN
# 3  ...              NaN                NaN                  NaN
#
#    CTX.neighborhood_label  CTX.size   taxonomy_id  cell_set_accession.cluster  \
# 0                     NaN       NaN  CCN202307220        CS20230722_CLUS_5197
# 1                     NaN       NaN  CCN202307220        CS20230722_CLUS_5198
# 2                     NaN       NaN  CCN202307220        CS20230722_CLUS_5199
# 3                     NaN       NaN  CCN202307220        CS20230722_CLUS_5200
#
#    cell_set_accession.supertype cell_set_accession.subclass  \
# 0          CS20230722_SUPT_1154         CS20230722_SUBC_314
# 1          CS20230722_SUPT_1154         CS20230722_SUBC_314
# 2          CS20230722_SUPT_1154         CS20230722_SUBC_314
# 3          CS20230722_SUPT_1155         CS20230722_SUBC_314
#
#   cell_set_accession.class
# 0       CS20230722_CLAS_29
# 1       CS20230722_CLAS_29
# 2       CS20230722_CLAS_29
# 3       CS20230722_CLAS_29
#
# [4 rows x 40 columns]

# %% [markdown]
# #### Import Spreadsheet into CAS
#
# Import assumes that the source spreadsheet will have:
#
# * One row per cluster (where cluster is the most granular cell set)
# * A column containing cluster_ids
# * A spreadsheet representation of hierarchy with columns for each leve in the hierarchy.
# * A set of columns specific to the sheet (author categories)
#
# To import an Allen-style spreadsheet into the CAS, we need a simple mapping file. This includes some general metadata and specification of heirarchy fields.  Rank refers to the level of a heirarchy field - with 0 being the most granular. The mapping file must specify cluster_id and cluster_name require specific field types.  All other hierarchy fields are typed as cell set.  Here is a configuration for our example sheet:

# %%
# !less ./data/wmb_ingestion_config.yaml
# Out:
# taxonomy_id: CS20230722
# brain_region_names:
#   - Whole Brain
# species_names:
#   - Mouse
# author_name: Hongkui Zeng
# title: Whole Mouse Brain taxonomy
#
# fields:
#   - column_name: cluster_id
#     column_type: cluster_id
#     rank: 0
#
#   - column_name: cluster
#     column_type: cluster_name
#     rank: 0
#
#   - column_name: supertype
#     column_type: cell_set
#     rank: 1
#
#   - column_name: subclass
#     column_type: cell_set
# ./data/wmb_ingestion_config.yaml

# %%
# Import to CAS

import json
from cas.ingest.ingest_user_table import ingest_data, ingest_user_data
from cas.file_utils import write_json_file


cas_data = ingest_user_data("./data/wmb_class_29_annotation.tsv", "./data/wmb_ingestion_config.yaml", True)
wmb_class_29_cas = cas_data.as_dictionary()
print(json.dumps(wmb_class_29_cas, indent=2)[:2000])
write_json_file(cas_data, 'wmb_class_29.json')  # saving CAS JSON file to disk
# Out:
# {
#   "author_name": "Hongkui Zeng",
#   "annotations": [
#     {
#       "labelset": "class",
#       "cell_label": "29 CB Glut",
#       "cell_set_accession": "5206"
#     },
#     {
#       "labelset": "subclass",
#       "cell_label": "314 CB Granule Glut",
#       "cell_set_accession": "5207",
#       "parent_cell_set_accession": "5206"
#     },
#     {
#       "labelset": "supertype",
#       "cell_label": "1154 CB Granule Glut_1",
#       "cell_set_accession": "5208",
#       "parent_cell_set_accession": "5207"
#     },
#     {
#       "labelset": "cluster",
#       "cell_label": "5197 CB Granule Glut_1",
#       "cell_set_accession": "5197",
#       "parent_cell_set_accession": "5208",
#       "author_annotation_fields": {
#         "neighborhood": "NN-IMN-GC",
#         "anatomical_annotation": "DCO VCO",
#         "CCF_broad.freq": "MY:0.35,CB:0.33,NA:0.26",
#         "CCF_acronym.freq": "DCO:0.19,FL:0.11,arb:0.09,VCO:0.09,DN:0.08,PFL:0.07,MY:0.07,mcp:0.06,CUL4, 5:0.04",
#         "v3.size": "14544",
#         "v2.size": "0",
#         "multiome.size": "0",
#         "F": "0.5",
#         "M": "0.5",
#         "Dark": "0.04",
#         "Light": "0.96",
#         "nt_type_label": "Glut",
#         "nt.markers": "Slc17a7:8.41",
#         "nt_type_combo_label": "Glut",
#         "cluster.markers.combo": "Gabra6,Lmx1a,Rnf182",
#         "merfish.markers.combo": "Col27a1,Barhl1,St18,Trhde,Spon1,Syt6",
#         "cluster.TF.markers.combo": "Lmx1a,Zic1,St18",
#         "cluster.markers.combo (within subclass)": "Lmx1a,Rnf182",
#         "taxonomy_id": "CCN202307220",
#         "cell_set_accession.cluster": "CS20230722_CLUS_5197",
#         "cell_set_accession.supertype": "CS20230722_SUPT_1154",
#         "cell_set_accession.subclass": "CS20230722_SUBC_314",
#         "cell_set_accession.class": "CS20230722_CLAS_29"
#       }
#     },
#     {
#       "labelset": "cluster",
#       "cell_label": "5198 CB Granule Glut_1",
#       "cell_set_accession": "5198",
#       "parent_cell_set_accession": "5208",
#       "author_annotation_fields": {
#         "neighborhood": "NN-IMN-GC"

# %%
# !less wmb_class_29.json
# Out:
# {7=
#   "author_name": "Hongkui Zeng",
#   "annotations": [
#     {
#       "labelset": "class",
#       "cell_label": "29 CB Glut",
#       "cell_set_accession": "5206"
#     },
#     {
#       "labelset": "subclass",
#       "cell_label": "314 CB Granule Glut",
#       "cell_set_accession": "5207",
#       "parent_cell_set_accession": "5206"
#     },
#     {
#       "labelset": "supertype",
#       "cell_label": "1154 CB Granule Glut_1",
#       "cell_set_accession": "5208",
#       "parent_cell_set_accession": "5207"
#     },
#     {
#       "labelset": "cluster",
#       "cell_label": "5197 CB Granule Glut_1",
# wmb_class_29.json

# %%
# Or we can use reporting tools from cas-tools to get view dataframes:

from cas import reports
reports.get_all_annotations(wmb_class_29_cas)
# Out:
#      labelset              cell_label cell_set_accession  \
# 0       class              29 CB Glut               5206
# 1    subclass     314 CB Granule Glut               5207
# 2   supertype  1154 CB Granule Glut_1               5208
# 3     cluster  5197 CB Granule Glut_1               5197
# 4     cluster  5198 CB Granule Glut_1               5198
# 5     cluster  5199 CB Granule Glut_1               5199
# 6   supertype  1155 CB Granule Glut_2               5209
# 7     cluster  5200 CB Granule Glut_2               5200
# 8     cluster  5201 CB Granule Glut_2               5201
# 9    subclass        315 DCO UBC Glut               5210
# 10  supertype     1156 DCO UBC Glut_1               5211
# 11    cluster     5202 DCO UBC Glut_1               5202
# 12    cluster     5203 DCO UBC Glut_1               5203
# 13    cluster     5204 DCO UBC Glut_1               5204
# 14    cluster     5205 DCO UBC Glut_1               5205
#
#    parent_cell_set_accession author_annotation_fields.neighborhood  \
# 0                        NaN                                   NaN
# 1                       5206                                   NaN
# 2                       5207                                   NaN
# 3                       5208                             NN-IMN-GC
# 4                       5208                             NN-IMN-GC
# 5                       5208                             NN-IMN-GC
# 6                       5207                                   NaN
# 7                       5209                             NN-IMN-GC
# 8                       5209                             NN-IMN-GC
# 9                       5206                                   NaN
# 10                      5210                                   NaN
# 11                      5211                             NN-IMN-GC
# 12                      5211                             NN-IMN-GC
# 13                      5211                             NN-IMN-GC
# 14                      5211                             NN-IMN-GC
#
#    author_annotation_fields.anatomical_annotation  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                         DCO VCO
# 4                                         DCO VCO
# 5                                         DCO VCO
# 6                                             NaN
# 7                                         NOD PFL
# 8                                             CBX
# 9                                             NaN
# 10                                            NaN
# 11                                            DCO
# 12                                            DCO
# 13                                            DCO
# 14                                            DCO
#
#    author_annotation_fields.CCF_broad.freq  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                  MY:0.35,CB:0.33,NA:0.26
# 4                  CB:0.56,MY:0.24,NA:0.19
# 5                   MY:0.4,CB:0.38,NA:0.18
# 6                                      NaN
# 7                          CB:0.77,NA:0.22
# 8                          CB:0.74,NA:0.26
# 9                                      NaN
# 10                                     NaN
# 11                         MY:0.45,CB:0.35
# 12                         CB:0.57,MY:0.32
# 13                          MY:0.5,CB:0.33
# 14                 MY:0.38,CB:0.29,NA:0.24
#
#             author_annotation_fields.CCF_acronym.freq  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   DCO:0.19,FL:0.11,arb:0.09,VCO:0.09,DN:0.08,PFL...
# 4   FL:0.25,PFL:0.17,DCO:0.13,VCO:0.09,arb:0.08,NA...
# 5   DCO:0.29,DN:0.12,arb:0.09,FL:0.09,PFL:0.06,VCO...
# 6                                                 NaN
# 7   PFL:0.17,NOD:0.17,FL:0.13,NA:0.11,arb:0.1,UVU:...
# 8   NA:0.17,CUL4, 5:0.14,SIM:0.11,ANcr1:0.09,arb:0...
# 9                                                 NaN
# 10                                                NaN
# 11  DCO:0.35,NOD:0.09,VCO:0.08,DN:0.06,arb:0.06,PF...
# 12  DCO:0.21,FL:0.14,PFL:0.14,DN:0.11,NOD:0.07,VCO...
# 13  DCO:0.39,DN:0.07,NOD:0.06,VCO:0.06,arb:0.05,PF...
# 14  DCO:0.27,arb:0.11,NOD:0.06,P:0.05,VCO:0.04,PFL...
#
#    author_annotation_fields.v3.size author_annotation_fields.v2.size  ...  \
# 0                               NaN                              NaN  ...
# 1                               NaN                              NaN  ...
# 2                               NaN                              NaN  ...
# 3                             14544                                0  ...
# 4                              2196                                0  ...
# 5                               909                                0  ...
# 6                               NaN                              NaN  ...
# 7                               220                                0  ...
# 8                            115909                                0  ...
# 9                               NaN                              NaN  ...
# 10                              NaN                              NaN  ...
# 11                             4062                                0  ...
# 12                              101                                0  ...
# 13                             2815                                0  ...
# 14                              350                                0  ...
#
#    author_annotation_fields.cluster.markers.combo  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                             Gabra6,Lmx1a,Rnf182
# 4                                    Gabra6,Cntn5
# 5                                  Cbln3,Tmem132d
# 6                                             NaN
# 7                             Gabra6,Gap43,Il1rap
# 8                              Gabra6,Daam2,Calb2
# 9                                             NaN
# 10                                            NaN
# 11                                Sln,Lmx1a,Plpp4
# 12                               Sln,Asic5,Slc4a4
# 13                                 Sln,Cbln3,Rgs6
# 14                               Sln,Abi3bp,Calb2
#
#    author_annotation_fields.merfish.markers.combo  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3            Col27a1,Barhl1,St18,Trhde,Spon1,Syt6
# 4                             Svep1,Slc17a7,Chrm2
# 5                             Eomes,Col27a1,Calb2
# 6                                             NaN
# 7                         Eomes,Svep1,Ntng1,Medag
# 8                      Svep1,Slc17a7,Pappa,Barhl2
# 9                                             NaN
# 10                                            NaN
# 11                         Eomes,Ctxn3,Plpp4,Zic1
# 12                             Eomes,Ctxn3,Grin2c
# 13                        Eomes,Ramp3,Ctxn3,Calb2
# 14                           Eomes,Cyp26b1,Abi3bp
#
#    author_annotation_fields.cluster.TF.markers.combo  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                    Lmx1a,Zic1,St18
# 4                           Pax6,Neurod2,Etv1,Bcl11b
# 5                           Eomes,Lmx1a,Nr2f2,Lin28b
# 6                                                NaN
# 7                               Eomes,St18,En2,Nr4a2
# 8                      Pax6,En2,Etv1,Barhl2,Uncx,Maf
# 9                                                NaN
# 10                                               NaN
# 11                     Eomes,Lmx1a,Thrb,Neurod6,Zeb2
# 12                             Eomes,Lmx1a,Zeb2,Thrb
# 13                           Eomes,Lmx1a,Klf3,Lin28b
# 14                             Eomes,Lmx1a,Klf6,Klf3
#
#    author_annotation_fields.cluster.markers.combo (within subclass)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                        Lmx1a,Rnf182
# 4                                               Cntn5
# 5                                                Rgs6
# 6                                                 NaN
# 7                                         Gap43,Kcnq5
# 8                                              Clstn2
# 9                                                 NaN
# 10                                                NaN
# 11                                              Plpp4
# 12                                             Slc4a4
# 13                                         Calb2,Rgs6
# 14                                             Abi3bp
#
#    author_annotation_fields.taxonomy_id  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                          CCN202307220
# 4                          CCN202307220
# 5                          CCN202307220
# 6                                   NaN
# 7                          CCN202307220
# 8                          CCN202307220
# 9                                   NaN
# 10                                  NaN
# 11                         CCN202307220
# 12                         CCN202307220
# 13                         CCN202307220
# 14                         CCN202307220
#
#    author_annotation_fields.cell_set_accession.cluster  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                CS20230722_CLUS_5197
# 4                                CS20230722_CLUS_5198
# 5                                CS20230722_CLUS_5199
# 6                                                 NaN
# 7                                CS20230722_CLUS_5200
# 8                                CS20230722_CLUS_5201
# 9                                                 NaN
# 10                                                NaN
# 11                               CS20230722_CLUS_5202
# 12                               CS20230722_CLUS_5203
# 13                               CS20230722_CLUS_5204
# 14                               CS20230722_CLUS_5205
#
#    author_annotation_fields.cell_set_accession.supertype  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                CS20230722_SUPT_1154
# 4                                CS20230722_SUPT_1154
# 5                                CS20230722_SUPT_1154
# 6                                                 NaN
# 7                                CS20230722_SUPT_1155
# 8                                CS20230722_SUPT_1155
# 9                                                 NaN
# 10                                                NaN
# 11                               CS20230722_SUPT_1156
# 12                               CS20230722_SUPT_1156
# 13                               CS20230722_SUPT_1156
# 14                               CS20230722_SUPT_1156
#
#    author_annotation_fields.cell_set_accession.subclass  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                 CS20230722_SUBC_314
# 4                                 CS20230722_SUBC_314
# 5                                 CS20230722_SUBC_314
# 6                                                 NaN
# 7                                 CS20230722_SUBC_314
# 8                                 CS20230722_SUBC_314
# 9                                                 NaN
# 10                                                NaN
# 11                                CS20230722_SUBC_315
# 12                                CS20230722_SUBC_315
# 13                                CS20230722_SUBC_315
# 14                                CS20230722_SUBC_315
#
#    author_annotation_fields.cell_set_accession.class  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                 CS20230722_CLAS_29
# 4                                 CS20230722_CLAS_29
# 5                                 CS20230722_CLAS_29
# 6                                                NaN
# 7                                 CS20230722_CLAS_29
# 8                                 CS20230722_CLAS_29
# 9                                                NaN
# 10                                               NaN
# 11                                CS20230722_CLAS_29
# 12                                CS20230722_CLAS_29
# 13                                CS20230722_CLAS_29
# 14                                CS20230722_CLAS_29
#
#    author_annotation_fields.np.markers
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                         Adcyap1:6.7
# 12                         Adcyap1:5.8
# 13                         Adcyap1:4.7
# 14                         Adcyap1:3.6
#
# [15 rows x 28 columns]

# %% [markdown]
# #### Retrieve AnnData File for `CB Glut`
#
# Assumed starting point - an AnnData file with annotations corresponding to the hierarchy in the spreadsheet.
#
# Download the AnnData file corresponding to `CB Glut (CS20230722_CLAS_29)`. The original [WMB-10Xv2](https://allen-brain-cell-atlas.s3.us-west-2.amazonaws.com/index.html#expression_matrices/WMB-10Xv2/20230630/) and [WMB-10Xv3](https://allen-brain-cell-atlas.s3.us-west-2.amazonaws.com/index.html#expression_matrices/WMB-10Xv3/20230630/) AnnData files were generated based on dissection.
#
# These files were merged and then split into 34 top-level classes. The resulting AnnData files for each class can be accessed at the following links:
# - [Class 01](http://cellular-semantics.cog.sanger.ac.uk/public/merged_CS20230722_CLAS_01.h5ad)
# - [Class 02](http://cellular-semantics.cog.sanger.ac.uk/public/merged_CS20230722_CLAS_02.h5ad)
# - ...
# - [Class 34](http://cellular-semantics.cog.sanger.ac.uk/public/merged_CS20230722_CLAS_34.h5ad)
#
# The file specific to `CB Glut` is included in this collection.

# %%
#!rm merged_CS20230722_CLAS_29.h5ad
# !wget -N http://cellular-semantics.cog.sanger.ac.uk/public/merged_CS20230722_CLAS_29.h5ad
# Out:
# --2025-02-11 15:55:53--  http://cellular-semantics.cog.sanger.ac.uk/public/merged_CS20230722_CLAS_29.h5ad
# Resolving cellular-semantics.cog.sanger.ac.uk (cellular-semantics.cog.sanger.ac.uk)... 193.62.203.62, 193.62.203.61, 193.62.203.63
# Connecting to cellular-semantics.cog.sanger.ac.uk (cellular-semantics.cog.sanger.ac.uk)|193.62.203.62|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cellular-semantics.cog.sanger.ac.uk/public/merged_CS20230722_CLAS_29.h5ad [following]
# --2025-02-11 15:55:53--  https://cellular-semantics.cog.sanger.ac.uk/public/merged_CS20230722_CLAS_29.h5ad
# Connecting to cellular-semantics.cog.sanger.ac.uk (cellular-semantics.cog.sanger.ac.uk)|193.62.203.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2585489225 (2.4G) [binary/octet-stream]
# Saving to: ‘merged_CS20230722_CLAS_29.h5ad’
#
# merged_CS20230722_C 100%[===================>]   2.41G  8.82MB/s    in 4m 39s
#
# 2025-02-11 16:00:32 (8.83 MB/s) - ‘merged_CS20230722_CLAS_29.h5ad’ saved [2585489225/2585489225]

# %%
from cas.file_utils import read_anndata_file
CLAS_29_ad = read_anndata_file("./merged_CS20230722_CLAS_29.h5ad")
CLAS_29_ad.obs[:3]
# Out:
#                               cell_barcode       library_label      tissue  \
# cell_label
# AAACCCAAGAACAAGG-472_A05  AAACCCAAGAACAAGG  L8TX_201217_01_G07  Cerebellum
# AAACCCAAGAATCCCT-473_A06  AAACCCAAGAATCCCT  L8TX_201217_01_A08  Cerebellum
# AAACCCAAGACTACCT-225_A01  AAACCCAAGACTACCT  L8TX_200227_01_F10     Medulla
#
#                          tissue_ontology_term_id neurotransmitter       class  \
# cell_label
# AAACCCAAGAACAAGG-472_A05          UBERON:0002037             Glut  29 CB Glut
# AAACCCAAGAATCCCT-473_A06          UBERON:0002037             Glut  29 CB Glut
# AAACCCAAGACTACCT-225_A01          UBERON:0001896             Glut  29 CB Glut
#
#                                      subclass               supertype  \
# cell_label
# AAACCCAAGAACAAGG-472_A05  314 CB Granule Glut  1155 CB Granule Glut_2
# AAACCCAAGAATCCCT-473_A06  314 CB Granule Glut  1155 CB Granule Glut_2
# AAACCCAAGACTACCT-225_A01  314 CB Granule Glut  1154 CB Granule Glut_1
#
#                                          cluster      organism disease  \
# cell_label
# AAACCCAAGAACAAGG-472_A05  5201 CB Granule Glut_2  Mus musculus  normal
# AAACCCAAGAATCCCT-473_A06  5201 CB Granule Glut_2  Mus musculus  normal
# AAACCCAAGACTACCT-225_A01  5197 CB Granule Glut_1  Mus musculus  normal
#
#                               assay
# cell_label
# AAACCCAAGAACAAGG-472_A05  10x 3' v2
# AAACCCAAGAATCCCT-473_A06  10x 3' v3
# AAACCCAAGACTACCT-225_A01  10x 3' v2

# %% [markdown]
# #### Analyse CAS and AnnData

# %% [markdown]
# #### Populate CAS with Cell IDs
#
# **Check hieraarchies match between h5ad and CAS, and if they do, add Cell IDs to CAS**
#
# * *Checks*: Does the heirarchy of nested cell sets in the AnnData file matches the heirarchy in the CAS file (as derived from the Allen spreadsheet)? If two cell set are identical but one has a higher rank then the other, this is also treated as valid heirarchy.
# * *Warnings*: If heirarchies do not match, report differences
# * *Update IDs*: If heirarchies match, add cell IDs to the most granular level of the hierarchy in CAS.  (Cell IDs for other levels can be derived from the hierarchy).

# %%
from cas.populate_cell_ids import add_cell_ids

# get list of labelset names sorted by rank
labelset_names = [labelset.name for labelset in sorted(cas_data.labelsets, key=lambda x: x.rank)]
cas = add_cell_ids(wmb_class_29_cas, CLAS_29_ad.obs, labelset_names)
print(json.dumps(cas["annotations"][5], indent=2)[:1500])
with open('CLAS_29_ad.json', 'w') as f:
    f.write(json.dumps(cas))
CLAS_29_ad.file.close()
# Out:
# {
#   "labelset": "cluster",
#   "cell_label": "5199 CB Granule Glut_1",
#   "cell_set_accession": "5199",
#   "parent_cell_set_accession": "5208",
#   "author_annotation_fields": {
#     "neighborhood": "NN-IMN-GC",
#     "anatomical_annotation": "DCO VCO",
#     "CCF_broad.freq": "MY:0.4,CB:0.38,NA:0.18",
#     "CCF_acronym.freq": "DCO:0.29,DN:0.12,arb:0.09,FL:0.09,PFL:0.06,VCO:0.05,MY:0.05,CUL4, 5:0.05,P:0.04",
#     "v3.size": "909",
#     "v2.size": "0",
#     "multiome.size": "0",
#     "F": "0.44",
#     "M": "0.56",
#     "Dark": "0.03",
#     "Light": "0.97",
#     "nt_type_label": "Glut",
#     "nt.markers": "Slc17a7:8.33,Slc17a6:3.37",
#     "nt_type_combo_label": "Glut",
#     "cluster.markers.combo": "Cbln3,Tmem132d",
#     "merfish.markers.combo": "Eomes,Col27a1,Calb2",
#     "cluster.TF.markers.combo": "Eomes,Lmx1a,Nr2f2,Lin28b",
#     "cluster.markers.combo (within subclass)": "Rgs6",
#     "taxonomy_id": "CCN202307220",
#     "cell_set_accession.cluster": "CS20230722_CLUS_5199",
#     "cell_set_accession.supertype": "CS20230722_SUPT_1154",
#     "cell_set_accession.subclass": "CS20230722_SUBC_314",
#     "cell_set_accession.class": "CS20230722_CLAS_29"
#   },
#   "cell_ids": [
#     "AAACCCAGTAGCTGTT-225_A01",
#     "AAACCCATCGAACGGA-175_B01",
#     "AAACGAAGTGTTCGTA-175_A01",
#     "AAACGAATCAGGAACG-231.2_B01",
#     "AAACGCTGTCTTGGTA-175_A01",
#     "AAAGAACTCTCGCGTT-231.2_B01",
#     "AAAGGGCCAGTCGGTC-231.2_A01",
#     "AAAGGGCGTCAAGGCA-179_C01",
#     "AAAGGTACATCCCGTT-179_C01",
#     "AAAGTCCAGAGAAGGT-175_B01",
#     "AAAGTGACATTGAGGG

# %% [markdown]
# #### Merge CAS to Anndata
#
# Adds CAS to uns of the AnnData file.
#
# Note that further checks are carried out here to assess whether cell set membership matches between the CAS file and the AnnData file.  In this case they do match, but this also protects against files being out of sync.

# %%
from cas.anndata_conversion import merge_cas_object
import anndata as ad

merge_cas_object(input_json=wmb_class_29_cas, 
                 anndata_file_path="./merged_CS20230722_CLAS_29.h5ad", 
                 validate=True, 
                 output_file_path ="./merged_CS20230722_CLAS_29_v2.h5ad")
# Out:
# Error during read anndata file at path: ./merged_CS20230722_CLAS_29_v2.h5ad, error = Unable to open file (file is already open for read-only)!
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[24], line 4
#       1 from cas.anndata_conversion import merge_cas_object
#       2 import anndata as ad
# ----> 4 merge_cas_object(input_json=wmb_class_29_cas,
#       5                  anndata_file_path="./merged_CS20230722_CLAS_29.h5ad",
#       6                  validate=True,
#       7                  output_file_path ="./merged_CS20230722_CLAS_29_v2.h5ad")
#
# File ~/Documents/GitHub/cas-tools/venv/lib/python3.9/site-packages/cas/anndata_conversion.py:72, in merge_cas_object(input_json, anndata_file_path, validate, output_file_path, download_dir)
#      69     anndata_file_path = fetch_anndata(input_json, download_dir)
#      70 anndata_file_path = copy_and_update_file_path(anndata_file_path, output_file_path)
# ---> 72 with read_h5ad(file_path=anndata_file_path, edit=True) as cap_adata:
#      73     cap_adata.read_obs()
#      74     obs = cap_adata.obs
#
# File ~/Documents/GitHub/cas-tools/venv/lib/python3.9/site-packages/cap_anndata/reader.py:29, in read_h5ad(file_path, edit)
#      25 except Exception as error:
#      26     logger.error(
#      27         f"Error during read anndata file at path: {file_path}, error = {error}!"
#      28     )
# ---> 29     raise error
#
# File ~/Documents/GitHub/cas-tools/venv/lib/python3.9/site-packages/cap_anndata/reader.py:20, in read_h5ad(file_path, edit)
#      17 logger.debug(f"Read file {file_path} mode={mode} in context...")
#      19 try:
# ---> 20     file = h5py.File(file_path, mode)
#      21     cap_adata = CapAnnData(file)
#      22     logger.debug(f"Successfully read anndata file path {file_path}")
#
# File ~/Documents/GitHub/cas-tools/venv/lib/python3.9/site-packages/h5py/_hl/files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File ~/Documents/GitHub/cas-tools/venv/lib/python3.9/site-packages/h5py/_hl/files.py:237, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
# --> 237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#     238 elif mode in ['w-', 'x']:
#     239     fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# OSError: Unable to open file (file is already open for read-only)

# %%
from cas.file_utils import read_cas_from_anndata

cas_read = read_cas_from_anndata("./merged_CS20230722_CLAS_29_v2.h5ad")
cas_read.get_all_annotations().head(5)
# Out:
#     labelset              cell_label    cell_set_accession cell_fullname  \
# 0      class              29 CB Glut    CS20230722_CLAS_29          None
# 1   subclass     314 CB Granule Glut   CS20230722_SUBC_314          None
# 2   subclass        315 DCO UBC Glut   CS20230722_SUBC_315          None
# 3  supertype  1154 CB Granule Glut_1  CS20230722_SUPT_1154          None
# 4  supertype  1155 CB Granule Glut_2  CS20230722_SUPT_1155          None
#
#   cell_ontology_term_id       cell_ontology_term rationale rationale_dois  \
# 0                  None                     None      None           None
# 1            CL:0001031  cerebellar granule cell      None           None
# 2            CL:4023161      unipolar brush cell      None           None
# 3                  None                     None      None           None
# 4                  None                     None      None           None
#
#   marker_gene_evidence synonyms  ... author_annotation_fields.neighborhood  \
# 0                 None     None  ...                             NN-IMN-GC
# 1                 None     None  ...                             NN-IMN-GC
# 2                 None     None  ...                             NN-IMN-GC
# 3                 None     None  ...                                  None
# 4                 None     None  ...                                  None
#
#   author_annotation_fields.subclass.tf.markers.combo  \
# 0                                               None
# 1                                  Pax6,Neurod2,Etv1
# 2                                   Eomes,Lmx1a,Klf3
# 3                                               None
# 4                                               None
#
#   author_annotation_fields.subclass.markers.combo  \
# 0                                            None
# 1                                     Gabra6,Ror1
# 2                                       Sln,Lmx1a
# 3                                            None
# 4                                            None
#
#   author_annotation_fields.supertype.markers.combo _within subclass_  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                              Cntn3
# 4                                              Gap43
#
#   author_annotation_fields.supertype.markers.combo  \
# 0                                             None
# 1                                             None
# 2                                             None
# 3                                     Gabra6,Lmx1a
# 4                               Gabra6,Gap43,Rab37
#
#   author_annotation_fields.anatomical_annotation  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
#
#   author_annotation_fields.merfish.markers.combo  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
#
#   author_annotation_fields.cluster.TF.markers.combo  \
# 0                                              None
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
#
#   author_annotation_fields.cluster.markers.combo _within subclass_  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   author_annotation_fields.cluster.markers.combo
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Export to CAP
#
# This flattens the annotations to obs following the spec in the [cap_anndata_schema](https://github.com/cellannotation/cell-annotation-schema/blob/main/docs/cap_anndata_schema.md). stores cas in the header and save checksums of cell IDs to use for validating

# %%
# !cas export2CAP --json wmb_class_29.json --anndata ./merged_CS20230722_CLAS_29_v2.h5ad --output ./flattened_CS20230722_CLAS_29.h5ad
# Out:
# Traceback (most recent call last):
#   File "/Users/do12/Documents/GitHub/cas-tools/venv/bin/cas", line 8, in <module>
#     sys.exit(main())
#   File "/Users/do12/Documents/GitHub/cas-tools/venv/lib/python3.9/site-packages/cas/__main__.py", line 64, in main
#     export2cap(json_file_path, anndata_file_path, output_file_path, fill_na)
#   File "/Users/do12/Documents/GitHub/cas-tools/venv/lib/python3.9/site-packages/cas/flatten_data_to_anndata.py", line 76, in export2cap
#     export_cas_object2cap(input_json, anndata_file_path, output_file_path, fill_na)
#   File "/Users/do12/Documents/GitHub/cas-tools/venv/lib/python3.9/site-packages/cas/flatten_data_to_anndata.py", line 114, in export_cas_object2cap
#     flatten_data = process_annotations(
#   File "/Users/do12/Documents/GitHub/cas-tools/venv/lib/python3.9/site-packages/cas/flatten_data_to_anndata.py", line 153, in process_annotations
#     else accession_manager.generate_accession_id(
#   File "/Users/do12/Documents/GitHub/cas-tools/venv/lib/python3.9/site-packages/cas/accession/hash_accession_manager.py", line 39, in generate_accession_id
#     raise Exception("Cell IDs list is empty.")
# Exception: Cell IDs list is empty.

# %%
flattened_adata = anndata.read_h5ad("flattened_CS20230722_CLAS_29.h5ad", backed='r')
flattened_adata.obs[:5]

# %%
# !which cas
# Out:
# /Users/do12/Documents/GitHub/cas-tools/venv/bin/cas
