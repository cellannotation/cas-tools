# %%
# Install pip packages
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install cas-tools
# Out:
# ...
#   Using cached pandas-2.1.4-cp39-cp39-macosx_11_0_arm64.whl (11.0 MB)
# ...
#   Using cached numpy-1.26.3-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
# ...
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# ...
#   Using cached tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.3.2 is available.
# You should consider upgrading via the '/Users/hk9/workspaces/workspace1/cas-tools/notebooks/venv/bin/python3 -m pip install --upgrade pip' command.
# ...
#   Using cached cas_tools-0.0.1.dev14-py3-none-any.whl (25 kB)
# ...
#   Using cached dataclasses_json-0.6.3-py3-none-any.whl (28 kB)
# ...
#   Using cached ruamel.yaml-0.18.5-py3-none-any.whl (116 kB)
# ...
#   Using cached anndata-0.10.3-py3-none-any.whl (119 kB)
# ...
#   Using cached h5py-3.10.0-cp39-cp39-macosx_11_0_arm64.whl (2.7 MB)
# ...
#   Using cached array_api_compat-1.4-py3-none-any.whl (29 kB)
# ...
#   Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# ...

# %%
import pandas as pd
from cas.reports import get_all_annotations
from cas.file_utils import read_cas_json_file, read_cas_from_anndata

# %%
cas = read_cas_json_file("../src/test/test_data/siletti/Siletti_all_non_neuronal_cells_with_cids.json")
# cas = read_cas_from_anndata("/path/to/my_anndata.h5ad")

# %%
df = cas.get_all_annotations()
df
# Out:
#              labelset                           cell_label cell_set_accession  \
# 0   supercluster_term                            Microglia    CS202210140_464
# 1   supercluster_term                             Vascular    CS202210140_465
# 2   supercluster_term                           Fibroblast    CS202210140_466
# 3   supercluster_term            Oligodendrocyte precursor    CS202210140_467
# 4   supercluster_term  Committed oligodendrocyte precursor    CS202210140_468
# ..                ...                                  ...                ...
# 84            Cluster                              Chrp_78     CS202210140_79
# 85            Cluster                              Chrp_79     CS202210140_80
# 86            Cluster                              Chrp_80     CS202210140_81
# 87            Cluster                              Chrp_81     CS202210140_82
# 88            Cluster                              Chrp_82     CS202210140_83
#
# ...

# %%
df = cas.get_all_annotations(labels=[("Supercluster", "Microglia"),
                                             ("Cluster", "Mgl_4"),
                                             ("Cluster", "Astro_55"),
                                             ("Dummy", "Dummy")])
df
# Out:
#         labelset cell_label cell_set_accession cell_fullname  \
# 0   Supercluster  Microglia    CS202210140_464          None
# 10       Cluster      Mgl_4      CS202210140_5          None
# 61       Cluster   Astro_55     CS202210140_56          None
#
#    cell_ontology_term_id cell_ontology_term rationale rationale_dois  \
# 0             CL:0000129          microglia                       []
# 10                                                                []
# 61                                                                []
#
#    marker_gene_evidence synonyms parent_cell_set_name  \
# 0               [PTPRC]     None                 None
# 10                   []     None            Microglia
# 61                   []     None            Astrocyte
#
#    parent_cell_set_accession  \
# 0                       None
# 10           CS202210140_464
# 61           CS202210140_470
#
#                                     user_annotations transferred_annotations
# ...
