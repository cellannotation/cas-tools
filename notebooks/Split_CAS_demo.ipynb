# %% [markdown]
# ## Introduction
#
# In this notebook, we demonstrate how to manage and split large Whole Mouse Brain CAS files into smaller, more manageable files. The workflow includes:
#
# - Installing the required packages.
# - Downloading the latest Whole Mouse Brain CAS file.
# - Inspecting the original file to check the cell set count in the annotations.
# - Splitting the large CAS file using the `29 CB Glut` cell set as a reference point.  This splits out the chosen reference cell set and all its subsets.
# - Comparing the annotations and cell set counts before and after the split to ensure the operation was successful.

# %% [markdown]
# ### Installing Required Packages

# %% [markdown]
# For detailed instructions on setting up and running the notebooks, please refer to the [README.md](https://github.com/cellannotation/cas-tools/blob/main/notebooks/README.md) in the notebooks directory.

# %% [markdown]
# ### Downloading latest version of Whole Mouse Brain CAS file

# %%
# !wget https://raw.githubusercontent.com/brain-bican/whole_mouse_brain_taxonomy/refs/heads/main/CCN20230722.json -O CCN20230722.json
# Out:
# --2025-03-18 11:55:16--  https://raw.githubusercontent.com/brain-bican/whole_mouse_brain_taxonomy/refs/heads/main/CCN20230722.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8000::154, 2606:50c0:8003::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12364592 (12M) [text/plain]
# Saving to: ‘CCN20230722.json’
#
# CCN20230722.json    100%[===================>]  11.79M  3.27MB/s    in 3.6s
#
# 2025-03-18 11:55:20 (3.28 MB/s) - ‘CCN20230722.json’ saved [12364592/12364592]

# %%
# Load and inspect the JSON file.

import json
import pandas as pd
with open("data/CCN20230722.json", "r") as f:
    cas = json.load(f)
print(f"There are {len(cas['annotations'])} cell sets in CAS annotations")
# Out:
# There are 6905 cell sets in CAS annotations

# %% [markdown]
# labelsets in the heirarchy have a rank, from 0 (leaf node) up.  labelsets outside of the heirarchy have no rank

# %%
pd.DataFrame.from_records(cas['labelsets'])
# Out:
#                name                                        description  rank
# 0  neurotransmitter  Clusters are assigned based on the average exp...   NaN
# 1             class  The top level of cell type definition in the m...   3.0
# 2          subclass  The coarse level of cell type definition in th...   2.0
# 3         supertype  The second finest level of cell type definitio...   1.0
# 4           cluster  The finest level of cell type definition in th...   0.0

# %% [markdown]
# ### Splitting Large CAS Files
#
# Large CAS files can be split into smaller ones based on cell accession IDs. By specifying an accession_id, you determine which groups are included in the split CAS. The `split_cas` command will create a separate CAS file for every cell set nested under the provided cell set.

# %%
# !cas split_cas --help
# Out:
# usage: cas split_cas [-h] --cas_json CAS_JSON
#                      [--split_on SPLIT_ON [SPLIT_ON ...]] [--multiple_outputs]
#
# Split CAS JSON file based on specified cell label/s.
#
# options:
#   -h, --help            show this help message and exit
#   --cas_json CAS_JSON   Path to the CAS JSON file that will be split
#   --split_on SPLIT_ON [SPLIT_ON ...]
#                         Cell accession_id(s) to split the CAS file.
#   --multiple_outputs    If set, create multiple output files for each split_on
#                         term; if not set, create a single output file named
#                         `split_cas.json`.

# %% [markdown]
# Split on the `29 CB Glut` cell set using accession_id `CS20230722_CLAS_29`.

# %%
# !cas split_cas --cas_json data/CCN20230722.json --split_on CS20230722_CLAS_29

# %%
with open("split_cas.json", "r") as f:
    split_cas = json.load(f)
print(f"There are {len(split_cas['annotations'])} cell sets in splited CAS annotations")
# Out:
# There are 16 cell sets in splited CAS annotations

# %%
from cas.file_utils import read_cas_json_file
caz = read_cas_json_file('./split_cas.json')
caz.get_all_annotations()
# Out:
#             labelset              cell_label    cell_set_accession  \
# 0   neurotransmitter                    Glut  CS20230722_NEUR_Glut
# 1              class              29 CB Glut    CS20230722_CLAS_29
# 2           subclass     314 CB Granule Glut   CS20230722_SUBC_314
# 3           subclass        315 DCO UBC Glut   CS20230722_SUBC_315
# 4          supertype  1154 CB Granule Glut_1  CS20230722_SUPT_1154
# 5          supertype  1155 CB Granule Glut_2  CS20230722_SUPT_1155
# 6          supertype     1156 DCO UBC Glut_1  CS20230722_SUPT_1156
# 7            cluster  5197 CB Granule Glut_1  CS20230722_CLUS_5197
# 8            cluster  5198 CB Granule Glut_1  CS20230722_CLUS_5198
# 9            cluster  5199 CB Granule Glut_1  CS20230722_CLUS_5199
# 10           cluster  5200 CB Granule Glut_2  CS20230722_CLUS_5200
# 11           cluster  5201 CB Granule Glut_2  CS20230722_CLUS_5201
# 12           cluster     5202 DCO UBC Glut_1  CS20230722_CLUS_5202
# 13           cluster     5203 DCO UBC Glut_1  CS20230722_CLUS_5203
# 14           cluster     5204 DCO UBC Glut_1  CS20230722_CLUS_5204
# 15           cluster     5205 DCO UBC Glut_1  CS20230722_CLUS_5205
#
#    cell_fullname cell_ontology_term_id       cell_ontology_term rationale  \
# 0           None            CL:0000679     glutamatergic neuron      None
# 1           None            CL:0000540                   neuron      None
# 2           None            CL:0001031  cerebellar granule cell      None
# 3           None            CL:4023161      unipolar brush cell      None
# 4           None                  None                     None      None
# 5           None                  None                     None      None
# 6           None                  None                     None      None
# 7           None                  None                     None      None
# 8           None                  None                     None      None
# 9           None                  None                     None      None
# 10          None                  None                     None      None
# 11          None                  None                     None      None
# 12          None                  None                     None      None
# 13          None                  None                     None      None
# 14          None                  None                     None      None
# 15          None                  None                     None      None
#
#    rationale_dois marker_gene_evidence synonyms  ...  \
# 0            None                 None     None  ...
# 1            None                 None     None  ...
# 2            None                 None     None  ...
# 3            None                 None     None  ...
# 4            None                 None     None  ...
# 5            None                 None     None  ...
# 6            None                 None     None  ...
# 7            None                 None     None  ...
# 8            None                 None     None  ...
# 9            None                 None     None  ...
# 10           None                 None     None  ...
# 11           None                 None     None  ...
# 12           None                 None     None  ...
# 13           None                 None     None  ...
# 14           None                 None     None  ...
# 15           None                 None     None  ...
#
#    author_annotation_fields.merfish.markers.combo  \
# 0                                             NaN
# 1                                            None
# 2                                            None
# 3                                            None
# 4                                            None
# 5                                            None
# 6                                            None
# 7            Col27a1,Barhl1,St18,Trhde,Spon1,Syt6
# 8                             Svep1,Slc17a7,Chrm2
# 9                             Eomes,Col27a1,Calb2
# 10                        Eomes,Svep1,Ntng1,Medag
# 11                     Svep1,Slc17a7,Pappa,Barhl2
# 12                         Eomes,Ctxn3,Plpp4,Zic1
# 13                             Eomes,Ctxn3,Grin2c
# 14                        Eomes,Ramp3,Ctxn3,Calb2
# 15                           Eomes,Cyp26b1,Abi3bp
#
#    author_annotation_fields.CTX.size  \
# 0                                NaN
# 1                               None
# 2                               None
# 3                               None
# 4                               None
# 5                               None
# 6                               None
# 7                               None
# 8                               None
# 9                               None
# 10                              None
# 11                              None
# 12                              None
# 13                              None
# 14                              None
# 15                              None
#
#     author_annotation_fields.subclass.tf.markers.combo  \
# 0                                                 NaN
# 1                                                None
# 2                                   Pax6,Neurod2,Etv1
# 3                                    Eomes,Lmx1a,Klf3
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
#
#    author_annotation_fields.nt_type_label  \
# 0                                     NaN
# 1                                    None
# 2                                    Glut
# 3                                    Glut
# 4                                    None
# 5                                    None
# 6                                    None
# 7                                    Glut
# 8                                    Glut
# 9                                    Glut
# 10                                   Glut
# 11                                   Glut
# 12                                   Glut
# 13                                   Glut
# 14                                   Glut
# 15                                   Glut
#
#    author_annotation_fields.nt_type_combo_label  \
# 0                                           NaN
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# 5                                          None
# 6                                          None
# 7                                          Glut
# 8                                          Glut
# 9                                          Glut
# 10                                         Glut
# 11                                         Glut
# 12                                         Glut
# 13                                         Glut
# 14                                         Glut
# 15                                         Glut
#
#    author_annotation_fields.CTX.cluster_id  \
# 0                                      NaN
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# 5                                     None
# 6                                     None
# 7                                     None
# 8                                     None
# 9                                     None
# 10                                    None
# 11                                    None
# 12                                    None
# 13                                    None
# 14                                    None
# 15                                    None
#
#    author_annotation_fields.CTX.neighborhood_id author_annotation_fields.F  \
# 0                                           NaN                        NaN
# 1                                          None                       None
# 2                                          None                       None
# 3                                          None                       None
# 4                                          None                       None
# 5                                          None                       None
# 6                                          None                       None
# 7                                          None                        0.5
# 8                                          None                       0.45
# 9                                          None                       0.44
# 10                                         None                       0.49
# 11                                         None                       0.48
# 12                                         None                       0.43
# 13                                         None                       0.34
# 14                                         None                       0.45
# 15                                         None                       0.51
#
#    author_annotation_fields.CTX.neighborhood_label author_annotation_fields.M
# 0                                              NaN                        NaN
# 1                                             None                       None
# 2                                             None                       None
# 3                                             None                       None
# 4                                             None                       None
# 5                                             None                       None
# 6                                             None                       None
# 7                                             None                        0.5
# 8                                             None                       0.55
# 9                                             None                       0.56
# 10                                            None                       0.51
# 11                                            None                       0.52
# 12                                            None                       0.57
# 13                                            None                       0.66
# 14                                            None                       0.55
# 15                                            None                       0.49
#
# [16 rows x 50 columns]
